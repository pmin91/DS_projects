# %%
from sklearn.feature_extraction.text import CountVectorizer
text = ["wookie stormtrooper",
        "wookie wookie wookie stormtrooper stormtrooper stormtrooper",
        "harry potter"]
# CountVectorizer is a class; so `vectorizer` below represents an instance of that object.
vectorizer = CountVectorizer()

# call `fit` to build the vocabulary
vectorizer.fit(text)

# then, use `get_feature_names` to return the tokens
print(vectorizer.get_feature_names())

# finally, call `transform` to convert text to a bag of words
x = vectorizer.transform(text)
# Out:
# ['harry', 'potter', 'stormtrooper', 'wookie']

# %%
print(x)
# Out:
#   (0, 2)	1
#   (0, 3)	1
#   (1, 2)	3
#   (1, 3)	3
#   (2, 0)	1
#   (2, 1)	1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vect = TfidfVectorizer(min_df=1)
tfidf = vect.fit_transform(text)

# %%
(tfidf * tfidf.T)
# Out:
# <3x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Generate the numbers 1 to 100.
#
# Do the above via list comprehension; then do it by using map and filter (hint: use lambda functions):
#
# Square the numbers.
# Select just the squares that are odd.
# What does reduce do? Use it to do the following:
#
# Add up the numbers 1 to 100.
# Square the numbers.
# Select just the numbers that are odd.

# %%
from functools import reduce
nums = [x for x in range(1,101)]
sums = reduce(lambda x, y: x + y, nums)
squares = list(map(lambda x: x**2, nums))
odd = list(filter(lambda x: x%2==1, squares))

# %%
import sys

def reading(self):
    s = open('/Users/petermin/sea18_ds4/class_lectures/week09-kojak1/01-docker-hadoop-hive/input.txt', 'r').read()
    self.whip = eval(s)
reading
# Out:
# <function __main__.reading>

# %% [markdown]
# 1. The mapping function will have to find each user_name.  Hint: it's nested.  You might use pretty-print to figure out the data structure.
# Try using sys.stdin.readline() to read just one line and deduce its structure.
# eval(line) will turn the stringified dictionary into an actual dict data structure, from which you can use dictionary logic.
# 2. Use sys.stdin to read the Twitter data in streaming fashion, line-by-line.  It creates an iterator on lines.
# 4. We want fail-safe code.  (More on distributed fault tolerance later.)  Make sure your code doesn't bomb if it doesn't find a user_name in the line.
# 5. You can simply use the print function to generate output to send to the sort step.

# %%
import ast
import sys
filename = '/Users/petermin/sea18_ds4/class_lectures/week09-kojak1/01-docker-hadoop-hive/input.txt'
# s = open(filename, 'r').read()
# ast.literal_eval(s)
file = open(filename,"r")
users = []
for line in file:
#    users.append(eval(line)["id"])
    print(eval(line))
#eval(open(filename, 'r').read())
#users
# Out:
# {'contributors': None, 'truncated': False, 'text': 'RT @FAFSA: Tired of scanning tax documents to answer #FAFSA questions? Transfer tax data automatically: http://t.co/FEH37ZJ21b http://t.co/…', 'in_reply_to_status_id': None, 'id': 439025607897137152, 'favorite_count': 0, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'retweeted': False, 'coordinates': None, 'entities': {'symbols': [], 'user_mentions': [{'id': 188001904, 'indices': [3, 9], 'id_str': '188001904', 'screen_name': 'FAFSA', 'name': 'Federal Student Aid'}], 'hashtags': [{'indices': [53, 59], 'text': 'FAFSA'}], 'urls': [{'url': 'http://t.co/FEH37ZJ21b', 'indices': [104, 126], 'expanded_url': 'http://1.usa.gov/zMUDBi', 'display_url': '1.usa.gov/zMUDBi'}], 'media': [{'expanded_url': 'http://twitter.com/FAFSA/status/436615090444718080/photo/1', 'display_url': 'pic.twitter.com/0JKzvAFiQJ', 'url': 'http://t.co/0JKzvAFiQJ', 'media_url_https': 'https://pbs.twimg.com/media/Bg8rHINIYA
# ...
