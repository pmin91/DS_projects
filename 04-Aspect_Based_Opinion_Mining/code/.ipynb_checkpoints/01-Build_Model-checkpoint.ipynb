# %% [markdown]
# # 01 - Sentence Classification Model Building

# %% [markdown]
# # Parse & clearn labeled training data

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('../data/Restaurants_Train.xml')
root = tree.getroot()

# %%
# Use this dataframe for multilabel classification
# Must use scikitlearn's multilabel binarizer

labeled_reviews = []
for sentence in root.findall("sentence"):
    entry = {}
    aterms = []
    aspects = []
    if sentence.find("aspectTerms"):
        for aterm in sentence.find("aspectTerms").findall("aspectTerm"):
            aterms.append(aterm.get("term"))
    if sentence.find("aspectCategories"):
        for aspect in sentence.find("aspectCategories").findall("aspectCategory"):
            aspects.append(aspect.get("category"))
    entry["text"], entry["terms"], entry["aspects"]= sentence[0].text, aterms, aspects
    labeled_reviews.append(entry)
labeled_df = pd.DataFrame(labeled_reviews)
print("there are",len(labeled_reviews),"reviews in this training set")
#    print(sentence.find("aspectCategories").findall("aspectCategory").get("category"))

# %%
# Save annotated reviews
labeled_df.to_pickle("annotated_reviews_df.pkl")
labeled_df.head()

# %% [markdown]
# # Training the model with Naive Bayes
# 1. replace pronouns with neural coref
# 2. train the model with naive bayes

# %%
from neuralcoref import Coref
import en_core_web_lg
spacy = en_core_web_lg.load()
coref = Coref(nlp=spacy)

# Define function for replacing pronouns using neuralcoref
def replace_pronouns(text):
    coref.one_shot_coref(text)
    return coref.get_resolved_utterances()[0]
# Out:
# Loading neuralcoref model from /home/ubuntu/anaconda3/lib/python3.6/site-packages/neuralcoref/weights/
# Loading embeddings from /home/ubuntu/anaconda3/lib/python3.6/site-packages/neuralcoref/weights/static_word
# Loading embeddings from /home/ubuntu/anaconda3/lib/python3.6/site-packages/neuralcoref/weights/tuned_word

# %%
# Read annotated reviews df, which is the labeled dataset for training
# This is located in the pickled files folder
annotated_reviews_df = pd.read_pickle("../pickled_files/annotated_reviews_df.pkl")
annotated_reviews_df.head(3)
# Out:
#                            aspects                  terms  \
# 0                        [service]                [staff]
# 1  [food, anecdotes/miscellaneous]                 [food]
# 2                           [food]  [food, kitchen, menu]
#
#                                                 text
# 0               But the staff was so horrible to us.
# 1  To be completely fair, the only redeeming fact...
# 2  The food is uniformly exceptional, with a very...

# %%
# Create a new column for text whose pronouns have been replaced
annotated_reviews_df["text_pro"] = annotated_reviews_df.text.map(lambda x: replace_pronouns(x))

# %%
# uncomment below to pickle the new df
# annotated_reviews_df.to_pickle("annotated_reviews_df2.pkl")

# Read pickled file with replaced pronouns if it exists already
annotated_reviews_df = pd.read_pickle("annotated_reviews_df2.pkl")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# Convert the multi-labels into arrays
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(annotated_reviews_df.aspects)
X = annotated_reviews_df.text_pro

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0)

# save the the fitted binarizer labels
# This is important: it contains the how the multi-label was binarized, so you need to
# load this in the next folder in order to undo the transformation for the correct labels.
filename = 'mlb.pkl'
pickle.dump(mlb, open(filename, 'wb'))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from skmultilearn.problem_transform import LabelPowerset
import numpy as np

# LabelPowerset allows for multi-label classification
# Build a pipeline for multinomial naive bayes classification
text_clf = Pipeline([('vect', CountVectorizer(stop_words = "english",ngram_range=(1, 1))),
                     ('tfidf', TfidfTransformer(use_idf=False)),
                     ('clf', LabelPowerset(MultinomialNB(alpha=1e-1))),])
text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)

# Calculate accuracy
np.mean(predicted == y_test)
# Out:
# 0.866491458607096

# %%
# Test if SVM performs better
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf-svm', LabelPowerset(
                             SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, max_iter=6, random_state=42)))])
_ = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)

#Calculate accuracy
np.mean(predicted_svm == y_test)
# Out:
# 0.8538764783180026

# %%
import pickle
# Train naive bayes on full dataset and save model
text_clf = Pipeline([('vect', CountVectorizer(stop_words = "english",ngram_range=(1, 1))),
                     ('tfidf', TfidfTransformer(use_idf=False)),
                     ('clf', LabelPowerset(MultinomialNB(alpha=1e-1))),])
text_clf = text_clf.fit(X, y)

# save the model to disk
filename = 'naive_model1.pkl'
pickle.dump(text_clf, open(filename, 'wb'))

# %% [markdown]
# At this point, we can move on to 02-Sentiment analysis notebook, which will load the fitted Naive bayes model.

# %%
#mlb.inverse_transform(predicted)
pred_df = pd.DataFrame(
    {'text_pro': X_test,
     'pred_category': mlb.inverse_transform(predicted)
    })

# %%
pd.set_option('display.max_colwidth', -1)
pred_df.head()
# Out:
#                    pred_category                                                                                                                                                                                                                                                                                                                                 text_pro
# 453   (anecdotes/miscellaneous,)  It's better than being on the roof of Sutton Place with 19 year old interns jabbing you in the ribs all night.
# 1611  (ambience,)                 Don't expect to sit down inside though, there are only a few tables and they are always full.
# 2078  (anecdotes/miscellaneous,)  Again, if you are in this neighborhood - by all means, come here.
# 2715  (anecdotes/miscellaneous,)  Go there to relax and feel like your somewhere else.
# 2602  (service,)                  As far as the service goes, the waitresses were not particularly friendly, but the waitresses got the job done.
# 2793  (food,)                     Just stick with the small dishes!
# 2850  (ambience,)                 The atmosphere is nothing special, but the atmosphere feels like a Sushi establishment in Tokyo.
# 1184  (service,)                  But when you are seated the waitresses are great, the waitresses explain everything on the menu, and the price of the food is really cheap for the service you get.
# 2539  (food,)                     They had scrapped the bottom of the vessel in which they make the rice -RESULT - WE HAD LARGE CHUNKS OF BURNT RICE IN OUR SERVING BOWL.
# 2266  (anecdotes/miscellaneous,)  It is nearly impossible to get a table, so if you ever have the chance to go here for dinner, DO NOT pass the chance to go here for dinner up.
# 1717  (food,)                     But they've done a really nice job of offering all the typical pizzeria faves plus some terrific specials like the Godmother pizza (a sort of traditional flat pizza with an olive oil-brushed crust and less tomato sauce than usual).
# 2704  (food, price)               And affordable.
# 3020  (anecdotes/miscellaneous,)  You won't find that anywhere in Manhattan.
# 1436  (ambience,)                 We ate out in the back patio, which is worth it as it's cool and the music is hear well there.
# 1712  (service,)                  I could have drank 4 glasses of water and still been parched - so watch out.
# 2048  (anecdotes/miscellaneous,)  As soon as I wake up on a saturday or sunday it is the first thing on my mind is when and how I will be getting to fried dumpling.
# 463   (anecdotes/miscellaneous,)  Definitely not a restaurant to skip!
# 1059  (price,)                    The prices and ambience are especially great considering the prices's in the West Village.
# 1196  (anecdotes/miscellaneous,)  Price no more than a Jersey deli but way better.
# 988   (food,)                     And its absolutely DELICIOUS.
# 661   (food,)                     Raga stands out with an interesting fusion of French and Indian cooking.
# 1943  (anecdotes/miscellaneous,)  Should you happen to be impressed by the cuisine definitely try the cuisine.
# 751   (service,)                  Service is not exactly five star, but thats not really a big deal.
# 533   (anecdotes/miscellaneous,)  I have been to spice three times- twice during lunch and once at dinner.
# 2600  (service,)                  Despite the fact that the space is large, the space is large've overcrowded the floor with tables.
# 2484  (food,)                     We didn't get drink refills and she didn't even offer us the option of dessert.
# 1070  (anecdotes/miscellaneous,)  We were very surprised by how good the food was on our first visit here on a Sunday night.
# 156   (anecdotes/miscellaneous,)  Wondering who had the best deals we noticed a line had formed to wait for this one particular establishment.
# 1702  (food, price)               Great wine selection, Gigondas is worth the price, and the house champagne is a great value.
# 1852  (service,)                  The best part of the experience was knowing that the manager (a bubbly, friendly young woman with a great smile) truly cared about how we were doing.
# 2423  (food,)                     My husband and I enjoyed each of the 6 taste size portions and left completely full.
# 10    (anecdotes/miscellaneous,)  i've noticed megadeth, mr. scruff, st. germain, traditional vietnamese songs, black sabbath, jay-z, and daft punk all being played.
# 2100  (service,)                  Service is friendly, prices are good - delivery time was a little slow, but for the way this pizza tastes, I'm willing to overlook this pizza.
# 1287  (food,)                     Oh, and the complimentary pudding dessert was just enough- yummy!
# 3034  (anecdotes/miscellaneous,)  Better than the bagel shop on the corner, but not worth going out of your way for, in my opinion.
# 943   (anecdotes/miscellaneous,)  I usually go there later at night when I get off work so I don't have to deal with crowds or lines.
# 1656  (food,)                     The worst excuse for Japanese food I've ever encountered.
# 2208  (anecdotes/miscellaneous,)  A restaurant that doesn't try to do anything except serve great food with great service in a pleasant atmosphere.
# 2948  (service,)                  Our tiny table for two (dinner plates hung over edge) was right in the middle of one of the lanes of waiter traffic.
# 2857  (anecdotes/miscellaneous,)  If you live in Upper Manhattan, Siam Square is THE place for Thia food.
# 1675  (food,)                     I must say it's a little pricey for the food because it was not as spectacular as the view.
# 2892  (food, service)             The food was great and the service was even better.
# 938   (food,)                     The food is good, especially their more basic dishes, and the drinks are delicious.
# 1763  (anecdotes/miscellaneous,)  We had the most wonderful waitress.
# 2368  (anecdotes/miscellaneous,)  I complete the total bagel experience by having the total bagel experience lightly toasted.
# 2993  (anecdotes/miscellaneous,)  She lives nearby but had never gone to this establishment thinking that this establishment might be too touristy.
# 2663  (service,)                  My host asked for appetizers for the group and the waiter gave us not only what we ordered, but some other items that were not ordered.
# 1290  (anecdotes/miscellaneous,)  Knowledge of the chef and the waitress are below average.
# 2231  (anecdotes/miscellaneous,)  Would definitely go back again.
# 306   (anecdotes/miscellaneous,)  Went there last night for 2 year anniversery, and wasn't all that impressed.
# 2151  (food,)                     Great deal!
# 1005  (anecdotes/miscellaneous,)  Have frequented 'ino for several years and the food remains excellent.
# 169   (food,)                     A glass of Leaping Lizard, a glass of prosecco, and the mussels had everything happy.
# 1513  (service,)                  Ambience is delightful, service impeccable.
# 1396  (service,)                  sometimes i get good food and ok service.
# 710   (food,)                     Both the fresh mozzerella slices and the Plain Cheese slice are phenomenal.
# 2194  (food,)                     The dosas are skimpy, unattractive and drip with grease, and personally I'd drink popcorn topping before I'd eat another one of these.
# 2305  (anecdotes/miscellaneous,)  For an untrendy rip-off- eat here.
# 263   (anecdotes/miscellaneous,)  We picked it randomly, without a recommendation from someone who has been there, so we weren't sure what to expect.
# 2841  (food,)                     If you go here - your focus should be the Tamarind Margaritas.
# 1282  (food,)                     Got club soda, filled with ice, no lime.
# 841   (food,)                     I was pretty much full after our fondue appetizer.
# 2475  (service,)                  Nice ambiance, nice little bar, good bartender, Francois, and good service.
# 1593  (service,)                  Good, fast service.
# 1460  (anecdotes/miscellaneous,)  The quality of food at this restaurant accompanied  by fantastic live jazz makes this place a perfect 10!
# 775   (service,)                  I had to share my table with a loud group of kids and the service was rude an unattentive.
# 1535  (service,)                  Great staff.
# 195   (food,)                     The fish is fresh but the variety of fish is nothing out of ordinary.
# 2810  (anecdotes/miscellaneous,)  Good food at the restaurant (a bit expensive, but great if you want to impress your date).
# 981   (anecdotes/miscellaneous,)  I would definently recommend this restaurant.
# 1875  (anecdotes/miscellaneous,)  The music is the best among all the Indian restaurants I have visited.
# 683   (ambience,)                 It's also attached to Angel's Share, which is a cool, more romantic bar...
# 2030  (anecdotes/miscellaneous,)  However, go for the ambience, and consider the food just a companion for a trip across the world!
# 2402  (food,)                     Try sushimi cucumber roll.
# 1979  (anecdotes/miscellaneous,)  I can't wait for the nex time.
# 1955  (food,)                     - i asked for them spicy and they were delicious).
# 104   (ambience, food, service)   The atmosphere is unheralded, the service impecible, and the food magnificant.
# 1612  (service,)                  The staff is accomodating, the ambiance is exciting and yet relaxed, and the food is out of this world!
# 2592  (anecdotes/miscellaneous,)  I went there for lunch and it was not as good as I expected from the reviews I read.
# 1370  (service,)                  Great food, great lay out and awesome service.
# 1065  (anecdotes/miscellaneous,)  Went here on a friend's reccomendation.
# 2316  (service,)                  The service is descent even when this small place is packed.
# 1458  (food,)                     Please save yourself the frustration.
# 2666  (food, price)               Slightly on the pricey side but worth it!
# 22    (anecdotes/miscellaneous,)  We were very disappointed.
# 2210  (anecdotes/miscellaneous,)  Well, this place is so Ghetto this place not even funny.
# 910   (anecdotes/miscellaneous,)  But don't ever order bacon late at nite (either platter or in sandwiches, for that matter don't from any take out place) as it is from the morning frying turns out hard almost like bacos, hurt my molars.
# 2044  (anecdotes/miscellaneous,)  Unbelievable.
# 2134  (service,)                  So rude.
# 2705  (anecdotes/miscellaneous,)  The staff makes you feel at home, the food is great and the atmosphere is WONDERFUL!
# 1450  (food, price)               Not worth the prices.
# 1448  (anecdotes/miscellaneous,)  Once for dinner and once for brunch.
# 30    (anecdotes/miscellaneous,)  Will not be back.
# 1649  (anecdotes/miscellaneous,)  I go twice a month!
# 898   (food,)                     The dim sum servings here are a bit larger than I'm used to.
# 937   (anecdotes/miscellaneous,)  Never once did I leave feeling unwelcome or impressed.
# 2398  (food, price)               The only fallback on this restaurant is the prices.
# 743   (anecdotes/miscellaneous,)  if this happens, just ask for real naan.
# 1269  (ambience,)                 Of course, it is crowded but who cares.
# 2758  (ambience,)                 It's a nice place to relax and have conversation.
# 977   (service,)                  There is also very limited seating and there can be a substantial wait in getting food at peak times.
# 1013  (anecdotes/miscellaneous,)  It's a shame that a nice, convenient place like the Pink Pony can be so ruined by lousy service.
# 1573  (anecdotes/miscellaneous,)  I don't live in NY but my best friend does.
# 1377  (anecdotes/miscellaneous,)  (Besides that there should be more restaurants like it around the city).
# 1654  (food, price)               The dim sum is delectable while the prices are quite easy on the wallet.
# 712   (anecdotes/miscellaneous,)  The food is terrible and overall, I would have to say avoid at all costs.
# 672   (anecdotes/miscellaneous,)  Probably much busier for lunch, it's seldom crowded for dinner (too close to downtown).
# 2077  (anecdotes/miscellaneous,)  I'd definitely recommend this little place.
# 1302  (anecdotes/miscellaneous,)  If you want a casual neighborhood bistro that has great food and excellent service, this is the place.
# 295   (food,)                     Everything we had was pretty good, but we have only been there once.
# 2302  (food,)                     The menu consisted of standard brassiere food, better then places like Balthazar etc.
# 692   (anecdotes/miscellaneous,)  We've only eaten in the restaurant once, but we have ordered many times for dinner.
# 385   (food,)                     They are tasty, but I suggest only eating one with meat because they tend not to mesh that well with the average American digestive system.
# 1884  (service,)                  The kitchen however, is almost always slow.
# 316   (anecdotes/miscellaneous,)  I'll keep this short.
# 867   (food,)                     Meat dishes now adorn the selections, although there's still a large number of vegetarian-friendly choices.
# 311   (anecdotes/miscellaneous,)  Suan was a recommendation that I am glad we heeded.
# 2479  (anecdotes/miscellaneous,)  For some reason the place was empty when we got in and remained so for the entire evening, I don't understand why but we had a blast and will definately go back the next time we are in the area.
# 599   (anecdotes/miscellaneous,)  For $760 for 2 people, it's a once in a lifetime experience.
# 2306  (anecdotes/miscellaneous,)  And you're hungry a few hours later.
# 2957  (anecdotes/miscellaneous,)  This is a true gem of the village.
# 118   (food,)                     However, it is jus too good to not praise it.
# 1049  (anecdotes/miscellaneous,)  They pray to their Food Gods to make them into a good pizza like VT's.
# 3005  (food,)                     Get the soup and a nosh (pastrami sandwich) for $8 and you're golden.
# 2360  (service,)                  The owners and employees are friendly and their pizza is fantastic.
# 530   (anecdotes/miscellaneous,)  The New York Times has reviewed this place three times already, you know it's going to be good.
# 2750  (service,)                  They're rude at times, and not very friendly.
# 1355  (anecdotes/miscellaneous,)  first it took us a long time to find the place.
# 1100  (anecdotes/miscellaneous,)  Just go and see for yourself.
# 838   (food,)                     You can also special order any kind of dumpling,etc.
# 1761  (anecdotes/miscellaneous,)  Rao is a good restaurant, but it's nothing special.
# ...
# 188   (ambience,)                 The atmosphere was crowded but the atmosphere was a great bistro-type vibe.
# 1423  (service,)                  While we enjoyed the food, we were highly disappointed by the poor service (waiter was not quite competent and SLOW service) and lack of remorse.
# 2312  (service,)                  The service is always bad though, don't expect much of anything from your server, and I would not recommend bringing a date here either.
# 2430  (food, price)               The food was boring and expensive.
# 1190  (food, service)             Go to Volare for 1st class service and terrific food.
# 2643  (service,)                  Turned out there was full service upstairs and sat down.
# 2125  (anecdotes/miscellaneous,)  I read the other review and have to say I had the opposite experience here last Sunday.
# 1127  (food, price)               The food is great and the food have a good selecion of wines at reasonable prices.
# 723   (food,)                     The large selection of bruschettas, paninis, tramezzinis keep the palate from stagnating.
# 2116  (anecdotes/miscellaneous,)  Kudos to Po!
# 1151  (food,)                     Over 100 different choices to create your own.
# 1138  (food,)                     My friend's food was also the complete opposite of what my friend's food's supposed to taste like (aND look like).
# 1379  (service,)                  The waitstaff are all very busy, the waitstaff's not outstanding service, but I've never been dealt with rudely.
# 2178  (anecdotes/miscellaneous,)  We went to eat at the Jekyll and Hyde restaurant on Friday night and really enjoyed the fun atmosphere and good food.
# 597   (anecdotes/miscellaneous,)  We parked on the block of Nina's the place looked nice, with people obviously enjoying people pizzas.
# 314   (ambience,)                 It is set far from the small street it's on, and there is no traffic noise.
# 1014  (anecdotes/miscellaneous,)  This is the first time Citysearch did't call it right.
# 37    (food, price)               Great food at REASONABLE prices, makes for an evening that can't be beat!
# 425   (anecdotes/miscellaneous,)  This tiny Williamsburg spot is always pleasantly surprising.
# 2166  (anecdotes/miscellaneous,)  We do not need to go to a four-star restaurant anymore.
# 2831  (anecdotes/miscellaneous,)  We ate at this Thai place following the reviews but very unhappy with the foods.
# 1530  (anecdotes/miscellaneous,)  I am relatively new to the area and tried Pick a bgel on 2nd and was disappointed with the service and I thought the food was overated and on the pricey side.
# 779   (food,)                     The sauce on the pizza is sooo good with garlic and fresh tomatoes and garlic don't skimp.
# 783   (food,)                     The food is usually good but the food certainly isn't a relaxing place to go.
# 2013  (anecdotes/miscellaneous,)  The aesthetics of this place are like an airport lounge.
# 299   (anecdotes/miscellaneous,)  I would highly recommend.
# 443   (anecdotes/miscellaneous,)  We visited Bread Bar during January restaurant week and were so pleased with the menu selections and service.
# 1560  (service,)                  And the staff is also young, energeic and hot!!!!
# 2963  (service,)                  Service was on par but not wonderful.
# 596   (anecdotes/miscellaneous,)  Went here last night and had a pleasant experience.
# 2507  (anecdotes/miscellaneous,)  Joe's Pizza used to have the best slice until this pizzeria opened up.
# 896   (anecdotes/miscellaneous,)  Ciao Bella
# 1081  (anecdotes/miscellaneous,)  The owner is very friendly and a great guy, go try the owner pizza, you'll like his pizza!
# 1680  (food,)                     My wife had the fried shrimp which are huge and loved it.
# 667   (food,)                     The food options rule.
# 1180  (anecdotes/miscellaneous,)  I didn't complain, I liked the atmosphere so much.
# 1467  (service,)                  Service and food is what any one would expect when spending that type of money.
# 546   (service,)                  The ambience was nice, but service wasn't so great.
# 1548  (food,)                     it is not consistent.
# 1903  (anecdotes/miscellaneous,)  Its worth the wait though.
# 2262  (anecdotes/miscellaneous,)  Saul is pretty good, but definitely not great.
# 666   (food,)                     The food was very good, a great deal, and the place the food self was great.
# 2441  (food, service)             The vibe is very relaxed and cozy, service was great and the food was excellent!
# 1140  (anecdotes/miscellaneous,)  I would like to return and try some of the other menu items when I don't have to rush off to a show.
#
# [761 rows x 2 columns]

# %% [markdown]
# ## Some scrap code below which wasn't used

# %%
# Save annotated reviews
labeled_df.to_pickle("annotated_reviews_df.pkl")
labeled_df.head()

# %%
# This code was for parsing out terms & their relations to aspects
# However, the terms were not always hyponyms of the aspects, so they were unusable
aspects = {"food":[],"service":[],"anecdotes/miscellaneous":[], "ambience":[], "price":[]}
for i in range(len(labeled_df)):
    if len(labeled_df.aspects[i]) == 1:
        if labeled_df.terms[i] != []:
            for terms in labeled_df.terms[i]:
                aspects[labeled_df.aspects[i][0]].append(terms.lower())
for key in aspects:
    aspects[key] = list(set(aspects[key]))

# %%
terms = []
for i in labeled_df.terms:
    for j in i:
        if j not in terms:
            terms.append(j)
print("there are", len(terms),"unique terms")

# %%
# Use this dataframe if doing the classifications separately as binary classifications
labeled_reviews2 = []
for sentence in root.findall("sentence"):
    entry = {"food":0,"service":0,"anecdotes/miscellaneous":0, "ambience":0, "price":0}
    aterms = []
    aspects = []
    if sentence.find("aspectTerms"):
        for aterm in sentence.find("aspectTerms").findall("aspectTerm"):
            aterms.append(aterm.get("term"))
    if sentence.find("aspectCategories"):
        for aspect in sentence.find("aspectCategories").findall("aspectCategory"):
            if aspect.get("category") in entry.keys():
                entry[aspect.get("category")] = 1
    entry["text"], entry["terms"] = sentence[0].text, aterms
    labeled_reviews2.append(entry)
labeled_df2 = pd.DataFrame(labeled_reviews2)
#    print(sentence.find("aspectCategories").findall("aspectCategory").get("category"))

# %%
labeled_df2.iloc[:,:5].sum()
