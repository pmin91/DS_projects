# %%
#from pymongo import MongoClient
import pandas as pd
#client = MongoClient()
# db = client.my_cool_database

# db.collection_names()
# col = db.my_cool_collection

# %%
yelp = pd.read_csv("yelp_review.csv")[["review_id","business_id","date","text"]]

# %%
yelp_business = pd.read_csv("yelp_business.csv")

# %%
restaurants = yelp_business[yelp_business.categories.str.contains("Restaurants")]

# %%
# List cities by # of restaurants
restaurants.city.value_counts()[:6]
# Out:
# Toronto       7148
# Las Vegas     5899
# Phoenix       3647
# Montréal      3332
# Charlotte     2460
# Pittsburgh    2207
# Name: city, dtype: int64

# %%
# save pittsburgh restaurants
yelp_pitt = restaurants[restaurants.city == "Pittsburgh"]

# %%
yelp_pitt.sort_values("review_count",ascending=False)
# Out:
#                    business_id                                name  \
# 130495  JLbgvGM4FXh9zNP4O5ZWjQ                   "Meat & Potatoes"
# 36476   u4sTiCzVeIHZY8OlaL346Q         "Gaucho Parrilla Argentina"
# 26943   lKom12WnYEjH5FFemK3M1Q                    "Primanti Bros."
# 81979   ejaUQ1hYo7Q7xCL1HdPINw                 "Church Brew Works"
# 15487   dLc1d1zwd1Teu2QED5TmlA                        "Noodlehead"
# 174433  woXlprCuowrLJswWere3TQ                              "täkō"
# 7282    SmkYLXEYhzwUZdS6TAevHg               "Butcher and the Rye"
# 3182    LQFmktF43j2NPncKdNd9mg                  "Fat Heads Saloon"
# 76284   sMzNLdhJZGzYirIWt-fMAg                    "Sienna Mercato"
# 52209   w_UCGMgok7N9p0XdYBx1VQ                     "Primanti Bros"
# 135266  d2ZQRjuizstCTnicysmpMQ                            "Eleven"
# 45524   wmCBxE0PfLZD8sxIwAY59Q            "Hofbrauhaus Pittsburgh"
# 38680   Ul6JwluSTm12PVDIqnNaTg                              "Kaya"
# 95752   xcmmTXhuMx2fZF2Bt69F4w                 "Point Brugge Café"
# 134370  Eg_M8eeu9SDEdbP7iUmVbQ             "The Porch at Schenley"
# 57136   hcFSc0OHgZJybnjQBrL_8Q                  "Everyday Noodles"
# 108702  oeW0vIYd3rUnAPgmD4fEFg                    "Deluca's Diner"
# 169162  NoF90rswXBHESSyDaWeKKA      "Proper Brick Oven & Tap Room"
# 54010   0PCBt3JKD6IooicImKNBzA              "Nicky's Thai Kitchen"
# 164153  -7H-oXvCxJzuT42ky6Db0g             "Industry Public House"
# 92001   Voeq7aGDmCGMjE_SQiHwRA                       "Bakersfield"
# 142360  j3IEZP4nQAt7fkxmerLMbA   "Winghart's Burger & Whiskey Bar"
# 26738   _R1jBQQieKpNGMBqmrLRyA                              "NOLA"
# 36696   K-SsrPH0nFExdpLrTo1X1w                         "Burgatory"
# 117710  sc__kdcFV4IcNTfBx1707w              "P&G's Pamela's Diner"
# 52698   KTPRYqiFdLowAUEAnN7e3g                         "Burgatory"
# 89534   wjLgM9Ybe5shoUPRrGMmsQ                         "Coca Cafe"
# 160342  u7CxxEzx8hvjoJ8onN4zTg  "Pittsburgh International Airport"
# 7016    i39--wZD6L9hm9Lg90Uziw            "Central Diner & Grille"
# 116265  e2ng0CQ69anIawqIKzhtlg               "Smiling Banana Leaf"
# ...                        ...                                 ...
# 29064   VRMNW1GXYihRxEnr1UI8hA                     "Boston Market"
# 117270  6zm33qiJAMtjMSXGlfIFKA                 "Bella Donne Pizza"
# 35818   IBSOhov5GLSZsGzz3ZsQjg                     "Boston Market"
# 58278   wSwkjQXQsWLQHa6AvFr_RQ                      "Sparta Gyros"
# 35846   KNvqTNhpCq7Sshqzykx9QQ          "Folino Brothers Pizzeria"
# 57000   2VnPnlU4pH-3TyFf436Wzg                   "LaNova Pizzaria"
# 83693   6hLFmFmDKO39b9qsyeVx-A                    "The Lexus Club"
# 84195   mPR5tFpraetedNPDACwn4A                         "McDonalds"
# 84517   d1-X_lnO4e00Xso0LF9Zgw                "Long John Silver's"
# 102996  KcFfciiA1lmui6r_h5OwTg                      "Steve's Deli"
# 35159   Q1WoqmmvoyWC3b6esLNyCQ                            "Arby's"
# 80928   3ybsKWA03f16v4OPC0jApg                  "Wings & a Prayer"
# 63059   GwcWB_uDN6ppuk_V8x7iww              "Nicky's Grant Street"
# 65222   OaDijC3QRwxw9uTadyWIsw                       "Mexico City"
# 114661  cxCxWI097kFvORVhCLd6kw                           "Wendy's"
# 81270   t6LKeb5gNSeqri1JqOPZow                            "Subway"
# 115874  b2ZukyGCS7xDlv0ZAlXdYg           "Alida's Woodfire Cucina"
# 143873  e0Vvrs1M-oMhNBg_8uc6ZQ                  "Verde Good Beans"
# 32249   QaFhHwtJf64AZIzqAujFxw           "Joe & Pie Cafe Pizzeria"
# 34504   -RxzvvyKBOPOzeTvagqEfg                        "McDonald's"
# 62672   wMCKPvpwktDF8mTlwcr23g                     "Penny's Diner"
# 76260   qvwf01a-p26UBkrE5k-gDg                "Nancy's Restaurant"
# 62637   UzCZyYj511zKERJEpEk7-w                 "Papa John's Pizza"
# 34746   vVz2o24e17PuQtHJOkHPfA                    "Brown Bag Deli"
# 62408   6ObhHav156dwof2qHvUj3g                            "Subway"
# 70512   _4l36Tgbmoroh3udeXU-JA                            "Arby's"
# 117083  rn0GU0mB6LYakXiky7JqLA                     "Palate Bistro"
# 61624   XQjigVIJSnsXXUP1igIeEw                     "Bomonti Pizza"
# 61492   JGXkldESnG69YXlSNVAgJQ                          "Eggheads"
# 4443    RhXKTksPWch75Bo1lpoLqQ                         "Taco Bell"
#
#           neighborhood                   address        city state  \
# 130495        Downtown            "649 Penn Ave"  Pittsburgh    PA
# 36476   Strip District           "1601 Penn Ave"  Pittsburgh    PA
# 26943   Strip District              "46 18th St"  Pittsburgh    PA
# 81979    Lawrenceville        "3525 Liberty Ave"  Pittsburgh    PA
# 15487        Shadyside      "242 S Highland Ave"  Pittsburgh    PA
# 174433        Downtown              "214 6th St"  Pittsburgh    PA
# 7282          Downtown              "212 6th St"  Pittsburgh    PA
# 3182        South Side        "1805 E Carson St"  Pittsburgh    PA
# 76284         Downtown            "942 Penn Ave"  Pittsburgh    PA
# 52209         Downtown           "2 S Market Sq"  Pittsburgh    PA
# 135266  Strip District        "1150 Smallman St"  Pittsburgh    PA
# 45524       South Side         "2705 S Water St"  Pittsburgh    PA
# 38680   Strip District        "2000 Smallman St"  Pittsburgh    PA
# 95752     Point Breeze         "401 Hastings St"  Pittsburgh    PA
# 134370         Oakland         "221 Schenley Dr"  Pittsburgh    PA
# 57136    Squirrel Hill         "5875 Forbes Ave"  Pittsburgh    PA
# 108702  Strip District           "2015 Penn Ave"  Pittsburgh    PA
# 169162        Downtown              "139 7th St"  Pittsburgh    PA
# 54010         Downtown            "903 Penn Ave"  Pittsburgh    PA
# 164153   Lawrenceville          "4305 Butler St"  Pittsburgh    PA
# 92001         Downtown            "940 Penn Ave"  Pittsburgh    PA
# 142360        Downtown             "5 Market Sq"  Pittsburgh    PA
# 26738         Downtown            "24 Market Sq"  Pittsburgh    PA
# 36696              NaN          "300 Mcholme Dr"  Pittsburgh    PA
# 117710  Strip District              "60 21st St"  Pittsburgh    PA
# 52698              NaN         "932 Freeport Rd"  Pittsburgh    PA
# 89534    Lawrenceville          "3811 Butler St"  Pittsburgh    PA
# 160342             NaN       "1000 Airport Blvd"  Pittsburgh    PA
# 7016               NaN  "6408 Steubenville Pike"  Pittsburgh    PA
# 116265   Highland Park          "5901 Bryant St"  Pittsburgh    PA
# ...                ...                       ...         ...   ...
# 29064              NaN      "1736 Washington Rd"  Pittsburgh    PA
# 117270             NaN           "461 Perry Hwy"  Pittsburgh    PA
# 35818              NaN        "98 Clairton Blvd"  Pittsburgh    PA
# 58278              NaN     "5843 Brownsville Rd"  Pittsburgh    PA
# 35846              NaN         "373 Vanadium Rd"  Pittsburgh    PA
# 57000       Sharpsburg     "1100 North Canal St"  Pittsburgh    PA
# 83693         Downtown            "1001 5th Ave"  Pittsburgh    PA
# 84195              NaN        "2925 Freeport Rd"  Pittsburgh    PA
# 84517              NaN      "807 W View Park Dr"  Pittsburgh    PA
# 102996  Strip District           "2401 Penn Ave"  Pittsburgh    PA
# 35159         West End      "2251 Noblestown Rd"  Pittsburgh    PA
# 80928              NaN          "7543 Roslyn St"  Pittsburgh    PA
# 63059         Downtown   "310 Grant St, Ste 100"  Pittsburgh    PA
# 65222       South Side        "2212 E Carson St"  Pittsburgh    PA
# 114661        Downtown         "502 Liberty Ave"  Pittsburgh    PA
# 81270              NaN     "11667 Penn Hills Dr"  Pittsburgh    PA
# 115874   Lawrenceville  "3345 Penn Ave, Ste 200"  Pittsburgh    PA
# 143873        Downtown           "412 First Ave"  Pittsburgh    PA
# 32249              NaN   "5474 Campbells Run Rd"  Pittsburgh    PA
# 34504              NaN          "100 Davis Blvd"  Pittsburgh    PA
# 62672       South Side        "1715 E Carson St"  Pittsburgh    PA
# 76260              NaN           "616 South Ave"  Pittsburgh    PA
# 62637              NaN     "4050 Brownsville Rd"  Pittsburgh    PA
# 34746         Downtown          "817 Forbes Ave"  Pittsburgh    PA
# 62408     Point Breeze           "7700 Penn Ave"  Pittsburgh    PA
# 70512         Downtown             "604 Wood St"  Pittsburgh    PA
# 117083        Downtown              "212 6th St"  Pittsburgh    PA
# 61624              NaN         "51 Crennell Ave"  Pittsburgh    PA
# 61492        Brookline     "1162 Brookline Blvd"  Pittsburgh    PA
# 4443               NaN       "9797 Mcknight Rd."  Pittsburgh    PA
#
#        postal_code   latitude  longitude  stars  review_count  is_open  \
# 130495       15222  40.443145 -80.001104    4.0          1476        1
# 36476        15222  40.449043 -79.987573    4.5          1267        1
# 26943        15222  40.450706 -79.985588    3.5          1101        1
# 81979        15201  40.462241 -79.964393    3.5           902        1
# 15487        15206  40.457748 -79.925494    4.5           820        1
# 174433       15222  40.442229 -80.001985    4.5           806        1
# 7282         15222  40.442334 -80.002066    4.5           677        1
# 3182         15203  40.428967 -79.980176    4.0           657        1
# 76284        15222  40.443950 -79.996437    4.0           632        1
# 52209        15222  40.440287 -80.002585    3.5           604        1
# 135266       15222  40.446002 -79.993500    4.0           572        1
# 45524        15203  40.428768 -79.964499    4.0           561        1
# 38680        15222  40.451655 -79.984218    4.0           546        1
# 95752        15206  40.450042 -79.913901    4.5           514        1
# 134370       15213  40.442777 -79.953151    3.5           509        1
# 57136        15217  40.438262 -79.920082    4.0           504        1
# 108702       15222  40.451543 -79.983726    4.0           490        1
# 169162       15222  40.443599 -80.000345    4.5           471        1
# 54010        15222  40.443983 -79.998256    4.0           469        1
# 164153       15201  40.470783 -79.960250    3.5           466        1
# 92001        15222  40.444065 -79.996632    4.0           457        1
# 142360       15222  40.440093 -80.002446    4.0           452        1
# 26738        15222  40.441184 -80.003046    3.5           439        1
# 36696        15275  40.448994 -80.174356    4.0           434        1
# 117710       15222  40.451971 -79.983657    4.5           433        1
# 52698        15238  40.489444 -79.892937    4.0           432        1
# 89534        15201  40.467229 -79.964203    3.5           422        1
# 160342       15231  40.495902 -80.241711    3.5           412        1
# 7016         15205  40.448699 -80.156811    4.0           406        1
# 116265       15206  40.475888 -79.919564    4.0           404        1
# ...            ...        ...        ...    ...           ...      ...
# 29064        15241  40.347540 -80.054769    4.5             3        0
# 117270       15229  40.520305 -80.032862    2.5             3        0
# 35818        15236  40.338788 -79.961031    3.5             3        0
# 58278        15236  40.327492 -79.986435    4.0             3        1
# 35846        15243  40.368864 -80.084901    4.0             3        0
# 57000        15215  40.495106 -79.930945    3.5             3        1
# 83693        15219  40.439593 -79.988935    3.0             3        1
# 84195        15238  40.486989 -79.889898    2.5             3        1
# 84517        15229  40.517137 -80.032211    1.0             3        0
# 102996       15222  40.453845 -79.980478    4.5             3        0
# 35159        15205  40.428509 -80.053100    3.5             3        1
# 80928        15218  40.420168 -79.884814    5.0             3        1
# 63059        15219  40.437485 -79.997584    3.5             3        1
# 65222        15203  40.428263 -79.973962    3.5             3        0
# 114661       15222  40.441321 -80.003363    3.5             3        0
# 81270        15235  40.465502 -79.826849    4.5             3        1
# 115874       15201  40.462642 -79.967718    4.0             3        1
# 143873       15219  40.437007 -80.000014    4.5             3        0
# 32249        15205  40.446206 -80.158020    1.5             3        1
# 34504        15275  40.449219 -80.173085    2.5             3        1
# 62672        15203  40.429090 -79.981298    3.5             3        0
# 76260        15221  40.442176 -79.886247    3.5             3        0
# 62637        15227  40.366578 -79.981471    3.5             3        0
# 34746        15219  40.439063 -79.992686    3.5             3        0
# 62408        15221  40.446355 -79.893766    2.5             3        1
# 70512        15222  40.442171 -79.999000    1.5             3        0
# 117083       15222  40.442334 -80.002066    3.0             3        0
# 61624        15205  40.436242 -80.069322    4.5             3        1
# 61492        15226  40.391881 -80.013367    2.0             3        1
# 4443         15237  40.585511 -80.036706    2.5             3        1
#
#                                                categories
# 130495  Specialty Food;Steakhouses;Meat Shops;American...
# 36476        Argentine;Seafood;Restaurants;Latin American
# 26943   Nightlife;American (New);Bars;Sports Bars;Sand...
# 81979   Food;Bars;Restaurants;Nightlife;American (Trad...
# 15487                            Restaurants;Noodles;Thai
# 174433                 Mexican;American (New);Restaurants
# 7282    Nightlife;Bars;Restaurants;Cocktail Bars;Butch...
# 3182    Restaurants;Bars;Nightlife;American (Traditional)
# 76284   Cocktail Bars;American (New);Nightlife;Italian...
# 52209   Sandwiches;American (New);Nightlife;Restaurant...
# 135266                         Restaurants;American (New)
# 45524   Pubs;Bars;Restaurants;German;Food;Breweries;Ni...
# 38680   Latin American;Nightlife;Restaurants;Caribbean...
# 95752                   Belgian;French;German;Restaurants
# 134370      Sandwiches;American (New);Burgers;Restaurants
# 57136              Noodles;Vegetarian;Restaurants;Chinese
# 108702                     Breakfast & Brunch;Restaurants
# 169162  Restaurants;Pizza;Nightlife;Beer;Wine & Spirit...
# 54010        Food;Seafood;Thai;Restaurants;Desserts;Vegan
# 164153  Restaurants;American (New);Bars;Nightlife;Cock...
# 92001   American (New);Cocktail Bars;Bars;Restaurants;...
# 142360  Burgers;Nightlife;Restaurants;Pizza;Bars;Food;...
# 26738                            Cajun/Creole;Restaurants
# 36696                                 Restaurants;Burgers
# 117710              Breakfast & Brunch;Restaurants;Diners
# 52698   Restaurants;Burgers;Nightlife;Cocktail Bars;Am...
# 89534   Food;Breakfast & Brunch;Coffee & Tea;American ...
# 160342     Fast Food;Restaurants;Airports;Hotels & Travel
# 7016            Restaurants;American (Traditional);Diners
# 116265                         Restaurants;Thai;Taiwanese
# ...                                                   ...
# 29064   Caterers;American (Traditional);Comfort Food;E...
# 117270                                  Restaurants;Pizza
# 35818   Restaurants;Comfort Food;American (Traditional...
# 58278                                   Restaurants;Greek
# 35846                           Pizza;Italian;Restaurants
# 57000       Pizza;Food;Food Delivery Services;Restaurants
# 83693   Restaurants;Venues & Event Spaces;American (Ne...
# 84195                               Fast Food;Restaurants
# 84517                               Fast Food;Restaurants
# 102996           Food Stands;Sandwiches;Restaurants;Delis
# 35159                    Restaurants;Sandwiches;Fast Food
# 80928   Barbeque;Comfort Food;Sandwiches;Restaurants;S...
# 63059   Restaurants;Diners;Breakfast & Brunch;American...
# 65222                                 Restaurants;Mexican
# 114661                      Restaurants;Burgers;Fast Food
# 81270                    Sandwiches;Fast Food;Restaurants
# 115874                          Pizza;Restaurants;Italian
# 143873  Restaurants;Cafes;Sandwiches;Salad;Coffee & Te...
# 32249        Breakfast & Brunch;Pizza;Restaurants;Burgers
# 34504                       Burgers;Fast Food;Restaurants
# 62672                                  Restaurants;Diners
# 76260   Restaurants;American (Traditional);Breakfast &...
# 62637                                   Pizza;Restaurants
# 34746   Cafes;Food;Food Delivery Services;Sandwiches;R...
# 62408              Fast Food;Sandwiches;Restaurants;Pizza
# 70512     Fast Food;American (New);Sandwiches;Restaurants
# 117083                                 French;Restaurants
# 61624                  Salad;Sandwiches;Pizza;Restaurants
# 61492   Restaurants;American (Traditional);Bars;Nightlife
# 4443                Fast Food;Restaurants;Mexican;Tex-Mex
#
# [2207 rows x 13 columns]

# %%
pitt_merge = yelp_pitt.merge(yelp,on="business_id",how="inner")
# save pittsburgh restaurants
pitt_merge.to_pickle("yelp_pitt.pkl")

# %%
pitt = pd.read_pickle("yelp_pitt.pkl")

# %%
pitt = pitt_merge.drop(["neighborhood","address","city","state",
                        "postal_code","latitude","longitude"],1)

# %%
meat_potatoes = pitt[pitt.name=='"Meat & Potatoes"']

# %%
meat_reviews = meat_potatoes.reset_index().text

# %%
counter=0
for rev in meat_reviews:
    if "pittsburghers" in rev.lower():
        print(counter)
    counter+=1
# Out:
# 1048

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
import numpy as np
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                ngram_range=(1,3),
                                max_features=1000,
                                stop_words='english')
tf = tf_vectorizer.fit_transform(meat_reviews[:1000])
n_components = 5
lda = LatentDirichletAllocation(n_components=n_components, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
lda.fit(tf)

vocab = tf_vectorizer.get_feature_names()

# %%
for topic in range(n_components):
    print(f"TOPIC {topic}")
    for j in np.argsort(-lda.components_,1)[topic,:5]:
        print(vocab[j])
    print()
# Out:
# TOPIC 0
# pork
# good
# fried
# ordered
# like
#
# TOPIC 1
# great
# food
# brunch
# bar
# place
#
# TOPIC 2
# good
# food
# meat
# place
# potatoes
#
# TOPIC 3
# restaurant
# place
# food
# steak
# service
#
# TOPIC 4
# good
# rude
# don
# food
# meat

# %% [markdown]
# # import opinion lexicon

# %%
neg_file = open("/Users/petermin/metis/04-fletcher/opinion-lexicon-English/neg_words.txt",encoding = "ISO-8859-1")
pos_file = open("/Users/petermin/metis/04-fletcher/opinion-lexicon-English/pos_words.txt",encoding = "ISO-8859-1")
neg = [line.strip() for line in neg_file.readlines()]
pos = [line.strip() for line in pos_file.readlines()]
opinion_words = neg + pos

# %%
print(len(pos),len(neg),len(opinion_words))
# Out:
# 2007 4783 6790

# %% [markdown]
# # Spacy Dependency Parser Approach

# %%
import spacy 
nlp = spacy.load("en")
# import en_core_web_sm
# nlp = en_core_web_sm.load()

# %%
review1 = nlp(meat_reviews[4])

# %%
review1
# Out:
# Been itching to try this place out for a long time now but I always have a huge party and waited too late to make the reservation.
# This place is small and pretty tight but since we had a larger party, we got a private room! It's dimly lit and very hipster.
# We got fries and wings as appetizers and they were both amazing. Wings weren't too hot and I've never had better fries in my life!
# I personally got the three little piggy sandwich and it was the best out of everyone else's meal. It's more like a yummy breakfast sandwich with s runny egg, thick cut bacon, and ham. It also came with fries. I loved it!
# The others at my table got a variety of different items. Two people got the shortbreads and two others got sandwiches. Everything looked amazing. If I were in the mood for this type of food, I would go back!

# %%
from spacy import displacy
test = "I did not like the service."
test = "it just feels really good to drink here. "
#test2 = "the service was good. it was bad"
test1 = nlp(test)
for token in test1:
#    if token.text in opinion_words:
    if token.dep_ == "nsubj":
        for child in token.head.children:
            if 
            print(child,child.dep_)
#        print(token.head.children)
#    print(token.text,token.pos_,token.head,token.dep_, token.lemma_)
displacy.render(test1, style='dep',jupyter=True)
# Out:
#   File "<ipython-input-522-341b440a95cb>", line 10
#     if
#        ^
# SyntaxError: invalid syntax

# %%
from spacy import displacy
from collections import defaultdict
test = "It's more like a yummy breakfast sandwich with s runny egg, thick cut bacon, and ham. It also came with fries. I loved it!"
sentence = nlp(test)
# can create a dictionary with 5 categories: food, service, etc.

sent_dict = defaultdict(int)
#for sentence
#sentiment = 0
for token in sentence:
#    print(token.text,token.dep_, token.head, token.head.dep_)
    #check if the word is an opinion word, then assign sentiment
    if token.text in opinion_words:
        sentiment = 1 if token.text in pos else -1
        
        # if target is a adj modifier (i.e. pretty, highly, etc.)
        # but happens to be an opinion word, ignore and pass
        if (token.dep_ == "advmod") or (token.dep_ == "amod"):
            continue
        #if (token.pos_ == "ADJ") or (token.pos_ == "ADV") or (token.pos_ == "VERB"):
        if True:
            for child in token.children:
                # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.text in opinion_words):
                    sentiment *= 1.5
                # check for negation words and flip the sign of sentiment
                if child.dep_ == "neg":
                    sentiment *= -1
                # if verb, check if there's a direct object
                if (token.pos_ == "VERB") & (child.dep_ == "dobj"):
                    sent_dict[child] += sentiment
                    # check for conjugates (a AND b), then add both to dictionary
                    subchildren = []
                    for subchild in child.children:
                        if subchild.text == "and":
                            conj=1
                        if (conj == 1) and (subchild.text != "and"):
                            subchildren.append(subchild.text)
                            conj = 0
                    for subchild in subchildren:
                        sent_dict[subchild] += sentiment
                        
          

            # token.head is always verb
            print(token.head)
            for child in token.head.children:
                # if the verb is referring to a noun, 
                noun = ""
                if child.pos_ == "NOUN":
                    noun = child.text
                    # first look for compound nouns
                    for subchild in child.children:
                        if subchild.dep_ == "compound":
                            noun = subchild.text + " " + noun
                    sent_dict[noun] += sentiment

#    print(token.text,token.pos_,token.head,token.dep_, token.lemma_)
print(sent_dict)
displacy.render(sentence, style='dep',jupyter=True)
# Out:
# 's
# loved
# defaultdict(<class 'int'>, {it: 1})
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="4425" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">more</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">yummy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">breakfast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">sandwich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">runny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">egg,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">thick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">cut</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">bacon,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">ham.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">also</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">came</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">fries.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">loved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">it!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width

# %% [markdown]
# # code for segmenting review into sentences

# %%
#"delicious" in opinion_words
test1 = "I did not like the service."
test2 = "It just feels really good to drink here. "
review = nlp(test1)# + test2 + "he was a good server.")
bag_sentence = []
start = 0
for token in review:
    if token.sent_start:
        bag_sentence.append(review[start:(token.i-1)])
        start = token.i
    if token.i == len(review)-1:
        bag_sentence.append(review[start:token.i])
bag_sentence
# Out:
# [I did not like the service]

# %%
str(bag_sentence[0])
# Out:
# 'I did not like the service'

# %% [markdown]
# # playing around with gensim

# %%
import os
import gensim
# Setup nltk corpora path and Google Word2Vec location
google_vec_file = '/Users/petermin/Downloads/GoogleNews-vectors-negative300.bin'
model = gensim.models.KeyedVectors.load_word2vec_format(google_vec_file, binary=True)

# %%
#model.most_similar('price' ,topn=50)
model.n_similarity(['price'], ['table'])
# Out:
# 0.17367959721838405

# %%
for noun in nouns:
    if model.n_similarity(['food'], [noun]) > 0.20:
        print(noun, model.n_similarity(['food'], [noun]))
# Out:
# dinner 0.32926710082092303
# cocktails 0.28745608420489777
# kitchen 0.3470575637135679
# menu 0.3369797112298345
# dishes 0.38281612787243424
# restaurants 0.4972250221421695

# %%
for noun in nouns:
    if model.n_similarity(['ambience'], [noun]) > 0.20:
        print(noun, model.n_similarity(['ambience'], [noun]))
# Out:
# downtown 0.25111992028422414
# bar 0.20074515988417627
# dinner 0.20456144314020488
# cocktails 0.3251233478877049
# kitchen 0.2389108715739009
# menu 0.33252094837534485
# dishes 0.3102893855830975
# city 0.2022985699944965
# restaurants 0.3272493875285166

# %%
model.n_similarity(['food'], ["terrible"])
# Out:
# 0.062305717702855604

# %%
def pos_words (sentence, token, ptag):
    sentences = [sent for sent in sentence.sents if token in sent.string]     
    pwrds = []
    for sent in sentences:
        for word in sent:
            for character in word.string: 
                   pwrds.extend([child.string.strip() for child in word.children
                                                      if child.pos_ == ptag] )
    return Counter(pwrds).most_common(10)
pos_words(review1, 'service', "ADJ")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-9923155b53d2> in <module>()
# ----> 1 import Counter
#       2 def pos_words (sentence, token, ptag):
#       3     sentences = [sent for sent in sentence.sents if token in sent.string]
#       4     pwrds = []
#       5     for sent in sentences:
#
# ModuleNotFoundError: No module named 'Counter'

# %%
from numpy import dot 
from numpy.linalg import norm 
import spacy 

parser = spacy.load("en")
#Generate word vector of the word - apple  
apple = parser.vocab['apple']

#Cosine similarity function 
cosine = lambda v1, v2: dot(v1, v2) / (norm(v1) * norm(v2))
others = list({w for w in parser.vocab if w.has_vector and w.orth_.islower() and w.lower_ != unicode("apple")})

# sort by similarity score
others.sort(key=lambda w: cosine(w.vector, apple.vector)) 
others.reverse()


print("top most similar words to apple:" )
for word in others[:10]:
    print(word.orth_)
# Out:
# top most similar words to apple:

# %% [markdown]
# # Stanford CoreNLP

# %%
# Simple usage
from stanfordcorenlp import StanfordCoreNLP
import logging
#Run corenlp in terminal
#java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
nlp = StanfordCoreNLP("/Users/petermin/metis/nlp/stanford-corenlp-full-2018-02-27", port=9000, quiet=False, logging_level=logging.DEBUG)

sentence = 'Guangdong University of Foreign Studies is located in Guangzhou.'
print('Tokenize:', nlp.word_tokenize(sentence))
print('Part of Speech:', nlp.pos_tag(sentence))
print('Named Entities:', nlp.ner(sentence))
print('Constituency Parsing:', nlp.parse(sentence))
print('Dependency Parsing:', nlp.dependency_parse(sentence))

nlp.close() # Do not forget to close! The backend server will consume a lot memery.
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/psutil/_psosx.py in wrapper(self, *args, **kwargs)
#     329         try:
# --> 330             return fun(self, *args, **kwargs)
#     331         except OSError as err:
#
# ~/anaconda3/lib/python3.6/site-packages/psutil/_psosx.py in connections(self, kind)
#     514         with catch_zombie(self):
# --> 515             rawlist = cext.proc_connections(self.pid, families, types)
#     516         ret = []
#
# PermissionError: [Errno 1] Operation not permitted
#
# During handling of the above exception, another exception occurred:
#
# AccessDenied                              Traceback (most recent call last)
# <ipython-input-11-4e9a6c56a413> in <module>()
#       4 #Run corenlp in terminal
#       5 #java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
# ----> 6 nlp = StanfordCoreNLP("/Users/petermin/metis/nlp/stanford-corenlp-full-2018-02-27", port=9000, quiet=False, logging_level=logging.DEBUG)
#       7
#       8 sentence = 'Guangdong University of Foreign Studies is located in Guangzhou.'
#
# ~/anaconda3/lib/python3.6/site-packages/stanfordcorenlp/corenlp.py in __init__(self, path_or_host, port, memory, lang, timeout, quiet, logging_level)
#      82
#      83             # Check if the port is in use
# ---> 84             if self.port in [conn.laddr[1] for conn in psutil.net_connections()]:
#      85                 raise IOError('Port ' + str(self.port) + ' is already in use.')
#      86
#
# ~/anaconda3/lib/python3.6/site-packages/psutil/__init__.py in net_connections(kind)
#    2106     On OSX this function requires root privileges.
#    2107     """
# -> 2108     return _psplatform.net_connections(kind)
#    2109
#    2110
#
# ~/anaconda3/lib/python3.6/site-packages/psutil/_psosx.py in net_connections(kind)
#     247     for pid in pids():
#     248         try:
# --> 249             cons = Process(pid).connections(kind)
#     250         except NoSuchProcess:
#     251             continue
#
# ~/anaconda3/lib/python3.6/site-packages/psutil/_psosx.py in wrapper(self, *args, **kwargs)
#     333                 raise NoSuchProcess(self.pid, self._name)
#     334             if err.errno in (errno.EPERM, errno.EACCES):
# --> 335                 raise AccessDenied(self.pid, self._name)
#     336             raise
#     337     return wrapper
#
# AccessDenied: psutil.AccessDenied (pid=35180)

# %%
from nltk.parse.stanford import StanfordDependencyParser
path_to_jar = '/Users/petermin/metis/nlp/stanford-corenlp-full-2018-02-27/stanford-corenlp-3.9.1.jar'
path_to_models_jar = '/Users/petermin/metis/nlp/stanford-corenlp-full-2018-02-27/stanford-english-corenlp-2018-02-27-models.jar'
dependency_parser = StanfordDependencyParser(path_to_jar=path_to_jar, path_to_models_jar=path_to_models_jar)

result = dependency_parser.raw_parse('I shot an elephant in my sleep')
dep = result.
list(dep.triples())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-8d36b7cf8fee> in <module>()
#       5
#       6 result = dependency_parser.raw_parse('I shot an elephant in my sleep')
# ----> 7 dep = result.next()
#       8 list(dep.triples())
#
# AttributeError: 'list_iterator' object has no attribute 'next'

# %% [markdown]
# # wordnet

# %%
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
import nltk
#nltk.download()

# %%
def make_synset(word, category='n', number='01'):
    """Conveniently make a synset"""
    number = int(number)
    return wn.synset('%s.%s.%02i' % (word, category, number))
price = make_synset('price')
price.hyponyms()
# Out:
# [Synset('assessment.n.03'),
#  Synset('average_cost.n.01'),
#  Synset('expensiveness.n.01'),
#  Synset('inexpensiveness.n.01'),
#  Synset('marginal_cost.n.01')]

# %%
def _recurse_all_hyponyms(synset, all_hyponyms):
    synset_hyponyms = synset.hyponyms()
    if synset_hyponyms:
        all_hyponyms += synset_hyponyms
        for hyponym in synset_hyponyms:
            _recurse_all_hyponyms(hyponym, all_hyponyms)

def all_hyponyms(synset):
    """Get the set of the tree of hyponyms under the synset"""
    hyponyms = []
    _recurse_all_hyponyms(synset, hyponyms)
    return set(hyponyms)

# %%
all_hyponyms(make_synset("price"))
# Out:
# {Synset('assessment.n.03'),
#  Synset('average_cost.n.01'),
#  Synset('bargain_rate.n.01'),
#  Synset('costliness.n.01'),
#  Synset('expensiveness.n.01'),
#  Synset('inexpensiveness.n.01'),
#  Synset('lavishness.n.01'),
#  Synset('marginal_cost.n.01'),
#  Synset('reasonableness.n.03'),
#  Synset('tax_assessment.n.01')}

# %%
def _recurse_leaf_hyponyms(synset, leaf_hyponyms):
    synset_hyponyms = synset.hyponyms()
    if synset_hyponyms:
        for hyponym in synset_hyponyms:
            _recurse_all_hyponyms(hyponym, leaf_hyponyms)
    else:
        leaf_hyponyms += synset

def leaf_hyponyms(synset):
    """Get the set of leaf nodes from the tree of hyponyms under the synset"""
    hyponyms = []
    _recurse_leaf_hyponyms(synset, hyponyms)
    return set(hyponyms)

leaf_hyponyms(price)
# Out:
# {Synset('bargain_rate.n.01'),
#  Synset('costliness.n.01'),
#  Synset('lavishness.n.01'),
#  Synset('reasonableness.n.03'),
#  Synset('tax_assessment.n.01')}

# %% [markdown]
# # Parsing the Training set

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Restaurants_Train.xml')
root = tree.getroot()

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# sentence {'id': '3121'}
# sentence {'id': '2777'}
# sentence {'id': '1634'}
# sentence {'id': '2534'}
# sentence {'id': '583'}
# sentence {'id': '2846'}
# sentence {'id': '1571'}
# sentence {'id': '1458'}
# sentence {'id': '3161'}
# sentence {'id': '2391'}
# sentence {'id': '986'}
# sentence {'id': '296'}
# sentence {'id': '1793'}
# sentence {'id': '2200'}
# sentence {'id': '3195'}
# sentence {'id': '3119'}
# sentence {'id': '3359'}
# sentence {'id': '70'}
# sentence {'id': '1829'}
# sentence {'id': '2935'}
# sentence {'id': '1805'}
# sentence {'id': '2559'}
# sentence {'id': '716'}
# sentence {'id': '2464'}
# sentence {'id': '385'}
# sentence {'id': '1350'}
# sentence {'id': '3534'}
# sentence {'id': '1407'}
# sentence {'id': '565'}
# sentence {'id': '387'}
# sentence {'id': '1314'}
# sentence {'id': '675'}
# sentence {'id': '2227'}
# sentence {'id': '3367'}
# sentence {'id': '1210'}
# sentence {'id': '2191'}
# sentence {'id': '270'}
# sentence {'id': '638'}
# sentence {'id': '500'}
# sentence {'id': '1108'}
# sentence {'id': '3294'}
# sentence {'id': '388'}
# sentence {'id': '3070'}
# sentence {'id': '3373'}
# sentence {'id': '425'}
# sentence {'id': '3192'}
# sentence {'id': '1098'}
# sentence {'id': '2173'}
# sentence {'id': '391'}
# sentence {'id': '263'}
# sentence {'id': '2384'}
# sentence {'id': '2962'}
# sentence {'id': '3404'}
# sentence {'id': '2599'}
# sentence {'id': '673'}
# sentence {'id': '648'}
# sentence {'id': '863'}
# sentence {'id': '1623'}
# sentence {'id': '2177'}
# sentence {'id': '430'}
# sentence {'id': '1101'}
# sentence {'id': '1823'}
# sentence {'id': '324'}
# sentence {'id': '2783'}
# sentence {'id': '2983'}
# sentence {'id': '66'}
# sentence {'id': '627'}
# sentence {'id': '3219'}
# sentence {'id': '2934'}
# sentence {'id': '2787'}
# sentence {'id': '825'}
# sentence {'id': '197'}
# sentence {'id': '604'}
# sentence {'id': '2911'}
# sentence {'id': '3074'}
# sentence {'id': '1479'}
# sentence {'id': '1074'}
# sentence {'id': '912'}
# sentence {'id': '728'}
# sentence {'id': '2925'}
# sentence {'id': '495'}
# sentence {'id': '3436'}
# sentence {'id': '3273'}
# sentence {'id': '1215'}
# sentence {'id': '183'}
# sentence {'id': '2511'}
# sentence {'id': '282'}
# sentence {'id': '1562'}
# sentence {'id': '1712'}
# sentence {'id': '3249'}
# sentence {'id': '2052'}
# sentence {'id': '3207'}
# sentence {'id': '672'}
# sentence {'id': '2972'}
# sentence {'id': '1903'}
# sentence {'id': '2549'}
# sentence {'id': '1755'}
# sentence {'id': '2890'}
# sentence {'id': '2277'}
# sentence {'id': '2308'}
# sentence {'id': '51'}
# sentence {'id': '3680'}
# sentence {'id': '3155'}
# sentence {'id': '1688'}
# sentence {'id': '598'}
# sentence {'id': '2926'}
# sentence {'id': '3083'}
# sentence {'id': '1388'}
# sentence {'id': '2977'}
# sentence {'id': '1574'}
# sentence {'id': '498'}
# sentence {'id': '2604'}
# sentence {'id': '473'}
# sentence {'id': '380'}
# sentence {'id': '2960'}
# sentence {'id': '322'}
# sentence {'id': '1383'}
# sentence {'id': '892'}
# sentence {'id': '2296'}
# sentence {'id': '868'}
# sentence {'id': '2936'}
# sentence {'id': '3423'}
# sentence {'id': '154'}
# sentence {'id': '591'}
# sentence {'id': '1197'}
# sentence {'id': '2061'}
# sentence {'id': '2274'}
# sentence {'id': '2804'}
# sentence {'id': '194'}
# sentence {'id': '148'}
# sentence {'id': '2747'}
# sentence {'id': '2845'}
# sentence {'id': '187'}
# sentence {'id': '856'}
# sentence {'id': '2033'}
# sentence {'id': '1402'}
# sentence {'id': '439'}
# sentence {'id': '3360'}
# sentence {'id': '2949'}
# sentence {'id': '570'}
# sentence {'id': '2053'}
# sentence {'id': '3316'}
# sentence {'id': '433'}
# sentence {'id': '738'}
# sentence {'id': '1549'}
# sentence {'id': '1798'}
# sentence {'id': '2941'}
# sentence {'id': '362'}
# sentence {'id': '2921'}
# sentence {'id': '1909'}
# sentence {'id': '1878'}
# sentence {'id': '858'}
# sentence {'id': '3376'}
# sentence {'id': '173'}
# sentence {'id': '1836'}
# sentence {'id': '1703'}
# sentence {'id': '3564'}
# sentence {'id': '1404'}
# sentence {'id': '645'}
# sentence {'id': '3288'}
# sentence {'id': '1819'}
# sentence {'id': '1144'}
# sentence {'id': '2639'}
# sentence {'id': '1474'}
# sentence {'id': '1553'}
# sentence {'id': '2059'}
# sentence {'id': '926'}
# sentence {'id': '2385'}
# sentence {'id': '2498'}
# sentence {'id': '2469'}
# sentence {'id': '567'}
# sentence {'id': '3517'}
# sentence {'id': '2069'}
# sentence {'id': '1599'}
# sentence {'id': '2860'}
# sentence {'id': '1092'}
# sentence {'id': '2548'}
# sentence {'id': '759'}
# sentence {'id': '3175'}
# sentence {'id': '2209'}
# sentence {'id': '2717'}
# sentence {'id': '1352'}
# sentence {'id': '1543'}
# sentence {'id': '3537'}
# sentence {'id': '3213'}
# sentence {'id': '1743'}
# sentence {'id': '1321'}
# sentence {'id': '2907'}
# sentence {'id': '1890'}
# sentence {'id': '2675'}
# sentence {'id': '2588'}
# sentence {'id': '2234'}
# sentence {'id': '3130'}
# sentence {'id': '3285'}
# sentence {'id': '709'}
# sentence {'id': '1198'}
# sentence {'id': '2380'}
# sentence {'id': '2250'}
# sentence {'id': '2302'}
# sentence {'id': '1110'}
# sentence {'id': '973'}
# sentence {'id': '2132'}
# sentence {'id': '231'}
# sentence {'id': '1184'}
# sentence {'id': '250'}
# sentence {'id': '227'}
# sentence {'id': '3653'}
# sentence {'id': '2988'}
# sentence {'id': '3092'}
# sentence {'id': '1166'}
# sentence {'id': '3686'}
# sentence {'id': '1922'}
# sentence {'id': '2978'}
# sentence {'id': '2139'}
# sentence {'id': '2454'}
# sentence {'id': '1881'}
# sentence {'id': '633'}
# sentence {'id': '268'}
# sentence {'id': '3613'}
# sentence {'id': '1531'}
# sentence {'id': '603'}
# sentence {'id': '678'}
# sentence {'id': '2690'}
# sentence {'id': '1830'}
# sentence {'id': '1408'}
# sentence {'id': '2521'}
# sentence {'id': '1918'}
# sentence {'id': '2930'}
# sentence {'id': '2166'}
# sentence {'id': '887'}
# sentence {'id': '2448'}
# sentence {'id': '3244'}
# sentence {'id': '1478'}
# sentence {'id': '1413'}
# sentence {'id': '3129'}
# sentence {'id': '2271'}
# sentence {'id': '1554'}
# sentence {'id': '2306'}
# sentence {'id': '1975'}
# sentence {'id': '3699'}
# sentence {'id': '2875'}
# sentence {'id': '2303'}
# sentence {'id': '2513'}
# sentence {'id': '458'}
# sentence {'id': '809'}
# sentence {'id': '141'}
# sentence {'id': '3655'}
# sentence {'id': '2098'}
# sentence {'id': '1624'}
# sentence {'id': '1928'}
# sentence {'id': '2377'}
# sentence {'id': '3209'}
# sentence {'id': '338'}
# sentence {'id': '1630'}
# sentence {'id': '1907'}
# sentence {'id': '1557'}
# sentence {'id': '3408'}
# sentence {'id': '1535'}
# sentence {'id': '3202'}
# sentence {'id': '449'}
# sentence {'id': '1449'}
# sentence {'id': '927'}
# sentence {'id': '585'}
# sentence {'id': '1927'}
# sentence {'id': '1367'}
# sentence {'id': '701'}
# sentence {'id': '345'}
# sentence {'id': '293'}
# sentence {'id': '1720'}
# sentence {'id': '1494'}
# sentence {'id': '1085'}
# sentence {'id': '2636'}
# sentence {'id': '1179'}
# sentence {'id': '1976'}
# sentence {'id': '1315'}
# sentence {'id': '3194'}
# sentence {'id': '688'}
# sentence {'id': '2393'}
# sentence {'id': '1278'}
# sentence {'id': '2201'}
# sentence {'id': '624'}
# sentence {'id': '3252'}
# sentence {'id': '620'}
# sentence {'id': '3541'}
# sentence {'id': '865'}
# sentence {'id': '375'}
# sentence {'id': '2126'}
# sentence {'id': '2078'}
# sentence {'id': '846'}
# sentence {'id': '2158'}
# sentence {'id': '1578'}
# sentence {'id': '1282'}
# sentence {'id': '1319'}
# sentence {'id': '1175'}
# sentence {'id': '1115'}
# sentence {'id': '3396'}
# sentence {'id': '34'}
# sentence {'id': '798'}
# sentence {'id': '395'}
# sentence {'id': '1838'}
# sentence {'id': '176'}
# sentence {'id': '3102'}
# sentence {'id': '984'}
# sentence {'id': '2138'}
# sentence {'id': '1472'}
# sentence {'id': '1969'}
# sentence {'id': '1674'}
# sentence {'id': '1330'}
# sentence {'id': '763'}
# sentence {'id': '332'}
# sentence {'id': '754'}
# sentence {'id': '2248'}
# sentence {'id': '691'}
# sentence {'id': '3363'}
# sentence {'id': '999'}
# sentence {'id': '2503'}
# sentence {'id': '1310'}
# sentence {'id': '940'}
# sentence {'id': '247'}
# sentence {'id': '2823'}
# sentence {'id': '3628'}
# sentence {'id': '349'}
# sentence {'id': '987'}
# sentence {'id': '1611'}
# sentence {'id': '2649'}
# sentence {'id': '2396'}
# sentence {'id': '139'}
# sentence {'id': '841'}
# sentence {'id': '3477'}
# sentence {'id': '442'}
# sentence {'id': '90'}
# sentence {'id': '298'}
# sentence {'id': '1104'}
# sentence {'id': '2563'}
# sentence {'id': '1280'}
# sentence {'id': '2790'}
# sentence {'id': '323'}
# sentence {'id': '24'}
# sentence {'id': '1891'}
# sentence {'id': '2417'}
# sentence {'id': '2980'}
# sentence {'id': '3451'}
# sentence {'id': '1551'}
# sentence {'id': '3146'}
# sentence {'id': '1785'}
# sentence {'id': '1492'}
# sentence {'id': '406'}
# sentence {'id': '3650'}
# sentence {'id': '2985'}
# sentence {'id': '2084'}
# sentence {'id': '2536'}
# sentence {'id': '1820'}
# sentence {'id': '1826'}
# sentence {'id': '96'}
# sentence {'id': '3584'}
# sentence {'id': '3193'}
# sentence {'id': '93'}
# sentence {'id': '2212'}
# sentence {'id': '3426'}
# sentence {'id': '1138'}
# sentence {'id': '1461'}
# sentence {'id': '128'}
# sentence {'id': '1008'}
# sentence {'id': '241'}
# sentence {'id': '1581'}
# sentence {'id': '1815'}
# sentence {'id': '1746'}
# sentence {'id': '2124'}
# sentence {'id': '2919'}
# sentence {'id': '2360'}
# sentence {'id': '3082'}
# sentence {'id': '1950'}
# sentence {'id': '2803'}
# sentence {'id': '1133'}
# sentence {'id': '3204'}
# sentence {'id': '1728'}
# sentence {'id': '2801'}
# sentence {'id': '2140'}
# sentence {'id': '2447'}
# sentence {'id': '224'}
# sentence {'id': '2434'}
# sentence {'id': '459'}
# sentence {'id': '3042'}
# sentence {'id': '152'}
# sentence {'id': '3062'}
# sentence {'id': '2426'}
# sentence {'id': '225'}
# sentence {'id': '2424'}
# sentence {'id': '494'}
# sentence {'id': '1033'}
# sentence {'id': '496'}
# sentence {'id': '2486'}
# sentence {'id': '2307'}
# sentence {'id': '1646'}
# sentence {'id': '3255'}
# sentence {'id': '2229'}
# sentence {'id': '2615'}
# sentence {'id': '318'}
# sentence {'id': '895'}
# sentence {'id': '198'}
# sentence {'id': '2864'}
# sentence {'id': '1269'}
# sentence {'id': '95'}
# sentence {'id': '2062'}
# sentence {'id': '3557'}
# sentence {'id': '38'}
# sentence {'id': '1957'}
# sentence {'id': '1542'}
# sentence {'id': '55'}
# sentence {'id': '168'}
# sentence {'id': '2328'}
# sentence {'id': '3644'}
# sentence {'id': '1214'}
# sentence {'id': '1825'}
# sentence {'id': '504'}
# sentence {'id': '1853'}
# sentence {'id': '1538'}
# sentence {'id': '2482'}
# sentence {'id': '791'}
# sentence {'id': '998'}
# sentence {'id': '2872'}
# sentence {'id': '3281'}
# sentence {'id': '2213'}
# sentence {'id': '2607'}
# sentence {'id': '1272'}
# sentence {'id': '3369'}
# sentence {'id': '3578'}
# sentence {'id': '572'}
# sentence {'id': '2500'}
# sentence {'id': '45'}
# sentence {'id': '2445'}
# sentence {'id': '3217'}
# sentence {'id': '1188'}
# sentence {'id': '1973'}
# sentence {'id': '1334'}
# sentence {'id': '2392'}
# sentence {'id': '1791'}
# sentence {'id': '1044'}
# sentence {'id': '925'}
# sentence {'id': '1828'}
# sentence {'id': '2363'}
# sentence {'id': '327'}
# sentence {'id': '2831'}
# sentence {'id': '2479'}
# sentence {'id': '1374'}
# sentence {'id': '985'}
# sentence {'id': '3061'}
# sentence {'id': '1843'}
# sentence {'id': '2102'}
# sentence {'id': '2149'}
# sentence {'id': '964'}
# sentence {'id': '748'}
# sentence {'id': '766'}
# sentence {'id': '2674'}
# sentence {'id': '2501'}
# sentence {'id': '2222'}
# sentence {'id': '2786'}
# sentence {'id': '773'}
# sentence {'id': '368'}
# sentence {'id': '994'}
# sentence {'id': '366'}
# sentence {'id': '3075'}
# sentence {'id': '1270'}
# sentence {'id': '3664'}
# sentence {'id': '3128'}
# sentence {'id': '2097'}
# sentence {'id': '1705'}
# sentence {'id': '3145'}
# sentence {'id': '790'}
# sentence {'id': '9'}
# sentence {'id': '3085'}
# sentence {'id': '1448'}
# sentence {'id': '1933'}
# sentence {'id': '1661'}
# sentence {'id': '1817'}
# sentence {'id': '2512'}
# sentence {'id': '1749'}
# sentence {'id': '3441'}
# sentence {'id': '3260'}
# sentence {'id': '2910'}
# sentence {'id': '76'}
# sentence {'id': '1971'}
# sentence {'id': '1286'}
# sentence {'id': '797'}
# sentence {'id': '2315'}
# sentence {'id': '344'}
# sentence {'id': '1990'}
# sentence {'id': '2900'}
# sentence {'id': '3122'}
# sentence {'id': '719'}
# sentence {'id': '3669'}
# sentence {'id': '3295'}
# sentence {'id': '1130'}
# sentence {'id': '2896'}
# sentence {'id': '2299'}
# sentence {'id': '1652'}
# sentence {'id': '2128'}
# sentence {'id': '2835'}
# sentence {'id': '778'}
# sentence {'id': '3029'}
# sentence {'id': '1672'}
# sentence {'id': '1125'}
# sentence {'id': '3694'}
# sentence {'id': '2721'}
# sentence {'id': '884'}
# sentence {'id': '954'}
# sentence {'id': '2452'}
# sentence {'id': '1250'}
# sentence {'id': '3234'}
# sentence {'id': '2494'}
# sentence {'id': '1533'}
# sentence {'id': '1055'}
# sentence {'id': '1784'}
# sentence {'id': '2178'}
# sentence {'id': '1689'}
# sentence {'id': '771'}
# sentence {'id': '3370'}
# sentence {'id': '823'}
# sentence {'id': '1988'}
# sentence {'id': '3535'}
# sentence {'id': '2449'}
# sentence {'id': '993'}
# sentence {'id': '3598'}
# sentence {'id': '2840'}
# sentence {'id': '1034'}
# sentence {'id': '2709'}
# sentence {'id': '2734'}
# sentence {'id': '174'}
# sentence {'id': '3654'}
# sentence {'id': '1049'}
# sentence {'id': '2515'}
# sentence {'id': '3320'}
# sentence {'id': '102'}
# sentence {'id': '2397'}
# sentence {'id': '511'}
# sentence {'id': '1203'}
# sentence {'id': '1077'}
# sentence {'id': '133'}
# sentence {'id': '3230'}
# sentence {'id': '2905'}
# sentence {'id': '491'}
# sentence {'id': '2001'}
# sentence {'id': '1362'}
# sentence {'id': '796'}
# sentence {'id': '2733'}
# sentence {'id': '178'}
# sentence {'id': '2627'}
# sentence {'id': '2946'}
# sentence {'id': '554'}
# sentence {'id': '1616'}
# sentence {'id': '3189'}
# sentence {'id': '3693'}
# sentence {'id': '1103'}
# sentence {'id': '1732'}
# sentence {'id': '990'}
# sentence {'id': '1994'}
# sentence {'id': '541'}
# sentence {'id': '229'}
# sentence {'id': '3542'}
# sentence {'id': '1617'}
# sentence {'id': '3322'}
# sentence {'id': '1022'}
# sentence {'id': '751'}
# sentence {'id': '1711'}
# sentence {'id': '2179'}
# sentence {'id': '1131'}
# sentence {'id': '2723'}
# sentence {'id': '2012'}
# sentence {'id': '1684'}
# sentence {'id': '3024'}
# sentence {'id': '1622'}
# sentence {'id': '1059'}
# sentence {'id': '2347'}
# sentence {'id': '3067'}
# sentence {'id': '530'}
# sentence {'id': '447'}
# sentence {'id': '1592'}
# sentence {'id': '3191'}
# sentence {'id': '3433'}
# sentence {'id': '2134'}
# sentence {'id': '2947'}
# sentence {'id': '2770'}
# sentence {'id': '1989'}
# sentence {'id': '445'}
# sentence {'id': '653'}
# sentence {'id': '3278'}
# sentence {'id': '2789'}
# sentence {'id': '440'}
# sentence {'id': '1331'}
# sentence {'id': '2497'}
# sentence {'id': '2705'}
# sentence {'id': '3105'}
# sentence {'id': '1495'}
# sentence {'id': '3039'}
# sentence {'id': '75'}
# sentence {'id': '2446'}
# sentence {'id': '3429'}
# sentence {'id': '3637'}
# sentence {'id': '861'}
# sentence {'id': '2000'}
# sentence {'id': '1316'}
# sentence {'id': '2450'}
# sentence {'id': '1577'}
# sentence {'id': '3538'}
# sentence {'id': '2901'}
# sentence {'id': '908'}
# sentence {'id': '1790'}
# sentence {'id': '150'}
# sentence {'id': '2523'}
# sentence {'id': '2170'}
# sentence {'id': '1012'}
# sentence {'id': '1626'}
# sentence {'id': '1579'}
# sentence {'id': '1567'}
# sentence {'id': '3515'}
# sentence {'id': '1698'}
# sentence {'id': '1873'}
# sentence {'id': '2592'}
# sentence {'id': '3081'}
# sentence {'id': '2806'}
# sentence {'id': '3142'}
# sentence {'id': '3575'}
# sentence {'id': '1884'}
# sentence {'id': '3381'}
# sentence {'id': '2507'}
# sentence {'id': '745'}
# sentence {'id': '3100'}
# sentence {'id': '2802'}
# sentence {'id': '1769'}
# sentence {'id': '201'}
# sentence {'id': '1180'}
# sentence {'id': '2335'}
# sentence {'id': '1593'}
# sentence {'id': '3631'}
# sentence {'id': '901'}
# sentence {'id': '3049'}
# sentence {'id': '1242'}
# sentence {'id': '932'}
# sentence {'id': '2769'}
# sentence {'id': '1105'}
# sentence {'id': '2609'}
# sentence {'id': '776'}
# sentence {'id': '272'}
# sentence {'id': '1152'}
# sentence {'id': '2894'}
# sentence {'id': '2591'}
# sentence {'id': '833'}
# sentence {'id': '461'}
# sentence {'id': '2830'}
# sentence {'id': '1356'}
# sentence {'id': '539'}
# sentence {'id': '836'}
# sentence {'id': '2533'}
# sentence {'id': '1435'}
# sentence {'id': '3208'}
# sentence {'id': '3126'}
# sentence {'id': '1455'}
# sentence {'id': '2225'}
# sentence {'id': '1056'}
# sentence {'id': '3582'}
# sentence {'id': '2708'}
# sentence {'id': '275'}
# sentence {'id': '2105'}
# sentence {'id': '2152'}
# sentence {'id': '191'}
# sentence {'id': '3319'}
# sentence {'id': '3681'}
# sentence {'id': '2171'}
# sentence {'id': '3462'}
# sentence {'id': '1087'}
# sentence {'id': '1865'}
# sentence {'id': '1380'}
# sentence {'id': '3421'}
# sentence {'id': '1293'}
# sentence {'id': '3475'}
# sentence {'id': '818'}
# sentence {'id': '2893'}
# sentence {'id': '3170'}
# sentence {'id': '2932'}
# sentence {'id': '2575'}
# sentence {'id': '451'}
# sentence {'id': '3700'}
# sentence {'id': '119'}
# sentence {'id': '2817'}
# sentence {'id': '2517'}
# sentence {'id': '2883'}
# sentence {'id': '556'}
# sentence {'id': '563'}
# sentence {'id': '924'}
# sentence {'id': '3113'}
# sentence {'id': '2164'}
# sentence {'id': '3461'}
# sentence {'id': '3041'}
# sentence {'id': '2459'}
# sentence {'id': '1013'}
# sentence {'id': '193'}
# sentence {'id': '1569'}
# sentence {'id': '2217'}
# sentence {'id': '78'}
# sentence {'id': '2280'}
# sentence {'id': '3424'}
# sentence {'id': '3641'}
# sentence {'id': '1707'}
# sentence {'id': '2766'}
# sentence {'id': '667'}
# sentence {'id': '1600'}
# sentence {'id': '134'}
# sentence {'id': '3336'}
# sentence {'id': '2421'}
# sentence {'id': '159'}
# sentence {'id': '1490'}
# sentence {'id': '3546'}
# sentence {'id': '1548'}
# sentence {'id': '2107'}
# sentence {'id': '1709'}
# sentence {'id': '1550'}
# sentence {'id': '3305'}
# sentence {'id': '874'}
# sentence {'id': '3116'}
# sentence {'id': '2707'}
# sentence {'id': '2630'}
# sentence {'id': '3353'}
# sentence {'id': '2081'}
# sentence {'id': '533'}
# sentence {'id': '972'}
# sentence {'id': '3420'}
# sentence {'id': '2329'}
# sentence {'id': '1827'}
# sentence {'id': '692'}
# sentence {'id': '217'}
# sentence {'id': '878'}
# sentence {'id': '2891'}
# sentence {'id': '2673'}
# sentence {'id': '2276'}
# sentence {'id': '3199'}
# sentence {'id': '3414'}
# sentence {'id': '209'}
# sentence {'id': '3077'}
# sentence {'id': '1228'}
# sentence {'id': '3297'}
# sentence {'id': '1759'}
# sentence {'id': '2966'}
# sentence {'id': '2077'}
# sentence {'id': '3554'}
# sentence {'id': '410'}
# sentence {'id': '202'}
# sentence {'id': '3492'}
# sentence {'id': '537'}
# sentence {'id': '2439'}
# sentence {'id': '3562'}
# sentence {'id': '3280'}
# sentence {'id': '2189'}
# sentence {'id': '3573'}
# sentence {'id': '277'}
# sentence {'id': '2460'}
# sentence {'id': '952'}
# sentence {'id': '2811'}
# sentence {'id': '2024'}
# sentence {'id': '3020'}
# sentence {'id': '3079'}
# sentence {'id': '2716'}
# sentence {'id': '746'}
# sentence {'id': '2912'}
# sentence {'id': '3566'}
# sentence {'id': '1702'}
# sentence {'id': '199'}
# sentence {'id': '882'}
# sentence {'id': '2324'}
# sentence {'id': '2524'}
# sentence {'id': '628'}
# sentence {'id': '3563'}
# sentence {'id': '727'}
# sentence {'id': '1925'}
# sentence {'id': '2740'}
# sentence {'id': '3422'}
# sentence {'id': '3144'}
# sentence {'id': '2202'}
# sentence {'id': '618'}
# sentence {'id': '1919'}
# sentence {'id': '1487'}
# sentence {'id': '2120'}
# sentence {'id': '1868'}
# sentence {'id': '770'}
# sentence {'id': '2205'}
# sentence {'id': '948'}
# sentence {'id': '1940'}
# sentence {'id': '2451'}
# sentence {'id': '56'}
# sentence {'id': '1632'}
# sentence {'id': '1961'}
# sentence {'id': '710'}
# sentence {'id': '911'}
# sentence {'id': '3607'}
# sentence {'id': '1955'}
# sentence {'id': '2903'}
# sentence {'id': '1887'}
# sentence {'id': '3495'}
# sentence {'id': '1273'}
# sentence {'id': '590'}
# sentence {'id': '762'}
# sentence {'id': '3374'}
# sentence {'id': '179'}
# sentence {'id': '109'}
# sentence {'id': '339'}
# sentence {'id': '489'}
# sentence {'id': '2487'}
# sentence {'id': '499'}
# sentence {'id': '2589'}
# sentence {'id': '3701'}
# sentence {'id': '381'}
# sentence {'id': '3050'}
# sentence {'id': '1185'}
# sentence {'id': '1555'}
# sentence {'id': '1112'}
# sentence {'id': '3368'}
# sentence {'id': '1032'}
# sentence {'id': '1124'}
# sentence {'id': '1663'}
# sentence {'id': '1690'}
# sentence {'id': '788'}
# sentence {'id': '1780'}
# sentence {'id': '742'}
# sentence {'id': '1471'}
# sentence {'id': '1789'}
# sentence {'id': '2751'}
# sentence {'id': '1189'}
# sentence {'id': '3352'}
# sentence {'id': '3315'}
# sentence {'id': '3393'}
# sentence {'id': '2157'}
# sentence {'id': '3018'}
# sentence {'id': '1401'}
# sentence {'id': '257'}
# sentence {'id': '813'}
# sentence {'id': '2862'}
# sentence {'id': '3292'}
# sentence {'id': '3343'}
# sentence {'id': '3045'}
# sentence {'id': '3135'}
# sentence {'id': '3391'}
# sentence {'id': '3651'}
# sentence {'id': '2018'}
# sentence {'id': '3551'}
# sentence {'id': '2355'}
# sentence {'id': '3178'}
# sentence {'id': '586'}
# sentence {'id': '2211'}
# sentence {'id': '2317'}
# sentence {'id': '175'}
# sentence {'id': '1609'}
# sentence {'id': '2706'}
# sentence {'id': '1860'}
# sentence {'id': '961'}
# sentence {'id': '1057'}
# sentence {'id': '3188'}
# sentence {'id': '65'}
# sentence {'id': '2735'}
# sentence {'id': '2882'}
# sentence {'id': '1948'}
# sentence {'id': '2041'}
# sentence {'id': '1046'}
# sentence {'id': '1656'}
# sentence {'id': '3440'}
# sentence {'id': '870'}
# sentence {'id': '2986'}
# sentence {'id': '288'}
# sentence {'id': '284'}
# sentence {'id': '3418'}
# sentence {'id': '3358'}
# sentence {'id': '83'}
# sentence {'id': '2940'}
# sentence {'id': '2141'}
# sentence {'id': '1854'}
# sentence {'id': '396'}
# sentence {'id': '3471'}
# sentence {'id': '3577'}
# sentence {'id': '2283'}
# sentence {'id': '614'}
# sentence {'id': '3012'}
# sentence {'id': '2621'}
# sentence {'id': '605'}
# sentence {'id': '2017'}
# sentence {'id': '2974'}
# sentence {'id': '2456'}
# sentence {'id': '25'}
# sentence {'id': '520'}
# sentence {'id': '3383'}
# sentence {'id': '2186'}
# sentence {'id': '3478'}
# sentence {'id': '1283'}
# sentence {'id': '3411'}
# sentence {'id': '3221'}
# sentence {'id': '1923'}
# sentence {'id': '756'}
# sentence {'id': '1194'}
# sentence {'id': '3372'}
# sentence {'id': '123'}
# sentence {'id': '2522'}
# sentence {'id': '2386'}
# sentence {'id': '3332'}
# sentence {'id': '717'}
# sentence {'id': '680'}
# sentence {'id': '1345'}
# sentence {'id': '3013'}
# sentence {'id': '1159'}
# sentence {'id': '3547'}
# sentence {'id': '792'}
# sentence {'id': '2015'}
# sentence {'id': '92'}
# sentence {'id': '548'}
# sentence {'id': '3692'}
# sentence {'id': '1209'}
# sentence {'id': '443'}
# sentence {'id': '400'}
# sentence {'id': '1486'}
# sentence {'id': '1377'}
# sentence {'id': '1439'}
# sentence {'id': '2741'}
# sentence {'id': '370'}
# sentence {'id': '599'}
# sentence {'id': '803'}
# sentence {'id': '1750'}
# sentence {'id': '737'}
# sentence {'id': '847'}
# sentence {'id': '81'}
# sentence {'id': '2144'}
# sentence {'id': '1007'}
# sentence {'id': '3687'}
# sentence {'id': '1161'}
# sentence {'id': '3123'}
# sentence {'id': '2301'}
# sentence {'id': '3405'}
# sentence {'id': '3576'}
# sentence {'id': '3702'}
# sentence {'id': '1911'}
# sentence {'id': '703'}
# sentence {'id': '619'}
# sentence {'id': '907'}
# sentence {'id': '1000'}
# sentence {'id': '3241'}
# sentence {'id': '1866'}
# sentence {'id': '2570'}
# sentence {'id': '280'}
# sentence {'id': '1021'}
# sentence {'id': '1729'}
# sentence {'id': '610'}
# sentence {'id': '3211'}
# sentence {'id': '2984'}
# sentence {'id': '1429'}
# sentence {'id': '1855'}
# sentence {'id': '3409'}
# sentence {'id': '579'}
# sentence {'id': '3670'}
# sentence {'id': '685'}
# sentence {'id': '428'}
# sentence {'id': '3378'}
# sentence {'id': '779'}
# sentence {'id': '916'}
# sentence {'id': '2194'}
# sentence {'id': '1066'}
# sentence {'id': '127'}
# sentence {'id': '427'}
# sentence {'id': '2298'}
# sentence {'id': '269'}
# sentence {'id': '3169'}
# sentence {'id': '3335'}
# sentence {'id': '2356'}
# sentence {'id': '1199'}
# sentence {'id': '2444'}
# sentence {'id': '720'}
# sentence {'id': '340'}
# sentence {'id': '228'}
# sentence {'id': '651'}
# sentence {'id': '2664'}
# sentence {'id': '1930'}
# sentence {'id': '2090'}
# sentence {'id': '977'}
# sentence {'id': '2433'}
# sentence {'id': '1949'}
# sentence {'id': '2757'}
# sentence {'id': '301'}
# sentence {'id': '336'}
# sentence {'id': '942'}
# sentence {'id': '2887'}
# sentence {'id': '80'}
# sentence {'id': '2398'}
# sentence {'id': '53'}
# sentence {'id': '1475'}
# sentence {'id': '1560'}
# sentence {'id': '2025'}
# sentence {'id': '1760'}
# sentence {'id': '259'}
# sentence {'id': '2829'}
# sentence {'id': '1211'}
# sentence {'id': '177'}
# sentence {'id': '1312'}
# sentence {'id': '1565'}
# sentence {'id': '2959'}
# sentence {'id': '3339'}
# sentence {'id': '1659'}
# sentence {'id': '839'}
# sentence {'id': '457'}
# sentence {'id': '1306'}
# sentence {'id': '3086'}
# sentence {'id': '2466'}
# sentence {'id': '531'}
# sentence {'id': '450'}
# sentence {'id': '121'}
# sentence {'id': '3263'}
# sentence {'id': '2939'}
# sentence {'id': '1678'}
# sentence {'id': '2606'}
# sentence {'id': '2019'}
# sentence {'id': '1797'}
# sentence {'id': '404'}
# sentence {'id': '1731'}
# sentence {'id': '2791'}
# sentence {'id': '3261'}
# sentence {'id': '1586'}
# sentence {'id': '1893'}
# sentence {'id': '309'}
# sentence {'id': '2290'}
# sentence {'id': '3601'}
# sentence {'id': '736'}
# sentence {'id': '2784'}
# sentence {'id': '2825'}
# sentence {'id': '1741'}
# sentence {'id': '2118'}
# sentence {'id': '84'}
# sentence {'id': '369'}
# sentence {'id': '3279'}
# sentence {'id': '1425'}
# sentence {'id': '2743'}
# sentence {'id': '3324'}
# sentence {'id': '1792'}
# sentence {'id': '166'}
# sentence {'id': '1679'}
# sentence {'id': '1727'}
# sentence {'id': '2425'}
# sentence {'id': '3532'}
# sentence {'id': '3455'}
# sentence {'id': '3508'}
# sentence {'id': '1541'}
# sentence {'id': '1037'}
# sentence {'id': '2288'}
# sentence {'id': '2955'}
# sentence {'id': '2585'}
# sentence {'id': '1386'}
# sentence {'id': '1378'}
# sentence {'id': '438'}
# sentence {'id': '232'}
# sentence {'id': '2764'}
# sentence {'id': '3246'}
# sentence {'id': '2473'}
# sentence {'id': '3051'}
# sentence {'id': '3621'}
# sentence {'id': '2579'}
# sentence {'id': '3489'}
# sentence {'id': '3600'}
# sentence {'id': '3519'}
# sentence {'id': '1183'}
# sentence {'id': '2663'}
# sentence {'id': '857'}
# sentence {'id': '1118'}
# sentence {'id': '2484'}
# sentence {'id': '576'}
# sentence {'id': '2915'}
# sentence {'id': '3166'}
# sentence {'id': '662'}
# sentence {'id': '3599'}
# sentence {'id': '502'}
# sentence {'id': '981'}
# sentence {'id': '1987'}
# sentence {'id': '2889'}
# sentence {'id': '1287'}
# sentence {'id': '476'}
# sentence {'id': '3626'}
# sentence {'id': '1094'}
# sentence {'id': '2881'}
# sentence {'id': '285'}
# sentence {'id': '700'}
# sentence {'id': '1493'}
# sentence {'id': '1014'}
# sentence {'id': '674'}
# sentence {'id': '953'}
# sentence {'id': '405'}
# sentence {'id': '3141'}
# sentence {'id': '466'}
# sentence {'id': '1899'}
# sentence {'id': '729'}
# sentence {'id': '487'}
# sentence {'id': '1434'}
# sentence {'id': '3410'}
# sentence {'id': '1050'}
# sentence {'id': '1981'}
# sentence {'id': '1991'}
# sentence {'id': '2035'}
# sentence {'id': '3587'}
# sentence {'id': '2851'}
# sentence {'id': '2294'}
# sentence {'id': '2726'}
# sentence {'id': '1680'}
# sentence {'id': '3605'}
# sentence {'id': '3624'}
# sentence {'id': '1671'}
# sentence {'id': '2767'}
# sentence {'id': '1155'}
# sentence {'id': '3327'}
# sentence {'id': '1700'}
# sentence {'id': '3589'}
# sentence {'id': '898'}
# sentence {'id': '2429'}
# sentence {'id': '483'}
# sentence {'id': '359'}
# sentence {'id': '2795'}
# sentence {'id': '342'}
# sentence {'id': '1239'}
# sentence {'id': '767'}
# sentence {'id': '3157'}
# sentence {'id': '2123'}
# sentence {'id': '1861'}
# sentence {'id': '2888'}
# sentence {'id': '2938'}
# sentence {'id': '2544'}
# sentence {'id': '408'}
# sentence {'id': '3703'}
# sentence {'id': '129'}
# sentence {'id': '529'}
# sentence {'id': '3504'}
# sentence {'id': '475'}
# sentence {'id': '2568'}
# sentence {'id': '1677'}
# sentence {'id': '2554'}
# sentence {'id': '1412'}
# sentence {'id': '2251'}
# sentence {'id': '808'}
# sentence {'id': '991'}
# sentence {'id': '2284'}
# sentence {'id': '3531'}
# sentence {'id': '2654'}
# sentence {'id': '1869'}
# sentence {'id': '550'}
# sentence {'id': '3243'}
# sentence {'id': '1995'}
# sentence {'id': '2316'}
# sentence {'id': '486'}
# sentence {'id': '1290'}
# sentence {'id': '3469'}
# sentence {'id': '3574'}
# sentence {'id': '1662'}
# sentence {'id': '2584'}
# sentence {'id': '2578'}
# sentence {'id': '3205'}
# sentence {'id': '528'}
# sentence {'id': '82'}
# sentence {'id': '2640'}
# sentence {'id': '1176'}
# sentence {'id': '3237'}
# sentence {'id': '291'}
# sentence {'id': '3643'}
# sentence {'id': '40'}
# sentence {'id': '3111'}
# sentence {'id': '1340'}
# sentence {'id': '1111'}
# sentence {'id': '2622'}
# sentence {'id': '3259'}
# sentence {'id': '1279'}
# sentence {'id': '2495'}
# sentence {'id': '469'}
# sentence {'id': '3040'}
# sentence {'id': '513'}
# sentence {'id': '3011'}
# sentence {'id': '3454'}
# sentence {'id': '3248'}
# sentence {'id': '2058'}
# sentence {'id': '3291'}
# sentence {'id': '3190'}
# sentence {'id': '2693'}
# sentence {'id': '3127'}
# sentence {'id': '1998'}
# sentence {'id': '1904'}
# sentence {'id': '454'}
# sentence {'id': '772'}
# sentence {'id': '3676'}
# sentence {'id': '3667'}
# sentence {'id': '2520'}
# sentence {'id': '668'}
# sentence {'id': '1006'}
# sentence {'id': '2401'}
# sentence {'id': '3460'}
# sentence {'id': '1621'}
# sentence {'id': '2204'}
# sentence {'id': '2003'}
# sentence {'id': '1041'}
# sentence {'id': '1089'}
# sentence {'id': '1236'}
# sentence {'id': '3710'}
# sentence {'id': '663'}
# sentence {'id': '276'}
# sentence {'id': '1532'}
# sentence {'id': '1277'}
# sentence {'id': '222'}
# sentence {'id': '1509'}
# sentence {'id': '2220'}
# sentence {'id': '518'}
# sentence {'id': '2595'}
# sentence {'id': '2260'}
# sentence {'id': '2885'}
# sentence {'id': '2967'}
# sentence {'id': '3147'}
# sentence {'id': '2187'}
# sentence {'id': '3639'}
# sentence {'id': '2852'}
# sentence {'id': '221'}
# sentence {'id': '2913'}
# sentence {'id': '297'}
# sentence {'id': '2964'}
# sentence {'id': '2502'}
# sentence {'id': '28'}
# sentence {'id': '1654'}
# sentence {'id': '131'}
# sentence {'id': '3218'}
# sentence {'id': '1874'}
# sentence {'id': '616'}
# sentence {'id': '3611'}
# sentence {'id': '1580'}
# sentence {'id': '2924'}
# sentence {'id': '2414'}
# sentence {'id': '2218'}
# sentence {'id': '1436'}
# sentence {'id': '2279'}
# sentence {'id': '2975'}
# sentence {'id': '1568'}
# sentence {'id': '3496'}
# sentence {'id': '3084'}
# sentence {'id': '3033'}
# sentence {'id': '3321'}
# sentence {'id': '699'}
# sentence {'id': '3173'}
# sentence {'id': '1370'}
# sentence {'id': '3340'}
# sentence {'id': '3334'}
# sentence {'id': '2463'}
# sentence {'id': '2297'}
# sentence {'id': '1353'}
# sentence {'id': '3274'}
# sentence {'id': '2668'}
# sentence {'id': '2538'}
# sentence {'id': '3060'}
# sentence {'id': '2221'}
# sentence {'id': '2582'}
# sentence {'id': '2071'}
# sentence {'id': '1645'}
# sentence {'id': '2257'}
# sentence {'id': '743'}
# sentence {'id': '765'}
# sentence {'id': '2133'}
# sentence {'id': '1054'}
# sentence {'id': '1040'}
# sentence {'id': '2278'}
# sentence {'id': '1324'}
# sentence {'id': '1477'}
# sentence {'id': '3059'}
# sentence {'id': '2365'}
# sentence {'id': '264'}
# sentence {'id': '3525'}
# sentence {'id': '485'}
# sentence {'id': '731'}
# sentence {'id': '3025'}
# sentence {'id': '239'}
# sentence {'id': '2765'}
# sentence {'id': '686'}
# sentence {'id': '1564'}
# sentence {'id': '1069'}
# sentence {'id': '3118'}
# sentence {'id': '1814'}
# sentence {'id': '744'}
# sentence {'id': '1382'}
# sentence {'id': '3665'}
# sentence {'id': '1128'}
# sentence {'id': '780'}
# sentence {'id': '2819'}
# sentence {'id': '566'}
# sentence {'id': '2646'}
# sentence {'id': '1576'}
# sentence {'id': '3223'}
# sentence {'id': '3214'}
# sentence {'id': '3434'}
# sentence {'id': '2687'}
# sentence {'id': '2064'}
# sentence {'id': '1191'}
# sentence {'id': '626'}
# sentence {'id': '1673'}
# sentence {'id': '1706'}
# sentence {'id': '1879'}
# sentence {'id': '2637'}
# sentence {'id': '3623'}
# sentence {'id': '2420'}
# sentence {'id': '2605'}
# sentence {'id': '1415'}
# sentence {'id': '1421'}
# sentence {'id': '3660'}
# sentence {'id': '1945'}
# sentence {'id': '612'}
# sentence {'id': '44'}
# sentence {'id': '2916'}
# sentence {'id': '859'}
# sentence {'id': '855'}
# sentence {'id': '514'}
# sentence {'id': '750'}
# sentence {'id': '2645'}
# sentence {'id': '2267'}
# sentence {'id': '2453'}
# sentence {'id': '2193'}
# sentence {'id': '1392'}
# sentence {'id': '4'}
# sentence {'id': '240'}
# sentence {'id': '2030'}
# sentence {'id': '3000'}
# sentence {'id': '2842'}
# sentence {'id': '2005'}
# sentence {'id': '3239'}
# sentence {'id': '1660'}
# sentence {'id': '1145'}
# sentence {'id': '2855'}
# sentence {'id': '652'}
# sentence {'id': '2774'}
# sentence {'id': '1575'}
# sentence {'id': '2908'}
# sentence {'id': '423'}
# sentence {'id': '1608'}
# sentence {'id': '835'}
# sentence {'id': '1431'}
# sentence {'id': '377'}
# sentence {'id': '3222'}
# sentence {'id': '125'}
# sentence {'id': '3342'}
# sentence {'id': '2808'}
# sentence {'id': '1298'}
# sentence {'id': '2183'}
# sentence {'id': '2841'}
# sentence {'id': '1418'}
# sentence {'id': '2208'}
# sentence {'id': '287'}
# sentence {'id': '814'}
# sentence {'id': '3112'}
# sentence {'id': '2413'}
# sentence {'id': '3435'}
# sentence {'id': '914'}
# sentence {'id': '2695'}
# sentence {'id': '664'}
# sentence {'id': '1644'}
# sentence {'id': '2036'}
# sentence {'id': '1880'}
# sentence {'id': '2101'}
# sentence {'id': '2113'}
# sentence {'id': '1822'}
# sentence {'id': '2537'}
# sentence {'id': '1594'}
# sentence {'id': '3459'}
# sentence {'id': '3572'}
# sentence {'id': '845'}
# sentence {'id': '3004'}
# sentence {'id': '2441'}
# sentence {'id': '965'}
# sentence {'id': '1327'}
# sentence {'id': '1615'}
# sentence {'id': '2681'}
# sentence {'id': '3361'}
# sentence {'id': '789'}
# sentence {'id': '782'}
# sentence {'id': '3148'}
# sentence {'id': '2203'}
# sentence {'id': '3661'}
# sentence {'id': '1403'}
# sentence {'id': '3682'}
# sentence {'id': '2727'}
# sentence {'id': '2293'}
# sentence {'id': '2119'}
# sentence {'id': '205'}
# sentence {'id': '655'}
# sentence {'id': '2092'}
# sentence {'id': '749'}
# sentence {'id': '132'}
# sentence {'id': '3176'}
# sentence {'id': '367'}
# sentence {'id': '3397'}
# sentence {'id': '3382'}
# sentence {'id': '2850'}
# sentence {'id': '708'}
# sentence {'id': '978'}
# sentence {'id': '1029'}
# sentence {'id': '3470'}
# sentence {'id': '3034'}
# sentence {'id': '3180'}
# sentence {'id': '163'}
# sentence {'id': '1017'}
# sentence {'id': '3277'}
# sentence {'id': '757'}
# sentence {'id': '923'}
# sentence {'id': '472'}
# sentence {'id': '2223'}
# sentence {'id': '849'}
# sentence {'id': '1035'}
# sentence {'id': '3196'}
# sentence {'id': '1339'}
# sentence {'id': '3131'}
# sentence {'id': '3649'}
# sentence {'id': '1140'}
# sentence {'id': '2337'}
# sentence {'id': '1174'}
# sentence {'id': '3474'}
# sentence {'id': '2818'}
# sentence {'id': '2920'}
# sentence {'id': '162'}
# sentence {'id': '1216'}
# sentence {'id': '3530'}
# sentence {'id': '951'}
# sentence {'id': '1005'}
# sentence {'id': '1619'}
# sentence {'id': '1304'}
# sentence {'id': '1856'}
# sentence {'id': '3318'}
# sentence {'id': '1335'}
# sentence {'id': '2545'}
# sentence {'id': '1821'}
# sentence {'id': '880'}
# sentence {'id': '401'}
# sentence {'id': '1238'}
# sentence {'id': '889'}
# sentence {'id': '21'}
# sentence {'id': '2944'}
# sentence {'id': '3298'}
# sentence {'id': '1344'}
# sentence {'id': '1381'}
# sentence {'id': '581'}
# sentence {'id': '3658'}
# sentence {'id': '1840'}
# sentence {'id': '2702'}
# sentence {'id': '3536'}
# sentence {'id': '1363'}
# sentence {'id': '1065'}
# sentence {'id': '2137'}
# sentence {'id': '2884'}
# sentence {'id': '2075'}
# sentence {'id': '3238'}
# sentence {'id': '558'}
# sentence {'id': '3597'}
# sentence {'id': '1099'}
# sentence {'id': '169'}
# sentence {'id': '2042'}
# sentence {'id': '1603'}
# sentence {'id': '1114'}
# sentence {'id': '233'}
# sentence {'id': '1832'}
# sentence {'id': '3276'}
# sentence {'id': '960'}
# sentence {'id': '3555'}
# sentence {'id': '2863'}
# sentence {'id': '2477'}
# sentence {'id': '1095'}
# sentence {'id': '696'}
# sentence {'id': '62'}
# sentence {'id': '768'}
# sentence {'id': '3636'}
# sentence {'id': '3695'}
# sentence {'id': '3256'}
# sentence {'id': '211'}
# sentence {'id': '524'}
# sentence {'id': '801'}
# sentence {'id': '3431'}
# sentence {'id': '266'}
# sentence {'id': '1986'}
# sentence {'id': '1240'}
# sentence {'id': '955'}
# sentence {'id': '1787'}
# sentence {'id': '682'}
# sentence {'id': '2131'}
# sentence {'id': '2349'}
# sentence {'id': '2485'}
# sentence {'id': '2412'}
# sentence {'id': '2647'}
# sentence {'id': '2311'}
# sentence {'id': '714'}
# sentence {'id': '3057'}
# sentence {'id': '3002'}
# sentence {'id': '2616'}
# sentence {'id': '2969'}
# sentence {'id': '1147'}
# sentence {'id': '3521'}
# sentence {'id': '2410'}
# sentence {'id': '2099'}
# sentence {'id': '2792'}
# sentence {'id': '3206'}
# sentence {'id': '837'}
# sentence {'id': '1244'}
# sentence {'id': '1343'}
# sentence {'id': '348'}
# sentence {'id': '1956'}
# sentence {'id': '2039'}
# sentence {'id': '2990'}
# sentence {'id': '2135'}
# sentence {'id': '1779'}
# sentence {'id': '142'}
# sentence {'id': '2768'}
# sentence {'id': '812'}
# sentence {'id': '218'}
# sentence {'id': '91'}
# sentence {'id': '2970'}
# sentence {'id': '1004'}
# sentence {'id': '1204'}
# sentence {'id': '811'}
# sentence {'id': '2239'}
# sentence {'id': '3493'}
# sentence {'id': '503'}
# sentence {'id': '2094'}
# sentence {'id': '3236'}
# sentence {'id': '1606'}
# sentence {'id': '1307'}
# sentence {'id': '300'}
# sentence {'id': '2334'}
# sentence {'id': '2079'}
# sentence {'id': '2602'}
# sentence {'id': '1424'}
# sentence {'id': '1294'}
# sentence {'id': '2361'}
# sentence {'id': '316'}
# sentence {'id': '1393'}
# sentence {'id': '3182'}
# sentence {'id': '1317'}
# sentence {'id': '1213'}
# sentence {'id': '1281'}
# sentence {'id': '1537'}
# sentence {'id': '2262'}
# sentence {'id': '3456'}
# sentence {'id': '1738'}
# sentence {'id': '1081'}
# sentence {'id': '1117'}
# sentence {'id': '306'}
# sentence {'id': '2112'}
# sentence {'id': '94'}
# sentence {'id': '1015'}
# sentence {'id': '1901'}
# sentence {'id': '2422'}
# sentence {'id': '200'}
# sentence {'id': '1607'}
# sentence {'id': '2771'}
# sentence {'id': '1400'}
# sentence {'id': '1019'}
# sentence {'id': '2793'}
# sentence {'id': '2332'}
# sentence {'id': '215'}
# sentence {'id': '58'}
# sentence {'id': '536'}
# sentence {'id': '869'}
# sentence {'id': '2961'}
# sentence {'id': '1355'}
# sentence {'id': '2085'}
# sentence {'id': '1173'}
# sentence {'id': '1470'}
# sentence {'id': '2457'}
# sentence {'id': '505'}
# sentence {'id': '842'}
# sentence {'id': '1595'}
# sentence {'id': '2150'}
# sentence {'id': '2443'}
# sentence {'id': '3706'}
# sentence {'id': '2010'}
# sentence {'id': '3064'}
# sentence {'id': '3483'}
# sentence {'id': '1719'}
# sentence {'id': '2442'}
# sentence {'id': '3101'}
# sentence {'id': '542'}
# sentence {'id': '255'}
# sentence {'id': '828'}
# sentence {'id': '3553'}
# sentence {'id': '315'}
# sentence {'id': '2587'}
# sentence {'id': '3282'}
# sentence {'id': '1883'}
# sentence {'id': '2219'}
# sentence {'id': '666'}
# sentence {'id': '1910'}
# sentence {'id': '1018'}
# sentence {'id': '39'}
# sentence {'id': '2247'}
# sentence {'id': '2458'}
# sentence {'id': '2689'}
# sentence {'id': '1959'}
# sentence {'id': '2282'}
# sentence {'id': '2943'}
# sentence {'id': '3228'}
# sentence {'id': '1837'}
# sentence {'id': '2333'}
# sentence {'id': '1296'}
# sentence {'id': '1842'}
# sentence {'id': '2245'}
# sentence {'id': '2028'}
# sentence {'id': '2810'}
# sentence {'id': '3293'}
# sentence {'id': '1916'}
# sentence {'id': '343'}
# sentence {'id': '165'}
# sentence {'id': '2508'}
# sentence {'id': '3659'}
# sentence {'id': '3114'}
# sentence {'id': '492'}
# sentence {'id': '1886'}
# sentence {'id': '3512'}
# sentence {'id': '538'}
# sentence {'id': '3156'}
# sentence {'id': '1947'}
# sentence {'id': '1929'}
# sentence {'id': '740'}
# sentence {'id': '2736'}
# sentence {'id': '669'}
# sentence {'id': '677'}
# sentence {'id': '2551'}
# sentence {'id': '2797'}
# sentence {'id': '409'}
# sentence {'id': '3442'}
# sentence {'id': '2878'}
# sentence {'id': '158'}
# sentence {'id': '3186'}
# sentence {'id': '654'}
# sentence {'id': '52'}
# sentence {'id': '2125'}
# sentence {'id': '3371'}
# sentence {'id': '2115'}
# sentence {'id': '1546'}
# sentence {'id': '753'}
# sentence {'id': '2560'}
# sentence {'id': '3165'}
# sentence {'id': '2601'}
# sentence {'id': '3505'}
# sentence {'id': '1747'}
# sentence {'id': '1481'}
# sentence {'id': '1767'}
# sentence {'id': '634'}
# sentence {'id': '3058'}
# sentence {'id': '968'}
# sentence {'id': '2300'}
# sentence {'id': '2136'}
# sentence {'id': '1039'}
# sentence {'id': '3138'}
# sentence {'id': '2722'}
# sentence {'id': '1547'}
# sentence {'id': '2597'}
# sentence {'id': '1740'}
# sentence {'id': '715'}
# sentence {'id': '2160'}
# sentence {'id': '3437'}
# sentence {'id': '939'}
# sentence {'id': '3140'}
# sentence {'id': '1714'}
# sentence {'id': '337'}
# sentence {'id': '2027'}
# sentence {'id': '595'}
# sentence {'id': '256'}
# sentence {'id': '764'}
# sentence {'id': '1375'}
# sentence {'id': '613'}
# sentence {'id': '1329'}
# sentence {'id': '3198'}
# sentence {'id': '623'}
# sentence {'id': '3325'}
# sentence {'id': '294'}
# sentence {'id': '3375'}
# sentence {'id': '3304'}
# sentence {'id': '3608'}
# sentence {'id': '3203'}
# sentence {'id': '3640'}
# sentence {'id': '3499'}
# sentence {'id': '694'}
# sentence {'id': '831'}
# sentence {'id': '271'}
# sentence {'id': '2677'}
# sentence {'id': '844'}
# sentence {'id': '551'}
# sentence {'id': '3709'}
# sentence {'id': '386'}
# sentence {'id': '1704'}
# sentence {'id': '1196'}
# sentence {'id': '3689'}
# sentence {'id': '1379'}
# sentence {'id': '2142'}
# sentence {'id': '3472'}
# sentence {'id': '2372'}
# sentence {'id': '3561'}
# sentence {'id': '16'}
# sentence {'id': '2253'}
# sentence {'id': '3425'}
# sentence {'id': '2698'}
# sentence {'id': '2496'}
# sentence {'id': '124'}
# sentence {'id': '2600'}
# sentence {'id': '630'}
# sentence {'id': '267'}
# sentence {'id': '1804'}
# sentence {'id': '2657'}
# sentence {'id': '920'}
# sentence {'id': '2976'}
# sentence {'id': '2408'}
# sentence {'id': '2237'}
# sentence {'id': '304'}
# sentence {'id': '3225'}
# sentence {'id': '3154'}
# sentence {'id': '2348'}
# sentence {'id': '2971'}
# sentence {'id': '921'}
# sentence {'id': '532'}
# sentence {'id': '1972'}
# sentence {'id': '553'}
# sentence {'id': '1681'}
# sentence {'id': '2586'}
# sentence {'id': '1734'}
# sentence {'id': '2558'}
# sentence {'id': '1522'}
# sentence {'id': '3683'}
# sentence {'id': '2715'}
# sentence {'id': '760'}
# sentence {'id': '120'}
# sentence {'id': '2295'}
# sentence {'id': '3513'}
# sentence {'id': '2880'}
# sentence {'id': '2034'}
# sentence {'id': '3299'}
# sentence {'id': '1208'}
# sentence {'id': '2148'}
# sentence {'id': '2192'}
# sentence {'id': '2020'}
# sentence {'id': '915'}
# sentence {'id': '1768'}
# sentence {'id': '302'}
# sentence {'id': '3052'}
# sentence {'id': '2956'}
# sentence {'id': '569'}
# sentence {'id': '658'}
# sentence {'id': '1664'}
# sentence {'id': '3690'}
# sentence {'id': '1274'}
# sentence {'id': '481'}
# sentence {'id': '2827'}
# sentence {'id': '1585'}
# sentence {'id': '2163'}
# sentence {'id': '3443'}
# sentence {'id': '2108'}
# sentence {'id': '3452'}
# sentence {'id': '412'}
# sentence {'id': '3675'}
# sentence {'id': '2154'}
# sentence {'id': '223'}
# sentence {'id': '1667'}
# sentence {'id': '426'}
# sentence {'id': '1964'}
# sentence {'id': '3380'}
# sentence {'id': '3185'}
# sentence {'id': '2651'}
# sentence {'id': '718'}
# sentence {'id': '2848'}
# sentence {'id': '596'}
# sentence {'id': '523'}
# sentence {'id': '1497'}
# sentence {'id': '2861'}
# sentence {'id': '2697'}
# sentence {'id': '876'}
# sentence {'id': '248'}
# sentence {'id': '1116'}
# sentence {'id': '3001'}
# sentence {'id': '1058'}
# sentence {'id': '2067'}
# sentence {'id': '2491'}
# sentence {'id': '2703'}
# sentence {'id': '1045'}
# sentence {'id': '2895'}
# sentence {'id': '59'}
# sentence {'id': '1650'}
# sentence {'id': '1432'}
# sentence {'id': '1527'}
# sentence {'id': '1926'}
# sentence {'id': '1835'}
# sentence {'id': '208'}
# sentence {'id': '1023'}
# sentence {'id': '85'}
# sentence {'id': '2388'}
# sentence {'id': '609'}
# sentence {'id': '3417'}
# sentence {'id': '602'}
# sentence {'id': '909'}
# sentence {'id': '488'}
# sentence {'id': '804'}
# sentence {'id': '1153'}
# sentence {'id': '769'}
# sentence {'id': '3026'}
# sentence {'id': '661'}
# sentence {'id': '1437'}
# sentence {'id': '2532'}
# sentence {'id': '1062'}
# sentence {'id': '552'}
# sentence {'id': '1953'}
# sentence {'id': '1722'}
# sentence {'id': '1218'}
# sentence {'id': '509'}
# sentence {'id': '2318'}
# sentence {'id': '2676'}
# sentence {'id': '1965'}
# sentence {'id': '597'}
# sentence {'id': '3317'}
# sentence {'id': '1745'}
# sentence {'id': '3527'}
# sentence {'id': '1387'}
# sentence {'id': '3629'}
# sentence {'id': '2168'}
# sentence {'id': '3023'}
# sentence {'id': '594'}
# sentence {'id': '1587'}
# sentence {'id': '2620'}
# sentence {'id': '3106'}
# sentence {'id': '262'}
# sentence {'id': '606'}
# sentence {'id': '2871'}
# sentence {'id': '46'}
# sentence {'id': '656'}
# sentence {'id': '1301'}
# sentence {'id': '1559'}
# sentence {'id': '3648'}
# sentence {'id': '3705'}
# sentence {'id': '1051'}
# sentence {'id': '3539'}
# sentence {'id': '1648'}
# sentence {'id': '3134'}
# sentence {'id': '2643'}
# sentence {'id': '1655'}
# sentence {'id': '1935'}
# sentence {'id': '1254'}
# sentence {'id': '3021'}
# sentence {'id': '1665'}
# sentence {'id': '2432'}
# sentence {'id': '2230'}
# sentence {'id': '2381'}
# sentence {'id': '574'}
# sentence {'id': '625'}
# sentence {'id': '1484'}
# sentence {'id': '3229'}
# sentence {'id': '1852'}
# sentence {'id': '3053'}
# sentence {'id': '3630'}
# sentence {'id': '2070'}
# sentence {'id': '2788'}
# sentence {'id': '2671'}
# sentence {'id': '3618'}
# sentence {'id': '335'}
# sentence {'id': '2416'}
# sentence {'id': '1845'}
# sentence {'id': '3622'}
# sentence {'id': '149'}
# sentence {'id': '3571'}
# sentence {'id': '1765'}
# sentence {'id': '877'}
# sentence {'id': '2415'}
# sentence {'id': '3453'}
# sentence {'id': '1243'}
# sentence {'id': '8'}
# sentence {'id': '2670'}
# sentence {'id': '781'}
# sentence {'id': '258'}
# sentence {'id': '1713'}
# sentence {'id': '946'}
# sentence {'id': '697'}
# sentence {'id': '452'}
# sentence {'id': '303'}
# sentence {'id': '549'}
# sentence {'id': '982'}
# sentence {'id': '3354'}
# sentence {'id': '1323'}
# sentence {'id': '2899'}
# sentence {'id': '1831'}
# sentence {'id': '584'}
# sentence {'id': '2906'}
# sentence {'id': '3645'}
# sentence {'id': '3048'}
# sentence {'id': '1322'}
# sentence {'id': '2089'}
# sentence {'id': '184'}
# sentence {'id': '3697'}
# sentence {'id': '2364'}
# sentence {'id': '1573'}
# sentence {'id': '1328'}
# sentence {'id': '3588'}
# sentence {'id': '2082'}
# sentence {'id': '1482'}
# sentence {'id': '1372'}
# sentence {'id': '1602'}
# sentence {'id': '873'}
# sentence {'id': '1473'}
# sentence {'id': '929'}
# sentence {'id': '2738'}
# sentence {'id': '1675'}
# sentence {'id': '321'}
# sentence {'id': '249'}
# sentence {'id': '3646'}
# sentence {'id': '3220'}
# sentence {'id': '2395'}
# sentence {'id': '2746'}
# sentence {'id': '2718'}
# sentence {'id': '2063'}
# sentence {'id': '2691'}
# sentence {'id': '350'}
# sentence {'id': '2892'}
# sentence {'id': '3227'}
# sentence {'id': '1692'}
# sentence {'id': '3684'}
# sentence {'id': '3556'}
# sentence {'id': '2104'}
# sentence {'id': '3612'}
# sentence {'id': '2037'}
# sentence {'id': '693'}
# sentence {'id': '2634'}
# sentence {'id': '3184'}
# sentence {'id': '2752'}
# sentence {'id': '519'}
# sentence {'id': '2369'}
# sentence {'id': '379'}
# sentence {'id': '726'}
# sentence {'id': '3005'}
# sentence {'id': '3490'}
# sentence {'id': '3035'}
# sentence {'id': '1068'}
# sentence {'id': '2233'}
# sentence {'id': '905'}
# sentence {'id': '2965'}
# sentence {'id': '2405'}
# sentence {'id': '1730'}
# sentence {'id': '1120'}
# sentence {'id': '1193'}
# sentence {'id': '3314'}
# sentence {'id': '1889'}
# sentence {'id': '2286'}
# sentence {'id': '3516'}
# sentence {'id': '2799'}
# sentence {'id': '1126'}
# sentence {'id': '1783'}
# sentence {'id': '1668'}
# sentence {'id': '3264'}
# sentence {'id': '2922'}
# sentence {'id': '2506'}
# sentence {'id': '2641'}
# sentence {'id': '497'}
# sentence {'id': '422'}
# sentence {'id': '1357'}
# sentence {'id': '1670'}
# sentence {'id': '122'}
# sentence {'id': '2054'}
# sentence {'id': '189'}
# sentence {'id': '1941'}
# sentence {'id': '1410'}
# sentence {'id': '1488'}
# sentence {'id': '2190'}
# sentence {'id': '2653'}
# sentence {'id': '2973'}
# sentence {'id': '365'}
# sentence {'id': '136'}
# sentence {'id': '2236'}
# sentence {'id': '274'}
# sentence {'id': '2483'}
# sentence {'id': '1096'}
# sentence {'id': '261'}
# sentence {'id': '2366'}
# sentence {'id': '2331'}
# sentence {'id': '3275'}
# sentence {'id': '3232'}
# sentence {'id': '1591'}
# sentence {'id': '2240'}
# sentence {'id': '799'}
# sentence {'id': '2923'}
# sentence {'id': '854'}
# sentence {'id': '2854'}
# sentence {'id': '3392'}
# sentence {'id': '592'}
# sentence {'id': '1844'}
# sentence {'id': '2859'}
# sentence {'id': '2431'}
# sentence {'id': '2999'}
# sentence {'id': '741'}
# sentence {'id': '775'}
# sentence {'id': '800'}
# sentence {'id': '896'}
# sentence {'id': '446'}
# sentence {'id': '2958'}
# sentence {'id': '1618'}
# sentence {'id': '2254'}
# sentence {'id': '894'}
# sentence {'id': '1800'}
# sentence {'id': '3253'}
# sentence {'id': '2411'}
# sentence {'id': '3139'}
# sentence {'id': '2667'}
# sentence {'id': '1002'}
# sentence {'id': '1181'}
# sentence {'id': '1052'}
# sentence {'id': '2832'}
# sentence {'id': '265'}
# sentence {'id': '1739'}
# sentence {'id': '2057'}
# sentence {'id': '1113'}
# sentence {'id': '883'}
# sentence {'id': '834'}
# sentence {'id': '1968'}
# sentence {'id': '237'}
# sentence {'id': '1583'}
# sentence {'id': '2370'}
# sentence {'id': '2638'}
# sentence {'id': '838'}
# sentence {'id': '3377'}
# sentence {'id': '2886'}
# sentence {'id': '2753'}
# sentence {'id': '891'}
# sentence {'id': '1469'}
# sentence {'id': '3565'}
# sentence {'id': '347'}
# sentence {'id': '1841'}
# sentence {'id': '1691'}
# sentence {'id': '1545'}
# ...
# sentence {'id': '1795'}
# sentence {'id': '2992'}
# sentence {'id': '3438'}
# sentence {'id': '1276'}
# sentence {'id': '730'}
# sentence {'id': '1870'}
# sentence {'id': '2367'}
# sentence {'id': '1519'}
# sentence {'id': '2904'}
# sentence {'id': '1009'}
# sentence {'id': '2642'}
# sentence {'id': '43'}
# sentence {'id': '1460'}
# sentence {'id': '307'}
# sentence {'id': '860'}
# sentence {'id': '2594'}
# sentence {'id': '607'}
# sentence {'id': '1338'}
# sentence {'id': '1625'}
# sentence {'id': '2665'}
# sentence {'id': '2095'}
# sentence {'id': '989'}
# sentence {'id': '1803'}
# sentence {'id': '3047'}
# sentence {'id': '850'}
# sentence {'id': '2993'}
# sentence {'id': '2596'}
# sentence {'id': '3602'}
# sentence {'id': '3108'}
# sentence {'id': '3439'}
# sentence {'id': '1604'}
# sentence {'id': '1440'}
# sentence {'id': '101'}
# sentence {'id': '351'}
# sentence {'id': '2009'}
# sentence {'id': '988'}
# sentence {'id': '2963'}
# sentence {'id': '3412'}
# sentence {'id': '1311'}
# sentence {'id': '246'}
# sentence {'id': '1771'}
# sentence {'id': '1913'}
# sentence {'id': '1394'}
# sentence {'id': '226'}
# sentence {'id': '3642'}
# sentence {'id': '2159'}
# sentence {'id': '1708'}
# sentence {'id': '593'}
# sentence {'id': '230'}
# sentence {'id': '1061'}
# sentence {'id': '3136'}
# sentence {'id': '947'}
# sentence {'id': '1514'}
# sentence {'id': '3187'}
# sentence {'id': '1906'}
# sentence {'id': '2700'}
# sentence {'id': '2781'}
# sentence {'id': '15'}
# sentence {'id': '1970'}
# sentence {'id': '2942'}
# sentence {'id': '2465'}
# sentence {'id': '2038'}
# sentence {'id': '186'}
# sentence {'id': '2127'}
# sentence {'id': '130'}
# sentence {'id': '702'}
# sentence {'id': '3510'}
# sentence {'id': '3030'}
# sentence {'id': '1320'}
# sentence {'id': '328'}
# sentence {'id': '512'}
# sentence {'id': '3019'}
# sentence {'id': '1683'}
# sentence {'id': '195'}
# sentence {'id': '2623'}
# sentence {'id': '1974'}
# sentence {'id': '959'}
# sentence {'id': '419'}
# sentence {'id': '2172'}
# sentence {'id': '3518'}
# sentence {'id': '1171'}
# sentence {'id': '1518'}
# sentence {'id': '941'}
# sentence {'id': '2898'}
# sentence {'id': '1960'}
# sentence {'id': '706'}
# sentence {'id': '214'}
# sentence {'id': '1285'}
# sentence {'id': '560'}
# sentence {'id': '2461'}
# sentence {'id': '3022'}
# sentence {'id': '2065'}
# sentence {'id': '2468'}
# sentence {'id': '3558'}
# sentence {'id': '3063'}
# sentence {'id': '1977'}
# sentence {'id': '87'}
# sentence {'id': '2499'}
# sentence {'id': '2093'}
# sentence {'id': '2153'}
# sentence {'id': '721'}
# sentence {'id': '1156'}
# sentence {'id': '2409'}
# sentence {'id': '3233'}
# sentence {'id': '2359'}
# sentence {'id': '3545'}
# sentence {'id': '2968'}
# sentence {'id': '210'}
# sentence {'id': '382'}
# sentence {'id': '1715'}
# sentence {'id': '1517'}
# sentence {'id': '611'}
# sentence {'id': '2379'}
# sentence {'id': '1643'}
# sentence {'id': '2305'}
# sentence {'id': '2989'}
# sentence {'id': '848'}
# sentence {'id': '2156'}
# sentence {'id': '1966'}
# sentence {'id': '2088'}
# sentence {'id': '1150'}
# sentence {'id': '185'}
# sentence {'id': '1710'}
# sentence {'id': '2610'}
# sentence {'id': '649'}
# sentence {'id': '3450'}
# sentence {'id': '974'}
# sentence {'id': '3089'}
# sentence {'id': '647'}
# sentence {'id': '2954'}
# sentence {'id': '378'}
# sentence {'id': '490'}
# sentence {'id': '3245'}
# sentence {'id': '1426'}
# sentence {'id': '1992'}
# sentence {'id': '414'}
# sentence {'id': '1857'}
# sentence {'id': '164'}
# sentence {'id': '1480'}
# sentence {'id': '904'}
# sentence {'id': '3094'}
# sentence {'id': '1717'}
# sentence {'id': '3663'}
# sentence {'id': '3250'}
# sentence {'id': '3366'}
# sentence {'id': '3073'}
# sentence {'id': '3303'}
# sentence {'id': '1299'}
# sentence {'id': '704'}
# sentence {'id': '2488'}
# sentence {'id': '1839'}
# sentence {'id': '1756'}
# sentence {'id': '29'}
# sentence {'id': '484'}
# sentence {'id': '1993'}
# sentence {'id': '2574'}
# sentence {'id': '3595'}
# sentence {'id': '1097'}
# sentence {'id': '2844'}
# sentence {'id': '2692'}
# sentence {'id': '2590'}
# sentence {'id': '71'}
# sentence {'id': '1584'}
# sentence {'id': '2957'}
# sentence {'id': '2235'}
# sentence {'id': '3633'}
# sentence {'id': '2696'}
# sentence {'id': '1186'}
# sentence {'id': '3224'}
# sentence {'id': '1154'}
# sentence {'id': '935'}
# sentence {'id': '3306'}
# sentence {'id': '2312'}
# sentence {'id': '1742'}
# sentence {'id': '3355'}
# sentence {'id': '331'}
# sentence {'id': '637'}
# sentence {'id': '2029'}
# sentence {'id': '2258'}
# sentence {'id': '2341'}
# sentence {'id': '679'}
# sentence {'id': '2004'}
# sentence {'id': '644'}
# sentence {'id': '2007'}
# sentence {'id': '723'}
# sentence {'id': '314'}
# sentence {'id': '3107'}
# sentence {'id': '580'}
# sentence {'id': '1295'}
# sentence {'id': '1590'}
# sentence {'id': '2701'}
# sentence {'id': '2514'}
# sentence {'id': '997'}
# sentence {'id': '470'}
# sentence {'id': '2730'}
# sentence {'id': '1491'}
# sentence {'id': '1001'}
# sentence {'id': '906'}
# sentence {'id': '758'}
# sentence {'id': '1601'}
# sentence {'id': '2877'}
# sentence {'id': '2195'}
# sentence {'id': '1917'}
# sentence {'id': '1796'}
# sentence {'id': '2252'}
# sentence {'id': '3679'}
# sentence {'id': '3668'}
# sentence {'id': '928'}
# sentence {'id': '1794'}
# sentence {'id': '3652'}
# sentence {'id': '2853'}
# sentence {'id': '1163'}
# sentence {'id': '216'}
# sentence {'id': '1109'}
# sentence {'id': '899'}
# sentence {'id': '1349'}
# sentence {'id': '934'}
# sentence {'id': '2199'}
# sentence {'id': '188'}
# sentence {'id': '1748'}
# sentence {'id': '949'}
# sentence {'id': '390'}
# sentence {'id': '885'}
# sentence {'id': '1428'}
# sentence {'id': '826'}
# sentence {'id': '1053'}
# sentence {'id': '1639'}
# sentence {'id': '1417'}
# sentence {'id': '3159'}
# sentence {'id': '190'}
# sentence {'id': '363'}
# sentence {'id': '2856'}
# sentence {'id': '1811'}
# sentence {'id': '1030'}
# sentence {'id': '2838'}
# sentence {'id': '3149'}
# sentence {'id': '2780'}
# sentence {'id': '1782'}
# sentence {'id': '403'}
# sentence {'id': '3696'}
# sentence {'id': '3419'}
# sentence {'id': '468'}
# sentence {'id': '2876'}
# sentence {'id': '2655'}
# sentence {'id': '3570'}
# sentence {'id': '2129'}
# sentence {'id': '206'}
# sentence {'id': '3038'}
# sentence {'id': '3365'}
# sentence {'id': '3708'}
# sentence {'id': '2068'}
# sentence {'id': '1102'}
# sentence {'id': '2742'}
# sentence {'id': '278'}
# sentence {'id': '3183'}
# sentence {'id': '817'}
# sentence {'id': '353'}
# sentence {'id': '1932'}
# sentence {'id': '213'}
# sentence {'id': '2214'}
# sentence {'id': '2261'}
# sentence {'id': '2772'}
# sentence {'id': '3458'}
# sentence {'id': '2979'}
# sentence {'id': '3344'}
# sentence {'id': '2399'}
# sentence {'id': '3520'}
# sentence {'id': '2263'}
# sentence {'id': '1902'}
# sentence {'id': '341'}
# sentence {'id': '1649'}
# sentence {'id': '1195'}
# sentence {'id': '3247'}
# sentence {'id': '1693'}
# sentence {'id': '1496'}
# sentence {'id': '918'}
# sentence {'id': '1653'}
# sentence {'id': '2387'}
# sentence {'id': '3326'}
# sentence {'id': '3388'}
# sentence {'id': '2382'}
# sentence {'id': '517'}
# sentence {'id': '1399'}
# sentence {'id': '3488'}
# sentence {'id': '2423'}
# sentence {'id': '3117'}
# sentence {'id': '992'}
# sentence {'id': '1024'}
# sentence {'id': '394'}
# sentence {'id': '1483'}
# sentence {'id': '2945'}
# sentence {'id': '3487'}
# sentence {'id': '1701'}
# sentence {'id': '464'}
# sentence {'id': '2779'}
# sentence {'id': '1086'}
# sentence {'id': '2539'}
# sentence {'id': '180'}
# sentence {'id': '2580'}
# sentence {'id': '3341'}
# sentence {'id': '722'}
# sentence {'id': '57'}
# sentence {'id': '832'}
# sentence {'id': '3685'}
# sentence {'id': '346'}
# sentence {'id': '2672'}
# sentence {'id': '295'}
# sentence {'id': '3296'}
# sentence {'id': '1231'}
# sentence {'id': '1676'}
# sentence {'id': '2547'}
# sentence {'id': '72'}
# sentence {'id': '3666'}
# sentence {'id': '2210'}
# sentence {'id': '1699'}
# sentence {'id': '147'}
# sentence {'id': '2051'}
# sentence {'id': '862'}
# sentence {'id': '1920'}
# sentence {'id': '3638'}
# sentence {'id': '54'}
# sentence {'id': '3088'}
# sentence {'id': '3364'}
# sentence {'id': '2083'}
# sentence {'id': '1245'}
# sentence {'id': '1411'}
# sentence {'id': '1566'}
# sentence {'id': '3617'}
# sentence {'id': '126'}
# sentence {'id': '1146'}
# sentence {'id': '1985'}
# sentence {'id': '2320'}
# sentence {'id': '2103'}
# sentence {'id': '2991'}
# sentence {'id': '2268'}
# sentence {'id': '3609'}
# sentence {'id': '2146'}
# sentence {'id': '2438'}
# sentence {'id': '2474'}
# sentence {'id': '1148'}
# sentence {'id': '2714'}
# sentence {'id': '3215'}
# sentence {'id': '3672'}
# sentence {'id': '2428'}
# sentence {'id': '1169'}
# sentence {'id': '2165'}
# sentence {'id': '3078'}
# sentence {'id': '1207'}
# sentence {'id': '182'}
# sentence {'id': '827'}
# sentence {'id': '1416'}
# sentence {'id': '196'}
# sentence {'id': '1997'}
# sentence {'id': '192'}
# sentence {'id': '2748'}
# sentence {'id': '2407'}
# sentence {'id': '1818'}
# sentence {'id': '2145'}
# sentence {'id': '2635'}
# sentence {'id': '2614'}
# sentence {'id': '3072'}
# sentence {'id': '1718'}
# sentence {'id': '2207'}
# sentence {'id': '3095'}
# sentence {'id': '2002'}
# sentence {'id': '441'}
# sentence {'id': '2948'}
# sentence {'id': '474'}
# sentence {'id': '3662'}
# sentence {'id': '1165'}
# sentence {'id': '1669'}
# sentence {'id': '1816'}
# sentence {'id': '2471'}
# sentence {'id': '1192'}
# sentence {'id': '1373'}
# sentence {'id': '936'}
# sentence {'id': '2686'}
# sentence {'id': '1952'}
# sentence {'id': '917'}
# sentence {'id': '1325'}
# sentence {'id': '3016'}
# sentence {'id': '1297'}
# sentence {'id': '1528'}
# sentence {'id': '1162'}
# sentence {'id': '411'}
# sentence {'id': '2796'}
# sentence {'id': '3634'}
# sentence {'id': '822'}
# sentence {'id': '2256'}
# sentence {'id': '2321'}
# sentence {'id': '3289'}
# sentence {'id': '2611'}
# sentence {'id': '1716'}
# sentence {'id': '1003'}
# sentence {'id': '1614'}
# sentence {'id': '2109'}
# sentence {'id': '867'}
# sentence {'id': '508'}
# sentence {'id': '1177'}
# sentence {'id': '1187'}
# sentence {'id': '650'}
# sentence {'id': '313'}
# sentence {'id': '785'}
# sentence {'id': '665'}
# sentence {'id': '140'}
# sentence {'id': '1168'}
# sentence {'id': '3162'}
# sentence {'id': '1289'}
# sentence {'id': '3242'}
# sentence {'id': '3526'}
# sentence {'id': '969'}
# sentence {'id': '407'}
# sentence {'id': '1507'}
# sentence {'id': '922'}
# sentence {'id': '1060'}
# sentence {'id': '352'}
# sentence {'id': '888'}
# sentence {'id': '2121'}
# sentence {'id': '559'}
# sentence {'id': '1302'}
# sentence {'id': '3262'}
# sentence {'id': '588'}
# sentence {'id': '2289'}
# sentence {'id': '527'}
# sentence {'id': '2478'}
# sentence {'id': '945'}
# sentence {'id': '1642'}
# sentence {'id': '1766'}
# sentence {'id': '2275'}
# sentence {'id': '1233'}
# sentence {'id': '2573'}
# sentence {'id': '2323'}
# sentence {'id': '413'}
# sentence {'id': '2281'}
# sentence {'id': '983'}
# sentence {'id': '2928'}
# sentence {'id': '2571'}
# sentence {'id': '2122'}
# sentence {'id': '659'}
# sentence {'id': '2350'}
# sentence {'id': '1119'}
# sentence {'id': '1158'}
# sentence {'id': '220'}
# sentence {'id': '2285'}
# sentence {'id': '3254'}
# sentence {'id': '1351'}
# sentence {'id': '2216'}
# sentence {'id': '1467'}
# sentence {'id': '555'}
# sentence {'id': '970'}
# sentence {'id': '3506'}
# sentence {'id': '1123'}
# sentence {'id': '2314'}
# sentence {'id': '397'}
# sentence {'id': '1395'}
# sentence {'id': '2246'}
# sentence {'id': '60'}
# sentence {'id': '2987'}
# sentence {'id': '463'}
# sentence {'id': '3457'}
# sentence {'id': '3473'}
# sentence {'id': '938'}
# sentence {'id': '3177'}
# sentence {'id': '2931'}
# sentence {'id': '3017'}
# sentence {'id': '1366'}
# sentence {'id': '1613'}
# sentence {'id': '2309'}
# sentence {'id': '1905'}
# sentence {'id': '2785'}
# sentence {'id': '1946'}
# sentence {'id': '1638'}
# sentence {'id': '2472'}
# sentence {'id': '544'}
# sentence {'id': '260'}
# sentence {'id': '3482'}
# sentence {'id': '695'}
# sentence {'id': '2807'}
# sentence {'id': '3120'}
# sentence {'id': '3590'}
# sentence {'id': '1534'}
# sentence {'id': '1778'}
# sentence {'id': '3071'}
# sentence {'id': '47'}
# sentence {'id': '2995'}
# sentence {'id': '2215'}
# sentence {'id': '2100'}
# sentence {'id': '479'}
# sentence {'id': '3379'}
# sentence {'id': '1733'}
# sentence {'id': '1885'}
# sentence {'id': '1358'}
# sentence {'id': '3533'}
# sentence {'id': '2389'}
# sentence {'id': '3087'}
# sentence {'id': '2847'}
# sentence {'id': '418'}
# sentence {'id': '871'}
# sentence {'id': '1556'}
# sentence {'id': '355'}
# sentence {'id': '3266'}
# sentence {'id': '966'}
# sentence {'id': '980'}
# sentence {'id': '167'}
# sentence {'id': '2546'}
# sentence {'id': '937'}
# sentence {'id': '2712'}
# sentence {'id': '1170'}
# sentence {'id': '3043'}
# sentence {'id': '41'}
# sentence {'id': '3677'}
# sentence {'id': '1485'}
# sentence {'id': '42'}
# sentence {'id': '1326'}
# sentence {'id': '2400'}
# sentence {'id': '3171'}
# sentence {'id': '2998'}
# sentence {'id': '1627'}
# sentence {'id': '739'}
# sentence {'id': '2492'}
# sentence {'id': '2198'}
# sentence {'id': '2390'}
# sentence {'id': '3467'}
# sentence {'id': '334'}
# sentence {'id': '1558'}
# sentence {'id': '913'}
# sentence {'id': '3003'}
# sentence {'id': '3583'}
# sentence {'id': '3581'}
# sentence {'id': '2435'}
# sentence {'id': '3704'}
# sentence {'id': '3200'}
# sentence {'id': '943'}
# sentence {'id': '2516'}
# sentence {'id': '3428'}
# sentence {'id': '3647'}
# sentence {'id': '784'}
# sentence {'id': '1540'}
# sentence {'id': '1980'}
# sentence {'id': '292'}
# sentence {'id': '774'}
# sentence {'id': '687'}
# sentence {'id': '732'}
# sentence {'id': '1508'}
# sentence {'id': '705'}
# sentence {'id': '1610'}
# sentence {'id': '3479'}
# sentence {'id': '1139'}
# sentence {'id': '1808'}
# sentence {'id': '2933'}
# sentence {'id': '2226'}
# sentence {'id': '2066'}
# sentence {'id': '3362'}
# sentence {'id': '2197'}
# sentence {'id': '547'}
# sentence {'id': '2782'}
# sentence {'id': '3046'}
# sentence {'id': '1398'}
# sentence {'id': '2406'}
# sentence {'id': '1178'}
# sentence {'id': '3625'}
# sentence {'id': '2652'}
# sentence {'id': '930'}
# sentence {'id': '2710'}
# sentence {'id': '444'}
# sentence {'id': '2467'}
# sentence {'id': '1038'}
# sentence {'id': '1921'}
# sentence {'id': '2437'}
# sentence {'id': '3494'}
# sentence {'id': '783'}
# sentence {'id': '1093'}
# sentence {'id': '1770'}
# sentence {'id': '646'}
# sentence {'id': '2699'}
# sentence {'id': '151'}
# sentence {'id': '1423'}
# sentence {'id': '1047'}
# sentence {'id': '755'}
# sentence {'id': '562'}
# sentence {'id': '3272'}
# sentence {'id': '971'}
# sentence {'id': '3258'}
# sentence {'id': '802'}
# sentence {'id': '2241'}
# sentence {'id': '3103'}
# sentence {'id': '299'}
# sentence {'id': '629'}
# sentence {'id': '1939'}
# sentence {'id': '2243'}
# sentence {'id': '1572'}
# sentence {'id': '2564'}
# sentence {'id': '482'}
# sentence {'id': '622'}
# sentence {'id': '1851'}
# sentence {'id': '571'}
# sentence {'id': '2526'}
# sentence {'id': '1300'}
# sentence {'id': '3464'}
# sentence {'id': '2608'}
# sentence {'id': '2704'}
# sentence {'id': '1539'}
# sentence {'id': '3181'}
# sentence {'id': '3044'}
# sentence {'id': '448'}
# sentence {'id': '1633'}
# sentence {'id': '1687'}
# sentence {'id': '1466'}
# sentence {'id': '950'}
# sentence {'id': '3567'}
# sentence {'id': '2224'}
# sentence {'id': '137'}
# sentence {'id': '1462'}
# sentence {'id': '1020'}
# sentence {'id': '3313'}
# sentence {'id': '897'}
# sentence {'id': '3463'}
# sentence {'id': '2794'}
# sentence {'id': '3511'}
# sentence {'id': '2096'}
# sentence {'id': '1967'}
# sentence {'id': '3632'}
# sentence {'id': '2114'}
# sentence {'id': '1605'}
# sentence {'id': '747'}
# sentence {'id': '1447'}
# sentence {'id': '543'}
# sentence {'id': '402'}
# sentence {'id': '3323'}
# sentence {'id': '1882'}
# sentence {'id': '587'}
# sentence {'id': '1430'}
# sentence {'id': '2060'}
# sentence {'id': '639'}
# sentence {'id': '2325'}
# sentence {'id': '3619'}
# sentence {'id': '1536'}
# sentence {'id': '2403'}
# sentence {'id': '810'}
# sentence {'id': '2169'}
# sentence {'id': '564'}
# sentence {'id': '1908'}
# sentence {'id': '2569'}
# sentence {'id': '2535'}
# sentence {'id': '330'}
# sentence {'id': '902'}
# sentence {'id': '568'}
# sentence {'id': '3133'}
# sentence {'id': '2553'}
# sentence {'id': '2624'}
# sentence {'id': '2116'}
# sentence {'id': '317'}
# sentence {'id': '2151'}
# sentence {'id': '944'}
# sentence {'id': '3014'}
# sentence {'id': '900'}
# sentence {'id': '2739'}
# sentence {'id': '279'}
# sentence {'id': '2937'}
# sentence {'id': '333'}
# sentence {'id': '236'}
# sentence {'id': '1420'}
# sentence {'id': '2259'}
# sentence {'id': '608'}
# sentence {'id': '2834'}
# sentence {'id': '3168'}
# sentence {'id': '2798'}
# sentence {'id': '2378'}
# sentence {'id': '1027'}
# sentence {'id': '1735'}
# sentence {'id': '1063'}
# sentence {'id': '777'}
# sentence {'id': '875'}
# sentence {'id': '671'}
# sentence {'id': '617'}

# %%
# Use this dataframe for multilabel classification
# Must use scikitlearn's multilabel binarizer

labeled_reviews = []
for sentence in root.findall("sentence"):
    entry = {}
    aterms = []
    aspects = []
    if sentence.find("aspectTerms"):
        for aterm in sentence.find("aspectTerms").findall("aspectTerm"):
            aterms.append(aterm.get("term"))
    if sentence.find("aspectCategories"):
        for aspect in sentence.find("aspectCategories").findall("aspectCategory"):
            aspects.append(aspect.get("category"))
    entry["text"], entry["terms"], entry["aspects"]= sentence[0].text, aterms, aspects
    labeled_reviews.append(entry)
labeled_df = pd.DataFrame(labeled_reviews)
print("there are",len(labeled_reviews),"reviews in this training set")
#    print(sentence.find("aspectCategories").findall("aspectCategory").get("category"))
# Out:
# there are 3044 reviews in this training set

# %%
labeled_df.to_pickle("annotated_reviews_df.pkl")
labeled_df.head()
# Out:
#                            aspects                  terms  \
# 0                        [service]                [staff]
# 1  [food, anecdotes/miscellaneous]                 [food]
# 2                           [food]  [food, kitchen, menu]
# 3                        [service]                     []
# 4        [anecdotes/miscellaneous]                     []
#
#                                                 text
# 0               But the staff was so horrible to us.
# 1  To be completely fair, the only redeeming fact...
# 2  The food is uniformly exceptional, with a very...
# 3  Where Gabriela personaly greets you and recomm...
# 4  For those that go once and don't enjoy it, all...

# %%
# This code was for parsing out terms & their relations to aspects
# However, the terms were not always hyponyms of the aspects, so they were unusable
aspects = {"food":[],"service":[],"anecdotes/miscellaneous":[], "ambience":[], "price":[]}
for i in range(len(labeled_df)):
    if len(labeled_df.aspects[i]) == 1:
        if labeled_df.terms[i] != []:
            for terms in labeled_df.terms[i]:
                aspects[labeled_df.aspects[i][0]].append(terms.lower())
for key in aspects:
    aspects[key] = list(set(aspects[key]))

# %%
terms = []
for i in labeled_df.terms:
    for j in i:
        if j not in terms:
            terms.append(j)
print("there are", len(terms),"unique terms")
# Out:
# there are 1295 unique terms

# %%
# Use this dataframe if doing the classifications separately as binary classifications
labeled_reviews2 = []
for sentence in root.findall("sentence"):
    entry = {"food":0,"service":0,"anecdotes/miscellaneous":0, "ambience":0, "price":0}
    aterms = []
    aspects = []
    if sentence.find("aspectTerms"):
        for aterm in sentence.find("aspectTerms").findall("aspectTerm"):
            aterms.append(aterm.get("term"))
    if sentence.find("aspectCategories"):
        for aspect in sentence.find("aspectCategories").findall("aspectCategory"):
            if aspect.get("category") in entry.keys():
                entry[aspect.get("category")] = 1
    entry["text"], entry["terms"] = sentence[0].text, aterms
    labeled_reviews2.append(entry)
labeled_df2 = pd.DataFrame(labeled_reviews2)
#    print(sentence.find("aspectCategories").findall("aspectCategory").get("category"))

# %%
labeled_df2.iloc[:,:5].sum()
# Out:
# ambience                    432
# anecdotes/miscellaneous    1131
# food                       1233
# price                       319
# service                     597
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer

# Split data into train and test set
X_train, X_test, y_train, y_test = train_test_split(
    labeled_df.text, labeled_df.aspects, test_size=0.25, random_state=42)
# Convert the multi-labels into arrays
mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(y_train)
y_test = mlb.fit_transform(y_test)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from skmultilearn.problem_transform import LabelPowerset

# LabelPowerset allows for multi-label classification
# Build a pipeline for multinomial naive bayes classification
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1, 2))),
                     ('tfidf', TfidfTransformer()),
                     ('clf', LabelPowerset(MultinomialNB(alpha=1e-2))),])
text_clf = text_clf.fit(X_train, y_train)
predicted = text_clf.predict(X_test)
np.mean(predicted == y_test)
# Out:
# 0.8588699080157687

# %%
# from sklearn.model_selection import KFold, cross_val_score
# cross_val_score(text_clf, X_train, y_train, cv=6, n_jobs=-1)

# %%
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer()),
                         ('tfidf', TfidfTransformer()),
                         ('clf-svm', LabelPowerset(
                             SGDClassifier(loss='hinge', penalty='l2',
                                           alpha=1e-3, max_iter=5, random_state=42)))])
_ = text_clf_svm.fit(X_train, y_train)
predicted_svm = text_clf_svm.predict(X_test)
np.mean(predicted_svm == y_test)
# Out:
# 0.854664914586071

# %% [markdown]
# # Figure out gridsearchcv for labelpowerset
# then run it in ec2

# %%
from sklearn.model_selection import GridSearchCV
# parameters = {'vect__ngram_range': [(1, 1), (1, 2)],
#               'tfidf__use_idf': (True, False),
parameters = {'clf': [LabelPowerset(MultinomialNB(alpha=1e-2)),
                     LabelPowerset(MultinomialNB(alpha=1e-3))
                     LabelPowerset(MultinomialNB(alpha=1e-4))]}
gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)
gs_clf = gs_clf.fit(X_train, y_train)
gs_clf.best_score_
# Out:
#   File "<ipython-input-622-ae9775820d8b>", line 6
#     LabelPowerset(MultinomialNB(alpha=1e-4))]}
#                 ^
# SyntaxError: invalid syntax

# %%
gs_clf.best_params_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-594-5db8d9a5987f> in <module>()
# ----> 1 gs_clf.best_params_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
#Use inverse transform for multilabel binarizer
mlb.inverse_transform(y_test)
# Out:
# [('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('ambience', 'food'),
#  ('service',),
#  ('ambience', 'service'),
#  ('price',),
#  ('food',),
#  ('food', 'service'),
#  ('food',),
#  ('food', 'price'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'service'),
#  ('food', 'service'),
#  ('price',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('ambience',),
#  ('ambience',),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('price',),
#  ('ambience',),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('price', 'service'),
#  ('price',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('food',),
#  ('food', 'service'),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('ambience',),
#  ('ambience', 'service'),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('price',),
#  ('food', 'price'),
#  ('ambience', 'service'),
#  ('ambience', 'food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'price'),
#  ('ambience', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('ambience', 'food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price', 'service'),
#  ('food',),
#  ('food',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('ambience', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience', 'food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('ambience', 'service'),
#  ('price',),
#  ('service',),
#  ('food',),
#  ('food', 'price'),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('ambience',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('food',),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('food', 'price'),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('ambience', 'price', 'service'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('ambience', 'food', 'service'),
#  ('food',),
#  ('ambience',),
#  ('service',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'food', 'service'),
#  ('food', 'service'),
#  ('food',),
#  ('price',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('food',),
#  ('ambience',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'price'),
#  ('food', 'price'),
#  ('service',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food', 'service'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'price'),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('price',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('service',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food', 'service'),
#  ('ambience', 'food', 'price'),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience', 'food', 'service'),
#  ('food', 'service'),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('price',),
#  ('food', 'service'),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('anecdotes/miscellaneous', 'service'),
#  ('ambience',),
#  ('ambience', 'food', 'price'),
#  ('service',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous', 'food'),
#  ('ambience',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('food', 'service'),
#  ('food',),
#  ('food',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('ambience', 'food', 'service'),
#  ('anecdotes/miscellaneous', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'service'),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('ambience', 'food'),
#  ('service',),
#  ('service',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('price',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('price',),
#  ('ambience',),
#  ('price',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous', 'service'),
#  ('price',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('ambience',),
#  ('ambience',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('ambience', 'food'),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('price', 'service'),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('ambience', 'service'),
#  ('food', 'price'),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('ambience',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('ambience',),
#  ('food',),
#  ('food',),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('ambience',),
#  ('price',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('ambience', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('ambience',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('food',),
#  ('price',),
#  ('food', 'service'),
#  ('food', 'price'),
#  ('food',),
#  ('price',),
#  ('ambience', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('food',),
#  ('ambience', 'service'),
#  ('food', 'price', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('price',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('price',),
#  ('food', 'price'),
#  ('service',),
#  ('food',),
#  ('service',),
#  ('price',),
#  ('price',),
#  ('ambience',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous', 'food'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('ambience', 'service'),
#  ('anecdotes/miscellaneous', 'service'),
#  ('anecdotes/miscellaneous', 'price'),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'price'),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience', 'service'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('ambience', 'food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('food',),
#  ('food',),
#  ('ambience', 'food'),
#  ('food',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous', 'food'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('food', 'service'),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('food',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'anecdotes/miscellaneous'),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous', 'service'),
#  ('anecdotes/miscellaneous', 'service'),
#  ('food', 'service'),
#  ('ambience', 'price'),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('price',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('food',),
#  ('service',),
#  ('ambience', 'food', 'service'),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('food', 'price'),
#  ('service',),
#  ('service',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('food',),
#  ('service',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'food'),
#  ('ambience',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous', 'food'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('food',),
#  ('price',),
#  ('ambience',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'price'),
#  ('ambience', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('food', 'price'),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('service',),
#  ('food',),
#  ('food',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience', 'service'),
#  ('ambience',),
#  ('anecdotes/miscellaneous',),
#  ('service',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('ambience',),
#  ('ambience',),
#  ('ambience', 'service'),
#  ('food',),
#  ('service',),
#  ('food',),
#  ('ambience',),
#  ('service',),
#  ('ambience', 'food'),
#  ('service',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('food',),
#  ('ambience',),
#  ('food', 'price'),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('price', 'service'),
#  ('service',),
#  ('food',),
#  ('service',),
#  ('anecdotes/miscellaneous',),
#  ('food',),
#  ('anecdotes/miscellaneous',),
#  ('ambience',),
#  ('ambience', 'food'),
#  ('anecdotes/miscellaneous',),
#  ('food', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'service'),
#  ('ambience', 'service'),
#  ('anecdotes/miscellaneous',),
#  ('ambience', 'anecdotes/miscellaneous', 'service')]

# %%
import pickle
from collections import Counter, OrderedDict
meat_potatoes_sent = pickle.load(open("aws_backup/meat_potatoes_sentiment.pkl", "rb"))
meat_potatoes_dict = pickle.load(open("aws_backup/meat_potatoes_dict.pkl", "rb"))
primanti_sent = pickle.load(open("aws_backup/primanti_sentiment.pkl", "rb"))
primanti_dict = pickle.load(open("aws_backup/primanti_dict.pkl", "rb"))
church_brew_sent = pickle.load(open("aws_backup/church_brew_sentiment.pkl", "rb"))
church_brew_dict = pickle.load(open("aws_backup/church_brew_dict.pkl", "rb"))

# %%
from collections import defaultdict
lowest = defaultdict()
for i in meat_potatoes_dict:
    if meat_potatoes_dict[i]:
        lowest[i] = meat_potatoes_dict[i].most_common()[-4:]
        #print(i, ":" ,meat_potatoes_dict[i].most_common()[-10:])
#        print(OrderedDict(aspect_dict[i]))
lowest
# Out:
# defaultdict(None,
#             {'ambience': [('bit', -4),
#               ('complaint', -9),
#               ('music', -10.0),
#               ('noise', -12.5)],
#              'food': [('livers', -30.0),
#               ('sprouts', -31),
#               ('pig', -57.0),
#               ('pickles', -125.75)],
#              'misc': [('complaint', -1),
#               ('break', -1),
#               ('joint', -1),
#               ('passion', -1.5)],
#              'price': [('tag', -1),
#               ('entree', -1),
#               ('place', -1),
#               ('downside', -11)],
#              'service': [('bar', -4.5),
#               ('complaint', -5),
#               ('hostesses', -5),
#               ('problems', -5.25)]})

# %%
for i in aspect_dict:
    if aspect_dict[i]:
        if aspect_dict[i].key() == "cocktails":
            print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-a342d06b17e3> in <module>()
#       1 for i in aspect_dict:
#       2     if aspect_dict[i]:
# ----> 3         if aspect_dict[i].key() == "cocktails":
#       4             print(i)
#
# AttributeError: 'Counter' object has no attribute 'key'

# %% [markdown]
# # Plot.ly Charts

# %%
import pandas as pd
primanti_df = pd.DataFrame(primanti_sent).T
meat_potatoes_df = pd.DataFrame(meat_potatoes_sent).T
church_brew_df = pd.DataFrame(church_brew_sent).T

# %%
primanti_df["total"] = primanti_df.neg + primanti_df.pos
primanti_df["neg_norm"] = primanti_df.neg/(primanti_df.neg + primanti_df.pos)
primanti_df["pos_norm"] = primanti_df.pos/(primanti_df.neg + primanti_df.pos)
church_brew_df["total"] = church_brew_df.neg + church_brew_df.pos
church_brew_df["neg_norm"] = church_brew_df.neg/(church_brew_df.neg + church_brew_df.pos)
church_brew_df["pos_norm"] = church_brew_df.pos/(church_brew_df.neg + church_brew_df.pos)
meat_potatoes_df["total"] = meat_potatoes_df.neg + meat_potatoes_df.pos
meat_potatoes_df["neg_norm"] = meat_potatoes_df.neg/(meat_potatoes_df.neg + meat_potatoes_df.pos)
meat_potatoes_df["pos_norm"] = meat_potatoes_df.pos/(meat_potatoes_df.neg + meat_potatoes_df.pos)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    x=primanti_df.index,
    y=primanti_df.pos_norm,
    name='% Pos Sentiment'
)
trace2 = go.Bar(
    x=primanti_df.index,
    y=primanti_df.neg_norm,
    name='% Neg Sentiment'
)

data = [trace1, trace2]
layout = go.Layout(
    title = "Aspect-Based Sentiment",
    barmode = 'stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pmin91/31.embed" height="525px" width="100%"></iframe>

# %%
primanti_df["pos/neg"]=primanti_df.pos/primanti_df.neg
meat_potatoes_df["pos/neg"]=meat_potatoes_df.pos/meat_potatoes_df.neg
church_brew_df["pos/neg"]=church_brew_df.pos/church_brew_df.neg

# %%
import plotly
plotly.tools.set_credentials_file(username='pmin91', api_key='OvWRYXZbhdZMigq7uEK3')
import plotly.plotly as py
import plotly.graph_objs as go


data = [
    go.Scatterpolar(
      r = primanti_df["pos/neg"],
      theta = primanti_df.index,
      fill = 'toself',
      name = 'Primanti Bros.'
    ),
    go.Scatterpolar(
      r = church_brew_df["pos/neg"],
      theta = church_brew_df.index,
      fill = 'toself',
      name = 'Church Brew Works'
    )
]

layout = go.Layout(
  polar = dict(
    radialaxis = dict(
      visible = True,
      range = [0, 5]
    )
  ),
  showlegend = True
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig)#, filename = "radar/multiple")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pmin91/49.embed" height="525px" width="100%"></iframe>

# %%
labels = meat_potatoes_df.index
values = meat_potatoes_df.total

trace = go.Pie(labels=labels, values=values)

py.iplot([trace])
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~pmin91/37.embed" height="525px" width="100%"></iframe>

# %%
def check_similarity(aspects, word):
    similarity = []
    for aspect in aspects:
        similarity.append(word2vec.n_similarity([aspect], [word]))
    # set threshold for max value
    if max(similarity) > 0.30:
        return aspects[np.argmax(similarity)]
    else:
        return None

    
def assign_term_to_aspect(aspect_sent, terms_dict, sent_dict, pred):
    '''
    function: takes in a sentiment dictionary and appends the aspect dictionary
    inputs: sent_dict is a Counter in the form Counter(term:sentiment value)
            aspect_sent is total sentiment tally
            terms_dict is dict with individual aspect words associated with sentiment
    output: return two types of aspect dictionaries: 
            updated terms_dict and aspect_sent
    '''
    aspects = ['ambience', 'food', 'price', 'service']
    

    # First, check word2vec
    # Note: the .split() is used for the term because word2vec can't pass compound nouns
    for term in sent_dict:
        try:
            # The conditions for when to use the NB classifier as default vs word2vec
            if check_similarity(aspects, term.split()[-1]):
                terms_dict[check_similarity(aspects, term.split()[-1])][term] += sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent[check_similarity(aspects, term.split()[-1])]["pos"] += sent_dict[term]
                else:
                    aspect_sent[check_similarity(aspects, term.split()[-1])]["neg"] += abs(sent_dict[term])
            elif (pred[0] == "anecdotes/miscellaneous"):
                continue
            elif (len(pred) == 1):
                terms_dict[pred[0]][term] += sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent[pred[0]]["pos"] += sent_dict[term]
                else:
                    aspect_sent[pred[0]]["neg"] += abs(sent_dict[term])
            # if unable to classify via NB or word2vec, then put them in misc. bucket
            else:
                terms_dict["misc"][term] += sent_dict[term]
                if sent_dict[term] > 0:
                    aspect_sent["misc"]["pos"] += sent_dict[term]
                else:
                    aspect_sent["misc"]["neg"] += abs(sent_dict[term])
        except:
            print(term, "not in vocab")
            continue
    return aspect_sent, terms_dict
    
    
def feature_sentiment(sentence):
    '''
    input: dictionary and sentence
    function: appends dictionary with new features if the feature did not exist previously,
              then updates sentiment to each of the new or existing features
    output: updated dictionary
    '''

    sent_dict = Counter()
    sentence = spacy(sentence)
    
    for token in sentence:
    #    print(token.text,token.dep_, token.head, token.head.dep_)
        #check if the word is an opinion word, then assign sentiment
        if token.text in opinion_words:
            sentiment = 1 if token.text in pos else -1
            # if target is an adverb modifier (i.e. pretty, highly, etc.)
            # but happens to be an opinion word, ignore and pass
            if (token.dep_ == "advmod"):
                continue
            elif (token.dep_ == "amod"):
                sent_dict[token.head.text] += sentiment
            # for opinion words that are adjectives, adverbs, verbs...
            for child in token.children:
                # if there's a adj modifier (i.e. very, pretty, etc.) add more weight to sentiment
                # This could be better updated for modifiers that either positively or negatively emphasize
                if ((child.dep_ == "amod") or (child.dep_ == "advmod")) and (child.text in opinion_words):
                    sentiment *= 1.5
                # check for negation words and flip the sign of sentiment
                if child.dep_ == "neg":
                    sentiment *= -1
                # if verb, check if there's a direct object
                if (token.pos_ == "VERB") & (child.dep_ == "dobj"):                        
                    sent_dict[child.text] += sentiment

                    # check for conjugates (a AND b), then add both to dictionary
                    subchildren = []
                    conj = 0
                    for subchild in child.children:
                        if subchild.text == "and":
                            conj=1
                        if (conj == 1) and (subchild.text != "and"):
                            subchildren.append(subchild.text)
                            conj = 0
                    for subchild in subchildren:
                        sent_dict[subchild] += sentiment

            # check token head and go to noun
            for child in token.head.children:
                # if the verb is referring to a noun, 
                noun = ""
                if child.pos_ == "NOUN":
                    noun = child.text

                    # Check for compound nouns
                    for subchild in child.children:
                        if subchild.dep_ == "compound":
                            noun = subchild.text + " " + noun
                    sent_dict[noun] += sentiment
    return sent_dict

def classify_and_sent(sentence, aspect_sent, terms_dict={'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}):
    '''
    function: classify the sentence into a category, and assign sentiment
    note: aspect_dict is a parent dictionary with all the aspects
    input: sentence & aspect dictionary, which is going to be updated
    output: updated aspect dictionary
    '''
    # classify sentence with NB classifier
    predicted = naive_model1.predict([sentence])
    pred = mlb.inverse_transform(predicted)
    # get aspect names and their sentiment in a dictionary form
    sent_dict = feature_sentiment(sentence)
    # try to categorize the aspect names into the 4 aspects in aspect_dict
    aspect_sent, terms_dict = assign_term_to_aspect(aspect_sent, terms_dict, sent_dict, pred[0])
    return aspect_sent, terms_dict

def replace_pronouns(text):
    coref.one_shot_coref(text)
    return coref.get_resolved_utterances()[0]

def split_sentence(text):
    '''
    splits review into a list of sentences using spacy's sentence parser
    '''
    review = spacy(text)
    bag_sentence = []
    start = 0
    for token in review:
        if token.sent_start:
            bag_sentence.append(review[start:(token.i-1)])
            start = token.i
        if token.i == len(review)-1:
            bag_sentence.append(review[start:token.i])
    return bag_sentence

def remove_special_char(sentence):
    return re.sub(r"[^a-zA-Z0-9]+", ' ', sentence)

def review_pipe(review, aspect_sent, terms_dict={'ambience':Counter(), 'food':Counter(), 'price':Counter(), 'service':Counter(),'misc':Counter()}):
    review = replace_pronouns(review)
    sentences = split_sentence(review)
    for sentence in sentences:
        sentence = remove_special_char(str(sentence))
        aspect_sent, terms_dict = classify_and_sent(sentence.lower(), aspect_sent, terms_dict)
    return aspect_sent, terms_dict
