# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import glob
import os
import googlemaps

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 0.22.0
# Numpy version: 1.14.1

# %%
# Read NYC turntable for the month of march, from march 3rd to march 30th (4weeks)
#df = pd.read_csv("NYCT180310.csv")
path =r'/Users/petermin/metis/Project1' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))
df = pd.concat((pd.read_csv(f) for f in all_files))

# %%
# Check for null values
df.isnull().sum()
# Out:
# C/A                                                                     0
# UNIT                                                                    0
# SCP                                                                     0
# STATION                                                                 0
# LINENAME                                                                0
# DIVISION                                                                0
# DATE                                                                    0
# TIME                                                                    0
# DESC                                                                    0
# ENTRIES                                                                 0
# EXITS                                                                   0
# dtype: int64

# %%
df.describe()
# Out:
#             ENTRIES  \
# count  7.882560e+05
# mean   3.915012e+07
# std    2.048017e+08
# min    0.000000e+00
# 25%    5.014248e+05
# 50%    2.591772e+06
# 75%    6.882948e+06
# max    2.130056e+09
#
#        EXITS
# count                                       7.882560e+05
# mean                                        3.236161e+07
# std                                         1.903977e+08
# min                                         0.000000e+00
# 25%                                         2.496720e+05
# 50%                                         1.460002e+06
# 75%                                         4.822181e+06
# max                                         2.145850e+09

# %%
#remove extra spaces in strings of columns
df.columns = df.columns.str.strip()
len(df)
# Out:
# 788256

# %%
#check num of 0 entries
num_resets = df[df["ENTRIES"] == 0]
print("There are", len(num_resets), "zero entries out of", len(df), "total entries")
# Out:
# There are 12694 zero entries out of 788256 total entries

# %%
#remove reset entries and designate this new dataframe as df_r
df_r = df[df.ENTRIES != 0]
len(df_r[df_r["ENTRIES"] == 0])
print("removed", len(df) - len(df_r), "entries")
# Out:
# removed 12694 entries

# %%
#create a datetime and add it as the 6th index
#pd.to_datetime(df.DATE + " " + df.TIME)
date_time = pd.to_datetime(df_r.DATE + " " + df_r.TIME, format="%m/%d/%Y %H:%M:%S")
df_r.insert(loc=6, column='DATE_TIME', value=date_time)

# %%
df_r["TIME_TIME"] = df_r.DATE_TIME.dt.time
# Out:
# /Users/petermin/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_r
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 15       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 16       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 17       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 20       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 21       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 22       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 23       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 24       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 25       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 26       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 27       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 28       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 29       A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...       ...   ...       ...            ...      ...      ...
# 196624  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196625  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196626  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196627  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196628  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196629  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196630  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196631  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196632  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196633  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196634  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196635  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196636  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196637  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196638  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196639  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196640  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196641  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196642  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196643  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196644  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196645  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196646  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196647  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196648  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196649  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196650  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196651  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196652  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196653  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
#
#                  DATE_TIME        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0      2018-03-10 03:00:00  03/10/2018  03:00:00  REGULAR  6543902  2216231
# 1      2018-03-10 07:00:00  03/10/2018  07:00:00  REGULAR  6543916  2216241
# 2      2018-03-10 11:00:00  03/10/2018  11:00:00  REGULAR  6543983  2216334
# 3      2018-03-10 15:00:00  03/10/2018  15:00:00  REGULAR  6544182  2216387
# 196635            1  17:00:00
# 196636            1  21:00:00
# 196637            2  01:00:00
# 196638            2  17:00:00
# 196639            2  21:00:00
# 196640            3  01:00:00
# 196641            3  05:00:00
# 196642            3  08:43:42
# 196643            3  08:44:44
# 196644            3  09:00:00
# 196645            3  13:00:00
# 196646            3  17:00:00
# 196647            3  21:00:00
# 196648            4  01:00:00
# 196649            4  05:00:00
# 196650            4  09:00:00
# 196651            4  13:00:00
# 196652            4  17:00:00
# 196653            4  21:00:00
#
# [775562 rows x 14 columns]

# %%
# Create a new column day_of_week, which tracks the day of the week (Mon: 0,... Sun: 6)
#df_r['day_of_week'] = df_r.DATE_TIME.dt.weekday
df_r.loc[:,'day_of_week'] = df_r.loc[:,"DATE_TIME"].dt.weekday
df_r.head()
# Out:
# /Users/petermin/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#     C/A  UNIT       SCP STATION LINENAME DIVISION           DATE_TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-03-10 03:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-03-10 07:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-03-10 11:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-03-10 15:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-03-10 19:00:00
#
#          DATE      TIME     DESC  ENTRIES    EXITS  day_of_week
# 0  03/10/2018  03:00:00  REGULAR  6543902  2216231            5
# 1  03/10/2018  07:00:00  REGULAR  6543916  2216241            5
# 2  03/10/2018  11:00:00  REGULAR  6543983  2216334            5
# 3  03/10/2018  15:00:00  REGULAR  6544182  2216387            5
# 4  03/10/2018  19:00:00  REGULAR  6544513  2216441            5

# %%
# create a new dataframe for the weekdays only: df_w
df_wd = df_r[df_r['day_of_week'] < 5]
#there are only Mon - Fri data (0 - 4)
df_wd.describe()
# Out:
#             ENTRIES         EXITS    day_of_week
# count  5.563840e+05  5.563840e+05  556384.000000
# mean   3.973792e+07  3.289316e+07       1.996427
# std    2.062026e+08  1.919348e+08       1.413839
# min    1.000000e+00  0.000000e+00       0.000000
# 25%    5.465595e+05  2.801890e+05       1.000000
# 50%    2.706982e+06  1.522990e+06       2.000000
# 75%    6.989373e+06  4.886429e+06       3.000000
# max    2.130054e+09  2.145850e+09       4.000000

# %%
# gb is with linename, gb2 is without linename
gb = df_wd.groupby(["C/A", "UNIT", "SCP", "STATION", "LINENAME", "DATE"]).ENTRIES.agg(["min", "max"])
gb2 = df_wd.groupby(["C/A", "UNIT", "SCP", "STATION", "DATE"]).ENTRIES.agg(["min", "max"])
#find diff between max and min
gb["dif"] = gb["max"] - gb["min"]
gb2["dif"] = gb2["max"] - gb2["min"]

# %%
#plt.barh(gb.index.levels[1],gb.dif)
gb.head()
#gb2.dif.describe()
#sns.boxplot(gb.dif)
#odd = len(gb[gb.dif > 10000])
#print("there are", odd, "days that had more than 10,000 entries (what I may consider odd/outliers)")
# Out:
#                                                     min      max   dif
# C/A  UNIT SCP      STATION LINENAME DATE
# A002 R051 02-00-00 59 ST   NQR456W  03/05/2018  6537057  6538436  1379
#                                     03/06/2018  6538452  6539924  1472
#                                     03/07/2018  6539944  6540923   979
#                                     03/08/2018  6540936  6542356  1420
#                                     03/09/2018  6542379  6543867  1488

# %%
# Take a look at the outliers >10000
#gb2[gb2.dif > 10000]
print(len(gb[gb.dif > 15000]))
gb[gb.dif > 15000]
# C/A   UNIT SCP      STATION         LINENAME DATE
# D016  R397 00-00-00 86 ST           N        03/15/2018    3949605
#            00-00-01 86 ST           N        03/15/2018    2730320
# G009  R151 02-00-03 CONEY IS-STILLW DFNQ     03/07/2018    3793501
# H028  R266 00-06-00 HALSEY ST       L        03/20/2018     213624
# N181  R357 00-06-00 AQUEDUCT N.COND A        03/19/2018     514733
# N218  R112 01-06-01 FORDHAM RD      BD       03/13/2018    5057706
# N221  R155 00-00-02 KINGSBRIDGE RD  BD       03/12/2018     186830
# N327  R254 00-05-04 GRAND-NEWTOWN   MR       03/08/2018    2029220
# N343  R019 00-00-04 JAMAICA 179 ST  F        03/06/2018    3917644
# N501A R020 02-06-03 47-50 STS ROCK  BDFM     03/21/2018     604468
# N520  R240 00-00-01 GRAND ST        BD       03/12/2018    8641344
# PTH01 R549 00-00-02 NEWARK HW BMEBE 1        03/16/2018      81828
#            00-00-06 NEWARK HW BMEBE 1        03/09/2018      87853
# PTH03 R552 00-00-09 JOURNAL SQUARE  1        03/06/2018     680550
#                                              03/07/2018     681842
#                                              03/08/2018     684048
#                                              03/09/2018     685480
#                                              03/12/2018     687218
#                                              03/13/2018     689207
#            00-02-01 JOURNAL SQUARE  1        03/06/2018     151933
# PTH07 R550 00-00-04 CITY / BUS      1        03/16/2018      32446
#            00-00-08 CITY / BUS      1        03/16/2018     174302
#            00-01-06 CITY / BUS      1        03/12/2018      27765
# PTH12 R542 00-00-00 TWENTY THIRD ST 1        03/12/2018     108399
# PTH16 R550 01-01-08 LACKAWANNA      1        03/27/2018      49224
# PTH18 R549 01-01-02 NEWARK BM BW    1        03/14/2018      81535
#            01-02-00 NEWARK BM BW    1        03/05/2018      94640
#            01-02-03 NEWARK BM BW    1        03/19/2018     155266
# PTH22 R540 00-01-00 PATH NEW WTC    1        03/09/2018     106107
#            00-01-01 PATH NEW WTC    1        03/19/2018     556622
#            00-01-02 PATH NEW WTC    1        03/15/2018     151742
#            00-03-07 PATH NEW WTC    1        03/26/2018      21237
# R127  R105 00-03-00 14 ST           123FLM   03/12/2018    4397068
# R165  R167 01-00-02 86 ST           1        03/23/2018     127383
# R197  R117 00-00-00 V.CORTLANDT PK  1        03/21/2018  618323331
# R244  R050 00-00-00 59 ST           456NQRW  03/20/2018    6632798
# R252  R180 00-03-00 103 ST          6        03/14/2018     185027
# R623  R061 00-00-02 NOSTRAND AV     3        03/26/2018    9906499
# TRAM2 R469 00-00-00 RIT-ROOSEVELT   R        03/29/2018    3508323
#            00-00-01 RIT-ROOSEVELT   R        03/29/2018     330280
#            00-03-00 RIT-ROOSEVELT   R        03/29/2018    3507316
#            00-03-01 RIT-ROOSEVELT   R        03/29/2018     331197

# %% [markdown]
# ### Looking at the data, it seems obvious that some of these entries have been reset (The ones where min are VERY low compared to the max. We can now get a better sense of the correct cutoff to not remove the entries that did not seem to reset, i.e. 15,000.

# %%
# gb_r is gb with the obviousresets removed
gb_r = gb[gb.dif < 15000]
gb2_r = gb2[gb2.dif < 15000]
# Show boxplot 
# 59 ST COLUMBUS  ABCD1          46732720489   46733727565  1007076
# 34 ST-PENN STA  123ACE         41360890997   41361857602   966605
# JKSN HT-ROOSVLT EFMR7           2782303223    2783213568   910345
# CANAL ST        JNQRZ6W       100465297629  100466120048   822419
# LEXINGTON AV/53 EM6            53904389175   53905162041   772866
# 86 ST           456            23463543831   23464304734   760903
# JAY ST-METROTEC ACF             8666610054    8667358131   748077
# 59 ST           456NQRW        38110387478   38111115592   728114
# 42 ST-BRYANT PK BDFM7          38952278734   38953002806   724072
# JAMAICA CENTER  EJZ            26654963462   26655685254   721792
# 72 ST           123            70888433280   70889107621   674341
# 96 ST           123             3045050714    3045708723   658009
# W 4 ST-WASH SQ  ABCDEFM         5030633681    5031282719   649038
# BOROUGH HALL    2345R           2027632200    2028267669   635469
# 57 ST-7 AV      NQRW           84202236770   84202845674   608904
# 34 ST-PENN STA  123             4674259017    4674837868   578851
# CHAMBERS ST     ACE23          38671415909   38671990058   574149
# BOWLING GREEN   45             49510555414   49511121156   565742
# 72 ST-2 AVE     Q               2546719545    2547276935   557390
# 23 ST           FM             62198650108   62199189547   539439
# ...                                    ...           ...      ...
# WHITLOCK AV     6                148343039     148378595    35556
# PARK PLACE      S                249372054     249407511    35457
# 215 ST          1                205074784     205110069    35285
# AVENUE N        F               2979119756    2979154837    35081
# BEACH 25 ST     A                162281496     162316440    34944
# AQUEDUCT RACETR A               1075256343    1075290937    34594
# 21 ST           G                 70303019      70336433    33414
# 86 ST           N               2270120954    2270153656    32702
# NEPTUNE AV      F                150790641     150822059    31418
# BOTANIC GARDEN  S2345            112433184     112462969    29785
# CYPRESS HILLS   J                132304502     132334083    29581
# AVENUE P        F                258302819     258330925    28106
# BEACH 90 ST     AS               118114872     118141585    26713
# 104 ST          JZ             63147944247   63147970607    26360
# 121 ST          JZ               481869592     481893387    23795
# E 143/ST MARY'S 6                105214002     105234557    20555
# 163 ST-AMSTERDM C              11833921995   11833942404    20409
# AQUEDUCT N.COND A                106143362     106161322    17960
# BEACH 36 ST     A                 91952956      91969722    16766
# TOMPKINSVILLE   1                189517453     189531919    14466
# BEACH 44 ST     A                 58489168      58502113    12945
# ROCKAWAY PARK B AS              2112388860    2112400691    11831
# AVENUE U        F                485474268     485485264    10996
# BEACH 98 ST     AS                95148997      95158158     9161
# SENECA AVE      M                128293144     128301977     8833
# BAY PKWY        F                121780939     121789185     8246
# AVENUE I        F                134775207     134782313     7106
# BROAD CHANNEL   AS                25955195      25960845     5650
# NEWARK HM HE    1                 14714611      14719628     5017
# BEACH 105 ST    AS              2375523417    2375528217     4800
#
# [473 rows x 3 columns]

# %%
#testcode with google geocode api
gmaps = googlemaps.Client(key='AIzaSyDPpbfUFcTtB7nO4KHcUKUzG1L6oiQWCPA')
geocode_result = gmaps.geocode('HALSEY ST station, NY')
#geocode_result[0]["address_components"][-1]['long_name']
geocode_result[0]["geometry"]["location"]
#geocode_result
# Out:
# {'lat': 40.69577750000001, 'lng': -73.9044092}

# %% [markdown]
# # Identifying high income zipcodes

# %%
# create stations series 
stations = df["STATION"].unique()
stations
# Out:
# array(['59 ST', '5 AV/59 ST', '57 ST-7 AV', '49 ST', 'TIMES SQ-42 ST',
#        '34 ST-HERALD SQ', '28 ST', '23 ST', '14 ST-UNION SQ', '8 ST-NYU',
#        'PRINCE ST', 'CANAL ST', 'CITY HALL', 'CORTLANDT ST', 'RECTOR ST',
#        'WHITEHALL S-FRY', 'DELANCEY/ESSEX', 'BOWERY', 'CHAMBERS ST',
#        'FULTON ST', 'BROAD ST', '7 AV', 'PARK PLACE', 'BOTANIC GARDEN',
#        'PROSPECT PARK', 'PARKSIDE AV', 'CHURCH AV', 'BEVERLEY ROAD',
#        'CORTELYOU RD', 'NEWKIRK PLAZA', 'AVENUE H', 'AVENUE J',
#        'AVENUE M', 'KINGS HWY', 'AVENUE U', 'NECK RD', 'SHEEPSHEAD BAY',
#        'BRIGHTON BEACH', 'OCEAN PKWY', 'BOROUGH HALL', 'JAY ST-METROTEC',
#        'DEKALB AV', 'ATL AV-BARCLAY', 'UNION ST', '4AV-9 ST',
#        'PROSPECT AV', '25 ST', '36 ST', '45 ST', '53 ST', 'BAY RIDGE AV',
#        '77 ST', '86 ST', 'BAY RIDGE-95 ST', '8 AV', 'FT HAMILTON PKY',
#        'NEW UTRECHT AV', '18 AV', '20 AV', 'BAY PKWY', '9 AV', '50 ST',
#        '55 ST', '71 ST', '79 ST', '25 AV', 'BAY 50 ST', 'CONEY IS-STILLW',
#        'W 8 ST-AQUARIUM', '6 AV', '3 AV', '1 AV', 'BEDFORD AV',
#        'LORIMER ST', 'GRAHAM AV', 'GRAND ST', 'MONTROSE AV', 'MORGAN AV',
#        'JEFFERSON ST', 'MYRTLE-WYCKOFF', 'HALSEY ST', 'WILSON AV',
#        'BUSHWICK AV', 'ATLANTIC AV', 'SUTTER AV', 'LIVONIA AV',
#        'NEW LOTS', 'EAST 105 ST', 'CANARSIE-ROCKAW', 'HOWARD BCH JFK',
#        'JFK JAMAICA CT1', 'MARCY AV', 'HEWES ST', 'FLUSHING AV',
#        'MYRTLE AV', 'KOSCIUSZKO ST', 'GATES AV', 'CHAUNCEY ST',
#        'ALABAMA AV', 'VAN SICLEN AV', 'CLEVELAND ST', 'NORWOOD AV',
#        'CRESCENT ST', 'CYPRESS HILLS', '75 ST-ELDERTS', '85 ST-FOREST PK',
#        'WOODHAVEN BLVD', '104 ST', '111 ST', '121 ST', 'SENECA AVE',
#        'FOREST AVE', 'FRESH POND RD', 'METROPOLITAN AV', 'INWOOD-207 ST',
#        'DYCKMAN ST', '190 ST', '181 ST', '175 ST', '168 ST',
#        '163 ST-AMSTERDM', '155 ST', '145 ST', '135 ST', '125 ST',
#        '116 ST', 'CATHEDRAL PKWY', '103 ST', '96 ST', '81 ST-MUSEUM',
#        '72 ST', '59 ST COLUMBUS', '42 ST-PORT AUTH', '34 ST-PENN STA',
#        '14 ST', 'W 4 ST-WASH SQ', 'SPRING ST', 'WORLD TRADE CTR',
#        'HIGH ST', 'HOYT-SCHER', 'LAFAYETTE AV', 'CLINTON-WASH AV',
#        'FRANKLIN AV', 'NOSTRAND AV', 'KINGSTON-THROOP', 'UTICA AV',
#        'RALPH AV', 'ROCKAWAY AV', 'BROADWAY JCT', 'LIBERTY AV',
#        'VAN SICLEN AVE', 'SHEPHERD AV', 'EUCLID AV', 'GRANT AV', '80 ST',
#        '88 ST', 'ROCKAWAY BLVD', 'OZONE PK LEFFRT', 'AQUEDUCT N.COND',
#        'AQUEDUCT RACETR', 'BROAD CHANNEL', 'BEACH 90 ST', 'BEACH 98 ST',
#        'BEACH 105 ST', 'ROCKAWAY PARK B', 'BEACH 67 ST', 'BEACH 60 ST',
#        'BEACH 44 ST', 'BEACH 36 ST', 'BEACH 25 ST', 'FAR ROCKAWAY',
#        '161/YANKEE STAD', '167 ST', '170 ST', '174-175 STS', 'TREMONT AV',
#        '182-183 STS', 'FORDHAM RD', 'KINGSBRIDGE RD', 'BEDFORD PK BLVD',
#        'NORWOOD 205 ST', '5 AV/53 ST', 'LEXINGTON AV/53',
#        'COURT SQ-23 ST', 'QUEENS PLAZA', 'STEINWAY ST', '46 ST',
#        'NORTHERN BLVD', '65 ST', 'JKSN HT-ROOSVLT', 'ELMHURST AV',
#        'GRAND-NEWTOWN', '63 DR-REGO PARK', '67 AV', 'FOREST HILLS 71',
#        '75 AV', 'KEW GARDENS', 'BRIARWOOD', 'SUTPHIN BLVD',
#        'PARSONS BLVD', '169 ST', 'JAMAICA 179 ST', 'COURT SQ', '21 ST',
#        'GREENPOINT AV', 'NASSAU AV', 'BROADWAY', 'MYRTLE-WILLOUGH',
#        'BEDFORD-NOSTRAN', 'CLASSON AV', '47-50 STS ROCK',
#        '42 ST-BRYANT PK', "B'WAY-LAFAYETTE", '2 AV', 'EAST BROADWAY',
#        'YORK ST', 'BERGEN ST', 'CARROLL ST', 'SMITH-9 ST', '4 AV-9 ST',
#        '15 ST-PROSPECT', 'DITMAS AV', 'AVENUE I', 'AVENUE N', 'AVENUE P',
#        'AVENUE X', 'NEPTUNE AV', '57 ST', 'LEXINGTON AV/63',
#        'ROOSEVELT ISLND', '21 ST-QNSBRIDGE', 'JAMAICA VAN WK',
#        'SUTPHIN-ARCHER', 'JAMAICA CENTER', '72 ST-2 AVE', '86 ST-2 AVE',
#        '96 ST-2 AVE', 'NEWARK HW BMEBE', 'HARRISON', 'JOURNAL SQUARE',
#        'GROVE STREET', 'EXCHANGE PLACE', 'PAVONIA/NEWPORT', 'CITY / BUS',
#        'CHRISTOPHER ST', '9TH STREET', '14TH STREET', 'TWENTY THIRD ST',
#        'THIRTY ST', 'LACKAWANNA', 'THIRTY THIRD ST', 'NEWARK BM BW',
#        'NEWARK C', 'NEWARK HM HE', 'PATH WTC 2', 'PATH NEW WTC',
#        'SOUTH FERRY', 'WALL ST', 'FRANKLIN ST', 'HOUSTON ST', '18 ST',
#        '66 ST-LINCOLN', '116 ST-COLUMBIA', '137 ST CITY COL', '157 ST',
#        '191 ST', '207 ST', '215 ST', 'MARBLE HILL-225', '231 ST',
#        '238 ST', 'V.CORTLANDT PK', 'BOWLING GREEN', 'BROOKLYN BRIDGE',
#        'BLEECKER ST', 'ASTOR PL', '33 ST', 'GRD CNTRL-42 ST', '51 ST',
#        '68ST-HUNTER CO', '110 ST', '138/GRAND CONC', '149/GRAND CONC',
#        'MT EDEN AV', '176 ST', 'BURNSIDE AV', '183 ST', 'MOSHOLU PKWY',
#        'WOODLAWN', 'CENTRAL PK N110', 'HARLEM 148 ST', '3 AV-149 ST',
#        'JACKSON AV', 'INTERVALE AV', 'SIMPSON ST', 'FREEMAN ST', '174 ST',
#        'WEST FARMS SQ', 'E 180 ST', 'BRONX PARK EAST', 'PELHAM PKWY',
#        'ALLERTON AV', 'BURKE AV', 'GUN HILL RD', '219 ST', '225 ST',
#        '233 ST', 'NEREID AV', 'WAKEFIELD/241', '3 AV 138 ST', 'BROOK AV',
#        'CYPRESS AV', "E 143/ST MARY'S", 'E 149 ST', 'LONGWOOD AV',
#        'HUNTS POINT AV', 'WHITLOCK AV', 'ELDER AV', 'MORISN AV/SNDVW',
#        'ST LAWRENCE AV', 'PARKCHESTER', 'CASTLE HILL AV', 'ZEREGA AV',
#        'WESTCHESTER SQ', 'MIDDLETOWN RD', 'BUHRE AV', 'PELHAM BAY PARK',
#        '5 AVE', 'VERNON-JACKSON', 'HUNTERS PT AV', 'QUEENSBORO PLZ',
#        '39 AV', 'ASTORIA BLVD', 'ASTORIA DITMARS', '33 ST-RAWSON ST',
#        '40 ST LOWERY ST', '46 ST BLISS ST', '52 ST', '61 ST WOODSIDE',
#        '69 ST', '74 ST-BROADWAY', '82 ST-JACKSON H', '90 ST-ELMHURST',
#        'JUNCTION BLVD', '103 ST-CORONA', 'METS-WILLETS PT',
#        'FLUSHING-MAIN', '34 ST-HUDSON YD', 'CLARK ST', 'HOYT ST',
#        'NEVINS ST', 'GRAND ARMY PLAZ', 'EASTN PKWY-MUSM', 'KINGSTON AV',
#        'CROWN HTS-UTICA', 'SUTTER AV-RUTLD', 'SARATOGA AV', 'JUNIUS ST',
#        'PENNSYLVANIA AV', 'NEW LOTS AV', 'PRESIDENT ST', 'STERLING ST',
#        'WINTHROP ST', 'BEVERLY RD', 'NEWKIRK AV', 'FLATBUSH AV-B.C',
#        'MORRIS PARK', 'BAYCHESTER AV', 'EASTCHSTER/DYRE', 'ST. GEORGE',
#        'TOMPKINSVILLE', 'RIT-MANHATTAN', 'RIT-ROOSEVELT'], dtype=object)

# %%
# Fetch lat long data from goeocode API
stations = stations + " station, NY"
def getlatlong(ser):
    latlong_dict = dict()
    for station in ser:
        try:
            latlong = gmaps.geocode(station)[0]["geometry"]["location"]
            latlong_dict[station] = latlong
            if len(latlong_dict) % 50 == 0:
                print("index =", len(latlong_dict), "latlong =", latlong)
        except IndexError:
            print("index error at index=", len(latlong_dict))
            pass
    return latlong_dict
latlong_dict = getlatlong(stations)
# Out:
# index error at index= 15
# index = 50 latlong = {'lat': 40.634967, 'lng': -74.023377}
# index error at index= 66
# index = 100 latlong = {'lat': 40.68141, 'lng': -73.880039}
# index = 150 latlong = {'lat': 40.67413, 'lng': -73.88074999999999}
# index error at index= 156
# index = 200 latlong = {'lat': 40.7467885, 'lng': -73.944548}
# index error at index= 209
# index error at index= 233
# index error at index= 246
# index error at index= 247
# index = 250 latlong = {'lat': 40.7017312, 'lng': -74.0129477}
# index = 300 latlong = {'lat': 40.893193, 'lng': -73.85747300000001}
# index = 350 latlong = {'lat': 40.661561, 'lng': -73.9160182}

# %%
stations = stations + " station, NY"
def getzipcode(ser):
    station_dict = dict()
    for station in ser:
        try:
            zipcode = gmaps.geocode(station)[0]["address_components"][-1]['long_name']
            station_dict[station] = zipcode
            if len(station_dict) % 50 == 0:
                print("index =", len(station_dict), "zipcode =", zipcode)
        except IndexError:
            print("index error at index=", len(station_dict))
            pass
    return station_dict
station_dict = getzipcode(stations)

# %% [markdown]
# ### station_dict & latlong

# %%
# # save dictionary as text
# import csv
# f = open("station_dict.txt","w")
# f.write( str(station_dict) )
# f.close()

# save dictionary as text
import csv
f = open("latlong_dict.txt","w")
f.write( str(station_dict) )
f.close()

# %%
#Write Dictionary to CSV file

#Convert Dictionary to Dataframe, convert non-zipcodes to NaN, zipcodes to integers
zipcode_df = pd.DataFrame(list(station_dict.items()), columns=['STATION', 'zipcode'])
latlong_df = pd.DataFrame(list(latlong_dict.items()), columns=['STATION', 'latlong'])
# ****** where trouble begins
#zipcode_df["STATION"] = zipcode_df["STATION"].str.replace(" stations, NY","")
zipcode_df["STATION"] = zipcode_df["STATION"].replace("\sstation,\sNY","", regex = True)
zipcode_df.head()
# Out:
#           STATION   zipcode
# 0           59 ST  New York
# 1      5 AV/59 ST     10022
# 2      57 ST-7 AV     10106
# 3           49 ST     10020
# 4  TIMES SQ-42 ST  New York

# %%
#Write Dictionary to CSV file
latlong_df = pd.DataFrame.from_dict(latlong_dict).T
#latlong_df["STATION"] = latlong_df.index
latlong_df.reset_index(level=latlong_df.index.names, inplace=True)
latlong_df = latlong_df.rename(columns={"index": "STATION"})
latlong_df["STATION"]= latlong_df["STATION"].replace("\sstation,\sNY","", regex = True)
latlong_df.lng.describe()
# Out:
# count    366.000000
# mean     -73.960446
# std        0.273200
# min      -77.674344
# 25%      -73.982790
# 50%      -73.944814
# 75%      -73.891724
# max      -73.711962
# Name: lng, dtype: float64

# %%
zipcode_df["zipcode"] = pd.to_numeric(zipcode_df["zipcode"],errors='coerce',downcast='integer')

# Find assigned values (google geocode could not locate the zipcode, or wrongly identifies the zipcode)
unassigned = zipcode_df[(zipcode_df.zipcode.isnull()) | (zipcode_df.zipcode < 10000)]
unassigned
# Out:
#              STATION  zipcode
# 0              59 ST      NaN
# 4     TIMES SQ-42 ST      NaN
# 8     14 ST-UNION SQ      NaN
# 10         PRINCE ST   3209.0
# 16            BOWERY   2811.0
# 41    ATL AV-BARCLAY      NaN
# 61             55 ST   2718.0
# 67              6 AV   2719.0
# 78         HALSEY ST      NaN
# 87    HOWARD BCH JFK      NaN
# 107           121 ST   2740.0
# 129   59 ST COLUMBUS      NaN
# 152            80 ST   2719.0
# 190            67 AV   2718.0
# 193      KEW GARDENS      NaN
# 229   JAMAICA CENTER      NaN
# 234   JOURNAL SQUARE   7306.0
# 235     GROVE STREET   7302.0
# 236   EXCHANGE PLACE   7302.0
# 237  PAVONIA/NEWPORT   7310.0
# 244       LACKAWANNA   1552.0
# 245  THIRTY THIRD ST      NaN
# 246         NEWARK C   7114.0
# 258           191 ST   2740.0
# 324            39 AV   2718.0
# 330            52 ST   2719.0
# 334  82 ST-JACKSON H      NaN
# 352      NEW LOTS AV      NaN
# 364    RIT-MANHATTAN   5603.0

# %%
#Assign mislocated or missing zipcodes manually
zipcode_df.iloc[0,1] = 11207.0
zipcode_df.iloc[4,1] = 10018.0
zipcode_df.iloc[8,1] = 10003.0
zipcode_df.iloc[10,1] = 10012.0
zipcode_df.iloc[16,1] = 10002.0
zipcode_df.iloc[41,1] = 11217.0
zipcode_df.iloc[61,1] = 11219.0
zipcode_df.iloc[67,1] = 10019.0
zipcode_df.iloc[78,1] = 11207.0
zipcode_df.iloc[87,1] = 11430.0
zipcode_df.iloc[107,1] = 11418.0
zipcode_df.iloc[129,1] = 10023.0
zipcode_df.iloc[152,1] = 11416.0
zipcode_df.iloc[190,1] = 11375.0
zipcode_df.iloc[193,1] = 11415.0
zipcode_df.iloc[229,1] = 11432.0
#skip new jersey stations & lackawanna
zipcode_df.iloc[245,1] = 10001.0
#new jersey ewark c
zipcode_df.iloc[258,1] = 10040.0
zipcode_df.iloc[324,1] = 11101.0
zipcode_df.iloc[330,1] = 11377.0
zipcode_df.iloc[334,1] = 11372.0
zipcode_df.iloc[352,1] = 11212.0
#RIT-MANHATTA don't know

# unassigned = zipcode_df[(zipcode_df.zipcode.isnull()) | (zipcode_df.zipcode < 10000)]
# unassigned

# %%
zipcode_df.zipcode = zipcode_df.zipcode.astype("int64")
#zipcode_df.info()

# %%
#Save the zipcode dataframe to CSV file
zipcode_df.to_csv("zipcode_df.csv")

# %%
latlong_df.to_csv("latlong_df.csv")

# %%
#pd.merge(df, zipcode_df,on="STATION")
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, SCP, STATION, LINENAME, DIVISION, DATE, TIME, DESC, ENTRIES, EXITS, zipcode]
# Index: []

# %%
set([1,2,3]) - set([2,3,4])
# Out:
# {1}

# %%
zipcode_df[zipcode_df["STATION"] == "WHITEHALL S-FRY"]
#len(zipcode_df)
# Out:
# Empty DataFrame
# Columns: [STATION, zipcode]
# Index: []

# %%
index error at index= 15
index = 50 zipcode = 11220
index error at index= 66
index = 100 zipcode = 11208
index = 150 zipcode = 11208
index error at index= 156
index = 200 zipcode = 11101
index error at index= 209
index error at index= 233
index error at index= 246
index error at index= 247
# Out:
# 7

# %%
stations = df["STATION"].unique()

# %%
stations[[15,66, 156, 209, 233, 246, 247]]
# Out:
# array(['WHITEHALL S-FRY', 'BAY 50 ST', 'ROCKAWAY BLVD', 'CLASSON AV',
#        'JAMAICA CENTER', '14TH STREET', 'TWENTY THIRD ST'], dtype=object)

# %%
station_dict
# Out:
# {'1 AV station, NY': '10017',
#  '103 ST station, NY': '10029',
#  '103 ST-CORONA station, NY': '11368',
#  '104 ST station, NY': '11418',
#  '110 ST station, NY': '10025',
#  '111 ST station, NY': '11368',
#  '116 ST station, NY': '10027',
#  '116 ST-COLUMBIA station, NY': '10027',
#  '121 ST station, NY': '2740',
#  '125 ST station, NY': '10035',
#  '135 ST station, NY': '10030',
#  '137 ST CITY COL station, NY': '10031',
#  '138/GRAND CONC station, NY': '10451',
#  '14 ST station, NY': '10011',
#  '14 ST-UNION SQ station, NY': 'United States',
#  '145 ST station, NY': '10031',
#  '149/GRAND CONC station, NY': '10451',
#  '14TH STREET station, NY': '10011',
#  '15 ST-PROSPECT station, NY': '11215',
#  '155 ST station, NY': '10039',
#  '157 ST station, NY': '10032',
#  '161/YANKEE STAD station, NY': '10451',
#  '163 ST-AMSTERDM station, NY': '10032',
#  '167 ST station, NY': '10452',
#  '168 ST station, NY': '10032',
#  '169 ST station, NY': '11432',
#  '170 ST station, NY': '10452',
#  '174 ST station, NY': '10460',
#  '174-175 STS station, NY': '10453',
#  '175 ST station, NY': '10033',
#  '176 ST station, NY': '10453',
#  '18 AV station, NY': '11204',
#  '18 ST station, NY': '10011',
#  '181 ST station, NY': '10040',
#  '182-183 STS station, NY': '10457',
#  '183 ST station, NY': '10453',
#  '190 ST station, NY': '10040',
#  '191 ST station, NY': '2740',
#  '2 AV station, NY': '10003',
#  '20 AV station, NY': '10309',
#  '207 ST station, NY': '10034',
#  '21 ST station, NY': '11101',
#  '21 ST-QNSBRIDGE station, NY': '11101',
#  '215 ST station, NY': '10034',
#  '219 ST station, NY': '10467',
#  '225 ST station, NY': '10034',
#  '23 ST station, NY': '10010',
#  '231 ST station, NY': '10463',
#  '233 ST station, NY': '10466',
#  '238 ST station, NY': '10463',
#  '25 AV station, NY': '11214',
#  '25 ST station, NY': '11232',
#  '28 ST station, NY': '10001',
#  '3 AV 138 ST station, NY': '10454',
#  '3 AV station, NY': '10003',
#  '3 AV-149 ST station, NY': '10455',
#  '33 ST station, NY': '10001',
#  '33 ST-RAWSON ST station, NY': '11101',
#  '34 ST-HERALD SQ station, NY': '11003',
#  '34 ST-HUDSON YD station, NY': '10001',
#  '34 ST-PENN STA station, NY': '10119',
#  '36 ST station, NY': '10012',
#  '39 AV station, NY': '2718',
#  '4 AV-9 ST station, NY': '11215',
#  '40 ST LOWERY ST station, NY': '11104',
#  '42 ST-BRYANT PK station, NY': '10021',
#  '42 ST-PORT AUTH station, NY': '10036',
#  '45 ST station, NY': '11220',
#  '46 ST BLISS ST station, NY': '11104',
#  '46 ST station, NY': '11103',
#  '47-50 STS ROCK station, NY': '10020',
#  '49 ST station, NY': '10020',
#  '4AV-9 ST station, NY': '11215',
#  '5 AV/53 ST station, NY': '10022',
#  '5 AV/59 ST station, NY': '10022',
#  '5 AVE station, NY': '10022',
#  '50 ST station, NY': '10019',
#  '51 ST station, NY': '10022',
#  '52 ST station, NY': '2719',
#  '53 ST station, NY': '10022',
#  '55 ST station, NY': '2718',
#  '57 ST station, NY': '10106',
#  '57 ST-7 AV station, NY': '10106',
#  '59 ST COLUMBUS station, NY': 'New York',
#  '59 ST station, NY': 'New York',
#  '6 AV station, NY': '2719',
#  '61 ST WOODSIDE station, NY': '11377',
#  '63 DR-REGO PARK station, NY': '11374',
#  '65 ST station, NY': '11377',
#  '66 ST-LINCOLN station, NY': '10023',
#  '67 AV station, NY': '2718',
#  '68ST-HUNTER CO station, NY': '10021',
#  '69 ST station, NY': '11377',
#  '7 AV station, NY': '10106',
#  '71 ST station, NY': '11375',
#  '72 ST station, NY': '10021',
#  '72 ST-2 AVE station, NY': '10021',
#  '74 ST-BROADWAY station, NY': '11372',
#  '75 AV station, NY': '11375',
#  '75 ST-ELDERTS station, NY': '11421',
#  '77 ST station, NY': '10075',
#  '79 ST station, NY': '11220',
#  '8 AV station, NY': '10014',
#  '8 ST-NYU station, NY': '10003',
#  '80 ST station, NY': '2719',
#  '81 ST-MUSEUM station, NY': '10024',
#  '82 ST-JACKSON H station, NY': 'New York',
#  '85 ST-FOREST PK station, NY': '11421',
#  '86 ST station, NY': '10028',
#  '86 ST-2 AVE station, NY': '10028',
#  '88 ST station, NY': '11417',
#  '9 AV station, NY': '11219',
#  '90 ST-ELMHURST station, NY': '11372',
#  '96 ST station, NY': '10025',
#  '96 ST-2 AVE station, NY': '10128',
#  '9TH STREET station, NY': '10011',
#  'ALABAMA AV station, NY': '11207',
#  'ALLERTON AV station, NY': '10467',
#  'AQUEDUCT RACETR station, NY': '11417',
#  'ASTOR PL station, NY': '10003',
#  'ASTORIA BLVD station, NY': '11102',
#  'ASTORIA DITMARS station, NY': '11105',
#  'ATL AV-BARCLAY station, NY': 'New York',
#  'ATLANTIC AV station, NY': '11243',
#  'AVENUE H station, NY': '11230',
#  'AVENUE I station, NY': '11230',
#  'AVENUE J station, NY': '11230',
#  'AVENUE M station, NY': '11230',
#  'AVENUE N station, NY': '11230',
#  'AVENUE P station, NY': '11230',
#  'AVENUE U station, NY': '11223',
#  'AVENUE X station, NY': '11223',
#  'BAY 50 ST station, NY': '11214',
#  'BAY PKWY station, NY': '11204',
#  'BAY RIDGE AV station, NY': '11220',
#  'BAY RIDGE-95 ST station, NY': '11209',
#  'BAYCHESTER AV station, NY': '10469',
#  'BEACH 105 ST station, NY': '11694',
#  'BEACH 25 ST station, NY': '11691',
#  'BEACH 36 ST station, NY': '11691',
#  'BEACH 44 ST station, NY': '11691',
#  'BEACH 60 ST station, NY': '11692',
#  'BEACH 67 ST station, NY': '11692',
#  'BEACH 90 ST station, NY': '11693',
#  'BEACH 98 ST station, NY': '11694',
#  'BEDFORD AV station, NY': '11211',
#  'BEDFORD PK BLVD station, NY': '10468',
#  'BEDFORD-NOSTRAN station, NY': '11205',
#  'BERGEN ST station, NY': '11201',
#  'BEVERLEY ROAD station, NY': '11226',
#  'BEVERLY RD station, NY': '11226',
#  'BLEECKER ST station, NY': '10012',
#  'BOROUGH HALL station, NY': '11201',
#  'BOTANIC GARDEN station, NY': '10458',
#  'BOWERY station, NY': '2811',
#  'BOWLING GREEN station, NY': '10004',
#  'BRIARWOOD station, NY': '11435',
#  'BRIGHTON BEACH station, NY': '11235',
#  'BROAD CHANNEL station, NY': '11693',
#  'BROAD ST station, NY': '10005',
#  'BROADWAY JCT station, NY': '10533',
#  'BROADWAY station, NY': '11106',
#  'BRONX PARK EAST station, NY': '10462',
#  'BROOK AV station, NY': '10454',
#  'BROOKLYN BRIDGE station, NY': '10038',
#  'BUHRE AV station, NY': '10461',
#  'BURKE AV station, NY': '10467',
#  'BURNSIDE AV station, NY': '10453',
#  'BUSHWICK AV station, NY': '11207',
#  'CANAL ST station, NY': '10013',
#  'CANARSIE-ROCKAW station, NY': '11236',
#  'CARROLL ST station, NY': '11231',
#  'CASTLE HILL AV station, NY': '10462',
#  'CATHEDRAL PKWY station, NY': '10025',
#  'CENTRAL PK N110 station, NY': '10026',
#  'CHAMBERS ST station, NY': '10013',
#  'CHAUNCEY ST station, NY': '11207',
#  'CHRISTOPHER ST station, NY': '10014',
#  'CHURCH AV station, NY': '11218',
#  'CITY / BUS station, NY': '10018',
#  'CITY HALL station, NY': '10007',
#  'CLARK ST station, NY': '11201',
#  'CLASSON AV station, NY': '11238',
#  'CLEVELAND ST station, NY': '11208',
#  'CLINTON-WASH AV station, NY': '11205',
#  'CORTELYOU RD station, NY': '11226',
#  'CORTLANDT ST station, NY': '10006',
#  'COURT SQ station, NY': '11101',
#  'COURT SQ-23 ST station, NY': '11101',
#  'CRESCENT ST station, NY': '11208',
#  'CROWN HTS-UTICA station, NY': '11213',
#  'CYPRESS AV station, NY': '10454',
#  'CYPRESS HILLS station, NY': '11208',
#  'DEKALB AV station, NY': '11217',
#  'DELANCEY/ESSEX station, NY': '10002',
#  'DITMAS AV station, NY': '11218',
#  'DYCKMAN ST station, NY': '10040',
#  "E 143/ST MARY'S station, NY": '10454',
#  'E 149 ST station, NY': '10451',
#  'E 180 ST station, NY': '10460',
#  'EAST 105 ST station, NY': '11236',
#  'EAST BROADWAY station, NY': '10002',
#  'EASTCHSTER/DYRE station, NY': '10466',
#  'EASTN PKWY-MUSM station, NY': '11238',
#  'ELDER AV station, NY': '10472',
#  'ELMHURST AV station, NY': '11372',
#  'EUCLID AV station, NY': '11208',
#  'EXCHANGE PLACE station, NY': '07302',
#  'FAR ROCKAWAY station, NY': '11691',
#  'FLATBUSH AV-B.C station, NY': '11217',
#  'FLUSHING AV station, NY': '11206',
#  'FLUSHING-MAIN station, NY': '11354',
#  'FORDHAM RD station, NY': '10458',
#  'FOREST AVE station, NY': '11375',
#  'FOREST HILLS 71 station, NY': '11375',
#  'FRANKLIN AV station, NY': '11238',
#  'FRANKLIN ST station, NY': '10013',
#  'FREEMAN ST station, NY': '10459',
#  'FRESH POND RD station, NY': '11385',
#  'FT HAMILTON PKY station, NY': '11218',
#  'FULTON ST station, NY': '10038',
#  'GATES AV station, NY': '11221',
#  'GRAHAM AV station, NY': '11211',
#  'GRAND ARMY PLAZ station, NY': '11238',
#  'GRAND ST station, NY': '10017',
#  'GRAND-NEWTOWN station, NY': '11373',
#  'GRANT AV station, NY': '11208',
#  'GRD CNTRL-42 ST station, NY': '10017',
#  'GREENPOINT AV station, NY': '11222',
#  'GROVE STREET station, NY': '07302',
#  'GUN HILL RD station, NY': '10467',
#  'HALSEY ST station, NY': 'New York',
#  'HARLEM 148 ST station, NY': '10039',
#  'HARRISON station, NY': '10528',
#  'HEWES ST station, NY': '11211',
#  'HIGH ST station, NY': '11201',
#  'HOUSTON ST station, NY': '10014',
#  'HOWARD BCH JFK station, NY': 'New York',
#  'HOYT ST station, NY': '11201',
#  'HOYT-SCHER station, NY': '11201',
#  'HUNTERS PT AV station, NY': '11101',
#  'HUNTS POINT AV station, NY': '10474',
#  'INTERVALE AV station, NY': '10459',
#  'INWOOD-207 ST station, NY': '10034',
#  'JACKSON AV station, NY': '10455',
#  'JAMAICA 179 ST station, NY': '11432',
#  'JAMAICA CENTER station, NY': 'New York',
#  'JAMAICA VAN WK station, NY': '11418',
#  'JAY ST-METROTEC station, NY': '11201',
#  'JEFFERSON ST station, NY': '11237',
#  'JFK JAMAICA CT1 station, NY': '11435',
#  'JKSN HT-ROOSVLT station, NY': '11372',
#  'JOURNAL SQUARE station, NY': '07306',
#  'JUNCTION BLVD station, NY': '11368',
#  'JUNIUS ST station, NY': '11212',
#  'KEW GARDENS station, NY': 'United States',
#  'KINGS HWY station, NY': '11229',
#  'KINGSBRIDGE RD station, NY': '10458',
#  'KINGSTON AV station, NY': '11213',
#  'KINGSTON-THROOP station, NY': '11213',
#  'KOSCIUSZKO ST station, NY': '11221',
#  'LACKAWANNA station, NY': '1552',
#  'LAFAYETTE AV station, NY': '11217',
#  'LEXINGTON AV/53 station, NY': '10022',
#  'LEXINGTON AV/63 station, NY': '10065',
#  'LIBERTY AV station, NY': '11207',
#  'LIVONIA AV station, NY': '11212',
#  'LONGWOOD AV station, NY': '10455',
#  'LORIMER ST station, NY': '11211',
#  'MARBLE HILL-225 station, NY': '10034',
#  'MARCY AV station, NY': '11211',
#  'METROPOLITAN AV station, NY': '11379',
#  'METS-WILLETS PT station, NY': '11368',
#  'MIDDLETOWN RD station, NY': '10461',
#  'MONTROSE AV station, NY': '11206',
#  'MORGAN AV station, NY': '11237',
#  'MORISN AV/SNDVW station, NY': '10472',
#  'MORRIS PARK station, NY': '10462',
#  'MOSHOLU PKWY station, NY': '10467',
#  'MT EDEN AV station, NY': '10452',
#  'MYRTLE AV station, NY': '11206',
#  'MYRTLE-WILLOUGH station, NY': '11206',
#  'MYRTLE-WYCKOFF station, NY': '11237',
#  'NASSAU AV station, NY': '11222',
#  'NECK RD station, NY': '11229',
#  'NEPTUNE AV station, NY': '11224',
#  'NEREID AV station, NY': '10119',
#  'NEVINS ST station, NY': '11217',
#  'NEW LOTS AV station, NY': 'New York',
#  'NEW LOTS station, NY': '11212',
#  'NEW UTRECHT AV station, NY': '11219',
#  'NEWARK C station, NY': '07114',
#  'NEWKIRK AV station, NY': '11226',
#  'NEWKIRK PLAZA station, NY': '11226',
#  'NORTHERN BLVD station, NY': '11377',
#  'NORWOOD 205 ST station, NY': '10467',
#  'NORWOOD AV station, NY': '11208',
#  'NOSTRAND AV station, NY': '11216',
#  'OCEAN PKWY station, NY': '11235',
#  'OZONE PK LEFFRT station, NY': '11419',
#  'PARK PLACE station, NY': '11238',
#  'PARKCHESTER station, NY': '10472',
#  'PARKSIDE AV station, NY': '11226',
#  'PARSONS BLVD station, NY': '11432',
#  'PATH NEW WTC station, NY': '10007',
#  'PATH WTC 2 station, NY': '10007',
#  'PAVONIA/NEWPORT station, NY': '07310',
#  'PELHAM BAY PARK station, NY': '10461',
#  'PELHAM PKWY station, NY': '10803',
#  'PENNSYLVANIA AV station, NY': '11207',
#  'PRESIDENT ST station, NY': '11225',
#  'PRINCE ST station, NY': '3209',
#  'PROSPECT AV station, NY': '11215',
#  'PROSPECT PARK station, NY': '11226',
#  'QUEENS PLAZA station, NY': '11101',
#  'QUEENSBORO PLZ station, NY': '11101',
#  'RALPH AV station, NY': '11233',
#  'RECTOR ST station, NY': '10006',
#  'RIT-MANHATTAN station, NY': '5603',
#  'RIT-ROOSEVELT station, NY': '11372',
#  'ROCKAWAY AV station, NY': '11224',
#  'ROCKAWAY BLVD station, NY': '11417',
#  'ROCKAWAY PARK B station, NY': '11694',
#  'ROOSEVELT ISLND station, NY': '10022',
#  'SARATOGA AV station, NY': '11212',
#  'SENECA AVE station, NY': '11385',
#  'SHEEPSHEAD BAY station, NY': '11235',
#  'SHEPHERD AV station, NY': '11208',
#  'SIMPSON ST station, NY': '10459',
#  'SMITH-9 ST station, NY': '11231',
#  'SOUTH FERRY station, NY': '10004',
#  'SPRING ST station, NY': '10013',
#  'ST LAWRENCE AV station, NY': '10472',
#  'ST. GEORGE station, NY': '10301',
#  'STEINWAY ST station, NY': '11103',
#  'STERLING ST station, NY': '11225',
#  'SUTPHIN BLVD station, NY': '11435',
#  'SUTPHIN-ARCHER station, NY': '11435',
#  'SUTTER AV station, NY': '11212',
#  'SUTTER AV-RUTLD station, NY': '11212',
#  'THIRTY ST station, NY': '19104',
#  'THIRTY THIRD ST station, NY': 'New York',
#  'TIMES SQ-42 ST station, NY': 'New York',
#  'TOMPKINSVILLE station, NY': '10304',
#  'TREMONT AV station, NY': '10457',
#  'TWENTY THIRD ST station, NY': '10010',
#  'UNION ST station, NY': '11215',
#  'UTICA AV station, NY': '11213',
#  'V.CORTLANDT PK station, NY': '10471',
#  'VAN SICLEN AV station, NY': '11207',
#  'VAN SICLEN AVE station, NY': '11207',
#  'VERNON-JACKSON station, NY': '11101',
#  'W 4 ST-WASH SQ station, NY': '10012',
#  'W 8 ST-AQUARIUM station, NY': '11224',
#  'WAKEFIELD/241 station, NY': '10470',
#  'WALL ST station, NY': '10038',
#  'WEST FARMS SQ station, NY': '10460',
#  'WESTCHESTER SQ station, NY': '10461',
#  'WHITLOCK AV station, NY': '10459',
#  'WILSON AV station, NY': '11207',
#  'WINTHROP ST station, NY': '11225',
#  'WOODHAVEN BLVD station, NY': '11373',
#  'WOODLAWN station, NY': '10466',
#  'WORLD TRADE CTR station, NY': '10006',
#  'YORK ST station, NY': '11201',
#  'ZEREGA AV station, NY': '10462'}

# %%
#date_time = pd.to_datetime(df.DATE + " " + df.TIME, format= "%m/%d/%Y %H:%M:%S")
#df.insert(loc=8, column= "DATE_TIME", value=date_time)
time = df.DATE_TIME.dt.time
df.insert(loc=9, column = "TIME_TIME", value=time)

# %%
#df_r.groupby(["C/A","UNIT","SCP","STATION","LINENAME","DATE"]).ENTRIES.diff()
df["entry_diff"]
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 5        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 6        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 7        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 8        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 9        A002  R051  02-00-00          59 ST  NQR456W      BMT
# 10       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 11       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 12       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 13       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 14       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 15       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 16       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 17       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 18       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 19       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 20       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 21       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 22       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 23       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 24       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 25       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 26       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 27       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 28       A002  R051  02-00-00          59 ST  NQR456W      BMT
# 29       A002  R051  02-00-00          59 ST  NQR456W      BMT
# ...       ...   ...       ...            ...      ...      ...
# 196624  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196625  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196626  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196627  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196628  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196629  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196630  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196631  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196632  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196633  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196634  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196635  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196636  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196637  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196638  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196639  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196640  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196641  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196642  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196643  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196644  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196645  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196646  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196647  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196648  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196649  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196650  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196651  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196652  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
# 196653  TRAM2  R469  00-03-01  RIT-ROOSEVELT        R      RIT
#
#                  DATE_TIME        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0      2018-03-10 03:00:00  03/10/2018  03:00:00  REGULAR  6543902  2216231
# 1      2018-03-10 07:00:00  03/10/2018  07:00:00  REGULAR  6543916  2216241
# 2      2018-03-10 11:00:00  03/10/2018  11:00:00  REGULAR  6543983  2216334
# 3      2018-03-10 15:00:00  03/10/2018  15:00:00  REGULAR  6544182  2216387
# 4      2018-03-10 19:00:00  03/10/2018  19:00:00  REGULAR  6544513  2216441
# 5      2018-03-10 23:00:00  03/10/2018  23:00:00  REGULAR  6544689  2216466
# 6      2018-03-11 04:00:00  03/11/2018  04:00:00  REGULAR  6544729  2216471
# 7      2018-03-11 08:00:00  03/11/2018  08:00:00  REGULAR  6544734  2216487
# 8      2018-03-11 12:00:00  03/11/2018  12:00:00  REGULAR  6544774  2216539
# 9      2018-03-11 16:00:00  03/11/2018  16:00:00  REGULAR  6544947  2216578
# 10     2018-03-11 20:00:00  03/11/2018  20:00:00  REGULAR  6545167  2216621
# 11     2018-03-12 00:00:00  03/12/2018  00:00:00  REGULAR  6545250  2216637
# 12     2018-03-12 04:00:00  03/12/2018  04:00:00  REGULAR  6545258  2216638
# 13     2018-03-12 08:00:00  03/12/2018  08:00:00  REGULAR  6545285  2216738
# 14     2018-03-12 12:00:00  03/12/2018  12:00:00  REGULAR  6545418  2216964
# 15     2018-03-12 16:00:00  03/12/2018  16:00:00  REGULAR  6545699  2217016
# 16     2018-03-12 20:00:00  03/12/2018  20:00:00  REGULAR  6546482  2217083
# 196645 2018-03-29 13:00:00  03/29/2018  13:00:00  REGULAR  2867407   385546
# 196646 2018-03-29 17:00:00  03/29/2018  17:00:00  REGULAR  2867494   385550
# 196647 2018-03-29 21:00:00  03/29/2018  21:00:00  REGULAR  2867574   385554
# 196648 2018-03-30 01:00:00  03/30/2018  01:00:00  REGULAR  2867588   385560
# 196649 2018-03-30 05:00:00  03/30/2018  05:00:00  REGULAR  2867588   385563
# 196650 2018-03-30 09:00:00  03/30/2018  09:00:00  REGULAR  2867598   385564
# 196651 2018-03-30 13:00:00  03/30/2018  13:00:00  REGULAR  2867643   385566
# 196652 2018-03-30 17:00:00  03/30/2018  17:00:00  REGULAR  2867744   385567
# 196653 2018-03-30 21:00:00  03/30/2018  21:00:00  REGULAR  2867815   385572
#
#         day_of_week TIME_TIME
# 0                 5  03:00:00
# 1                 5  07:00:00
# 2                 5  11:00:00
# 3                 5  15:00:00
# 4                 5  19:00:00
# 5                 5  23:00:00
# 6                 6  04:00:00
# 7                 6  08:00:00
# 8                 6  12:00:00
# 9                 6  16:00:00
# 10                6  20:00:00
# 11                0  00:00:00
# 12                0  04:00:00
# 13                0  08:00:00
# 14                0  12:00:00
# 15                0  16:00:00
# 16                0  20:00:00
# 17                1  00:00:00
# 18                1  04:00:00
# 19                1  08:00:00
# 20                1  12:00:00
# 21                1  16:00:00
# 22                1  20:00:00
# 23                2  00:00:00
# 24                2  04:00:00
# 25                2  08:00:00
# 26                2  12:00:00
# 27                2  16:00:00
# 28                2  20:00:00
# 29                3  00:00:00
# ...             ...       ...
# 196624            6  21:00:00
# 196625            0  01:00:00
# 196626            0  05:00:00
# 196627            0  09:00:00
# 196628            0  13:00:00
# 196629            0  17:00:00
# 196630            0  21:00:00
# 196631            1  01:00:00
# 196632            1  05:00:00
# 196633            1  09:00:00
# 196634            1  13:00:00
# 196635            1  17:00:00
# 196636            1  21:00:00
# 196637            2  01:00:00
# 196638            2  17:00:00
# 196639            2  21:00:00
# 196640            3  01:00:00
# 196641            3  05:00:00
# 196642            3  08:43:42
# 196643            3  08:44:44
# 196644            3  09:00:00
# 196645            3  13:00:00
# 196646            3  17:00:00
# 196647            3  21:00:00
# 196648            4  01:00:00
# 196649            4  05:00:00
# 196650            4  09:00:00
# 196651            4  13:00:00
# 196652            4  17:00:00
# 196653            4  21:00:00
#
# [775562 rows x 14 columns]

# %%
import datetime
data = np.random.rand(24)

#a list of time: 00:00:00 to 23:00:00
times = [datetime.datetime.strptime(str(i), '%H') for i in range(24)]
#'H' controls xticklabel format, 'H' means only the hours is shown
#day, year, week, month, etc are not shown
plt.plot_date(times, data, fmt='H')
plt.setp(plt.gca().xaxis.get_majorticklabels(),
         'rotation', 90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
def hr_func(ts):
    return ts.hour
#df['HOUR'] = df['TIME_TIME'].apply(hr_func)
df['TIME_TIME'][0]
# Out:
# 3

# %%
latlong_df[latlong_df["STATION"] == '23 ST']
# Out:
#    STATION        lat        lng
# 46   23 ST  40.742744 -73.992645
