# %%
#!pip install fuzzywuzzy
#!pip install python-Levenshtein
# Out:
# ...
#     100% |████████████████████████████████| 51kB 407kB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for python-Levenshtein ... done
#   Stored in directory: /Users/petermin/Library/Caches/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# ...

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import os
import json
from fuzzywuzzy import fuzz
# %matplotlib inline

# %%
neighborhoods = json.load(open("NY_neighborhoods.geojson.txt"))

# %%
neighborhoods
# Out:
# {'features': [{'geometry': {'coordinates': [[[-73.84859700000018,
#        40.871670000000115],
#       [-73.84582253683678, 40.870239076236174],
#       [-73.85455918463374, 40.85995383576425],
#       [-73.85466543306826, 40.859585694988056],
#       [-73.85638870335896, 40.85759363530448],
#       [-73.86888180915341, 40.857223150158326],
#       [-73.86831755272824, 40.85786206225831],
#       [-73.86955371467232, 40.85778409560018],
#       [-73.87102485762065, 40.857309948816905],
#       [-73.87048054998716, 40.865413584098484],
#       [-73.87055489856489, 40.86970279858986],
#       [-73.86721594442561, 40.86968966363671],
#       [-73.85745, 40.86953300000018],
#       [-73.85555000000011, 40.871813000000145],
#       [-73.85359796757658, 40.8732883686742],
#       [-73.84859700000018, 40.871670000000115]]],
#     'type': 'Polygon'},
#    'properties': {'@id': 'http://nyc.pediacities.com/Resource/Neighborhood/Allerton',
#     'borough': 'Bronx',
#     'boroughCode': '2',
# ...

# %%
nh_names = []
for i in neighborhoods['features']:
    name = i['properties']['neighborhood']
    nh_names.append(name)

# %%
# Out:
# ['Allerton',
#  'Alley Pond Park',
#  'Arden Heights',
#  'Arlington',
#  'Arrochar',
#  'Arverne',
#  'Astoria',
#  'Bath Beach',
#  'Battery Park City',
#  'Bay Ridge',
#  'Bay Terrace',
#  'Bay Terrace, Staten Island',
#  'Baychester',
#  'Bayside',
#  'Bayswater',
#  'Bayswater',
#  'Bedford-Stuyvesant',
#  'Belle Harbor',
#  'Bellerose',
#  'Belmont',
#  'Bensonhurst',
#  'Bergen Beach',
#  'Bloomfield',
#  'Boerum Hill',
#  'Borough Park',
#  'Breezy Point',
#  'Briarwood',
#  'Brighton Beach',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Broad Channel',
#  'Bronx Park',
#  'Bronxdale',
#  'Brooklyn Heights',
#  'Brownsville',
#  "Bull's Head",
#  'Bushwick',
#  'Cambria Heights',
#  'Canarsie',
#  'Carroll Gardens',
#  'Castle Hill',
#  'Castleton Corners',
#  'Central Park',
#  'Charleston',
#  'Chelsea',
#  'Chelsea, Staten Island',
# ...

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib as mpl
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
mpl.rcParams['figure.dpi']= 500
results = {"Facebook Prophet": 18.3, 
           "FP w/ Precipitation": 17.3,
           "GRU":14.5
          }
x = results.keys()
y = results.values()

# %%
sns.set_palette("PuBuGn_d")

# %%
sns.barplot(x=list(x),y=list(y))
plt.xticks(rotation=45)
plt.ylabel("RMSE")
plt.xlabel("Model")
plt.title("Comparison of Model Performance",fontsize=15);

# %%
(17.3-14.5)/17.3
# Out:
# 0.161849710982659
