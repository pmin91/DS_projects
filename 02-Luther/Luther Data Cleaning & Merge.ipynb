# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import seaborn as sns

# %%
# Import all the dataframes
mojo_df = pd.read_pickle('mojo_df.pkl')
youtube_df = pd.read_pickle('youtube_df.pkl')
omdb_df = pd.read_pickle('omdb_df.pkl')
director_df = pd.read_pickle('director_df.pkl')
actor_df = pd.read_pickle('actor_df.pkl')

# %%
#clean mojo df
mojo_df.opening = mojo_df.opening.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojo_df.opening = pd.to_numeric(mojo_df.opening)
mojo_df.tot_gross = mojo_df.tot_gross.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojo_df.tot_gross = pd.to_numeric(mojo_df.tot_gross)
mojo_df.theaters = mojo_df.theaters.replace(",","", regex = True).str.strip()
mojo_df.theaters = pd.to_numeric(mojo_df.theaters)
mojo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
# movie_name      500 non-null object
# movie           500 non-null object
# opening         500 non-null int64
# date_time       500 non-null datetime64[ns]
# release_date    500 non-null object
# theaters        500 non-null int64
# tot_gross       500 non-null int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 27.4+ KB

# %%
# Clean youtube df 
# select youtube df relevant data
youtube_df = youtube_df[["movie_name", "viewCount", "commentCount", "dislikeCount", "likeCount"]]

#replace nulls with 0
youtube_df = youtube_df.fillna(0)
# convert numeric str values to int
youtube_df.viewCount = pd.to_numeric(youtube_df.viewCount)
youtube_df.dislikeCount = pd.to_numeric(youtube_df.dislikeCount)
youtube_df.commentCount = pd.to_numeric(youtube_df.commentCount)
youtube_df.likeCount = pd.to_numeric(youtube_df.likeCount)
youtube_df = youtube_df.rename(columns ={"viewCount":"Yviews", "commentCount": "Ycomments", 
                                         "dislikeCount": "Ydislikes", "likeCount":"Ylikes"})
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# movie_name    500 non-null object
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 19.6+ KB

# %%
# Clean omdb data
omdb_df.imdb = pd.to_numeric(omdb_df.imdb.replace("/10","", regex = True).str.strip())
omdb_df.metacritic = pd.to_numeric(omdb_df.metacritic.replace("/100","", regex = True).str.strip())
omdb_df.rotten_tomatoes = pd.to_numeric(omdb_df.rotten_tomatoes.replace("%","", regex = True).str.strip())
omdb_df.runtime = pd.to_numeric(omdb_df.runtime.replace("min","", regex = True).str.strip())
omdb_df.year = pd.to_numeric(omdb_df.year)
# Remove 11 movies that have been wrongly identified on omdb (wrong year)
year = [2013,2014,2015,2016,2017]
omdb_df = omdb_df[omdb_df.year.isin(year)]
omdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 479
# Data columns (total 9 columns):
# actors             469 non-null object
# director           469 non-null object
# imdb               469 non-null float64
# metacritic         469 non-null int64
# movie              469 non-null object
# rated              469 non-null object
# rotten_tomatoes    469 non-null int64
# runtime            469 non-null int64
# year               469 non-null int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 36.6+ KB

# %%
# Clean directors data
# Convert str to numeric
director_df.dir_agross = pd.to_numeric(director_df.dir_agross.replace("\$","", regex = True).str.strip())
director_df.dir_gross = pd.to_numeric(director_df.dir_gross.replace("\$","", regex = True)
                                      .replace(",","", regex = True).str.strip())
director_df.dir_nmovies = pd.to_numeric(director_df.dir_nmovies)
director_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# dir_agross     500 non-null float64
# dir_gross      500 non-null float64
# dir_nmovies    500 non-null int64
# director       500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
# Clean directors data
# Convert str to numeric
actor_df.act_agross = pd.to_numeric(actor_df.act_agross.replace("\$", "", regex = True)
                                    .replace(",", "", regex = True).str.strip())
actor_df.act_gross = pd.to_numeric(actor_df.act_gross.replace("\$", "", regex = True)
                                      .replace(",", "", regex = True).str.strip())
actor_df.act_nmovies = pd.to_numeric(actor_df.act_nmovies)
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# act_agross     500 non-null float64
# act_gross      500 non-null float64
# act_nmovies    500 non-null int64
# actor          500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
actor_df.head()
# Out:
#    act_agross  act_gross  act_nmovies              actor
# 0        70.5     5149.1           73  Samuel L. Jackson
# 1       118.2     4963.8           42      Harrison Ford
# 2        96.0     4605.6           48          Tom Hanks
# 3        71.8     4522.2           63     Morgan Freeman
# 4       166.7     4333.5           26        Andy Serkis

# %%
# Split actor & director strings into lists
# for index in range(len(omdb_df)):
#     omdb_df.actors[index] = [x.strip() for x in omdb_df.actors[index].split(',')]
omdb_df.actors = omdb_df.actors.apply(lambda x :[x.strip() for x in x.split(',')])    
omdb_df.director = omdb_df.director.apply(lambda x :[x.strip() for x in x.split(',')])
omdb_df.head()
# Out:
#                                               actors  \
# 0  [Jennifer Lawrence, Liam Hemsworth, Jack Quaid...
# 1  [Robert Downey Jr., Gwyneth Paltrow, Don Chead...
# 2  [Kristen Bell, Idina Menzel, Jonathan Groff, J...
# 3  [Steve Carell, Kristen Wiig, Benjamin Bratt, M...
# 4  [Henry Cavill, Amy Adams, Michael Shannon, Dia...
#
#                         director  imdb  metacritic  \
# 0             [Francis Lawrence]   7.5          76
# 1                  [Shane Black]   7.2          62
# 2     [Chris Buck, Jennifer Lee]   7.5          74
# 3  [Pierre Coffin, Chris Renaud]   7.4          62
# 4                  [Zack Snyder]   7.1          55
#
#                              movie  rated  rotten_tomatoes  runtime  year
# 0  The Hunger Games: Catching Fire  PG-13               89      146  2013
# 1                       Iron Man 3  PG-13               80      130  2013
# 2                           Frozen     PG               90      102  2013
# 3                  Despicable Me 2     PG               74       98  2013
# 4                     Man of Steel  PG-13               55      143  2013

# %%
actor_df.sort_values(by="act_gross",ascending=False).head(5)
# Out:
#    act_agross  act_gross  act_nmovies              actor
# 0        70.5     5149.1           73  Samuel L. Jackson
# 1       118.2     4963.8           42      Harrison Ford
# 2        96.0     4605.6           48          Tom Hanks
# 3        71.8     4522.2           63     Morgan Freeman
# 4       166.7     4333.5           26        Andy Serkis

# %% [markdown]
# # Merge the dataframes

# %%
# Merge mojo and youtube
merged = pd.DataFrame.merge(mojo_df, youtube_df,on='movie_name', how = 'inner')
merged = merged.drop(["release_date"],1)
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 10 columns):
# movie_name    500 non-null object
# movie         500 non-null object
# opening       500 non-null int64
# date_time     500 non-null datetime64[ns]
# theaters      500 non-null int64
# tot_gross     500 non-null int64
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 43.0+ KB

# %%
# Merge omdb
merged2 = pd.DataFrame.merge(merged,omdb_df,on="movie",how="inner")

# %%
# First create a dataframe for year and corresponding movie ticket
year = [2013,2014,2015,2016,2017]
tick = [8.13,8.17,8.43,8.65,8.97]
adjuster = pd.DataFrame({"year":year,"tick":tick})
# Assign ticket price adjuster column to omdb through merge
merged2 = pd.merge(merged2,adjuster,on="year",how="inner")

# Create new column for merged
est_tick = (merged2.opening // merged2.tick).astype("int64")
merged2.insert(loc=3, column='est_tick', value=est_tick)
merged2 = merged2.rename(columns={"opening":"op_gross"})

# %%
merged2
# Out:
#                                       movie_name  \
# 0                The Hunger Games: Catching Fire
# 1                                     Iron Man 3
# 2                                         Frozen
# 3                                Despicable Me 2
# 4                                   Man of Steel
# 5                                        Gravity
# 6                            Monsters University
# 7            The Hobbit: The Desolation of Smaug
# 8                               Fast & Furious 6
# 9                      Oz The Great and Powerful
# 10                       Star Trek Into Darkness
# 11                          Thor: The Dark World
# 12                                   World War Z
# 13                                    The Croods
# 14                                      The Heat
# 15                             We're the Millers
# 16                               American Hustle
# 17                       The Great Gatsby (2013)
# 18                                 The Conjuring
# 19                                Identity Thief
# 20                                   Grown Ups 2
# 21                                 The Wolverine
# 22             Anchorman 2: The Legend Continues
# 23                                 Lone Survivor
# 24                         G.I. Joe: Retaliation
# 25           Cloudy with a Chance of Meatballs 2
# 26                                Now You See Me
# 27                       The Wolf of Wall Street
# 28                       Lee Daniels' The Butler
# 29                         The Hangover Part III
# ..                                           ...
# 439  Valerian and the City of a Thousand Planets
# 440                                     The Star
# 441                    Ghost in the Shell (2017)
# 442             King Arthur: Legend of the Sword
# 443                                       Jigsaw
# 444                            American Assassin
# 445                                The Foreigner
# 446                       Everything, Everything
# 447                                   Wind River
# 448                                     Geostorm
# 449                                   Fist Fight
# 450                      How to be a Latin Lover
# 451                                Kidnap (2017)
# 452                      The Mountain Between Us
# 453                                  Life (2017)
# 454                                     I, Tonya
# 455                                     Hostiles
# 456                                 Molly's Game
# 457               The Nut Job 2: Nutty by Nature
# 458                                        Rings
# 459                                  Logan Lucky
# 460                                   Home Again
# 461                                    The House
# 462                   All the Money in the World
# 463                                       Gifted
# 464                                   Downsizing
# 465                              The Bye Bye Man
# 466                                  Rough Night
# 467                    My Little Pony: The Movie
# 468                          The Disaster Artist
#
#                                            movie   op_gross  est_tick  \
# 0                The Hunger Games: Catching Fire  158074286  19443331
# 1                                     Iron Man 3  174144585  21419998
# 2                                         Frozen     243390     29937
# 3                                Despicable Me 2   83517315  10272732
# 4                                   Man of Steel  116619362  14344324
# 5                                        Gravity   55785112   6861637
# 6                            Monsters University   82429469  10138926
# 7            The Hobbit: The Desolation of Smaug   73645197   9058449
# 8                               Fast & Furious 6   97375245  11977274
# 454  [Margot Robbie, Sebastian Stan, Allison Janney...
# 455  [Scott Shepherd, Rosamund Pike, Ava Cooper, St...
# 456  [Jessica Chastain, Idris Elba, Kevin Costner, ...
# 457  [Will Arnett, Maya Rudolph, Bobby Cannavale, B...
# 458  [Matilda Anna Ingrid Lutz, Alex Roe, Johnny Ga...
# 459  [Farrah Mackenzie, Channing Tatum, Jim O'Heir,...
# 460  [Reese Witherspoon, Michael Sheen, Candice Ber...
# 461  [Will Ferrell, Amy Poehler, Jason Mantzoukas, ...
# 462  [Michelle Williams, Christopher Plummer, Mark ...
# 463  [Chris Evans, Mckenna Grace, Lindsay Duncan, O...
# 464  [Matt Damon, Christoph Waltz, Hong Chau, Krist...
# 465  [Douglas Smith, Lucien Laviscount, Cressida Bo...
# 466  [Scarlett Johansson, Jillian Bell, Zoë Kravitz...
# 467  [Uzo Aduba, Ashleigh Ball, Adam Bengis, Emily ...
# 468  [Dave Franco, James Franco, Seth Rogen, Ari Gr...
#
#                              director  imdb  metacritic  rated  \
# 0                  [Francis Lawrence]   7.5          76  PG-13
# 1                       [Shane Black]   7.2          62  PG-13
# 2          [Chris Buck, Jennifer Lee]   7.5          74     PG
# 3       [Pierre Coffin, Chris Renaud]   7.4          62     PG
# 4                       [Zack Snyder]   7.1          55  PG-13
# 5                    [Alfonso Cuarón]   7.8          96  PG-13
# 6                       [Dan Scanlon]   7.3          65      G
# 7                     [Peter Jackson]   7.9          66  PG-13
# 8                        [Justin Lin]   7.1          61  PG-13
# 9                         [Sam Raimi]   6.3          44     PG
# 10                      [J.J. Abrams]   7.8          72  PG-13
# 11                      [Alan Taylor]   7.0          54  PG-13
# 12                     [Marc Forster]   7.0          63  PG-13
# 13     [Kirk De Micco, Chris Sanders]   7.2          55     PG
# 14                        [Paul Feig]   6.6          60      R
# 15          [Rawson Marshall Thurber]   7.0          44      R
# 16                 [David O. Russell]   7.3          90      R
# 17                     [Baz Luhrmann]   7.3          55  PG-13
# 18                        [James Wan]   7.5          68      R
# 19                      [Seth Gordon]   5.7          35      R
# 20                     [Dennis Dugan]   5.4          19  PG-13
# 21                    [James Mangold]   6.7          60  PG-13
# 22                       [Adam McKay]   6.3          61  PG-13
# 23                       [Peter Berg]   7.5          60      R
# 24                       [Jon M. Chu]   5.8          41  PG-13
# 25         [Cody Cameron, Kris Pearn]   6.4          59     PG
# 26                  [Louis Leterrier]   7.3          50  PG-13
# 27                  [Martin Scorsese]   8.2          75      R
# 28                      [Lee Daniels]   7.2          66  PG-13
# 29                    [Todd Phillips]   5.9          30      R
# ..                                ...   ...         ...    ...
# 439                      [Luc Besson]   6.5          51  PG-13
# 440                 [Timothy Reckart]   5.8          42     PG
# 441                  [Rupert Sanders]   6.4          52  PG-13
# 442                     [Guy Ritchie]   6.8          41  PG-13
# 443  [Michael Spierig, Peter Spierig]   5.8          39      R
# 444                  [Michael Cuesta]   6.2          45      R
# 445                 [Martin Campbell]   7.0          55      R
# 446                   [Stella Meghie]   6.4          52  PG-13
