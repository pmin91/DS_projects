# %% [markdown]
# # Luther - Data Cleaning and Merging Dataframes

# %% [markdown]
# This is part 2 of the Luther Project. In part 1, I've created 6 different dataframes that will be merged and cleaned in this notebook. The final merged dataframe "merged2.pkl" will be used in the last notebook "03 - Luther - Linear Regression" to develop a final linear regression model for predicting movie ticket sales on opening week (as well as opening gross adjusted to ticket price).

# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import seaborn as sns
import datetime

# %%
# Import all the dataframes
mojog_df = pd.read_pickle('mojog_df.pkl')
unemp_df = pd.read_pickle("unemp_df.pkl")
youtube_df = pd.read_pickle('youtube_df.pkl')
omdb_df = pd.read_pickle('omdb_df.pkl')
director_df = pd.read_pickle('director_df.pkl')
actor_df = pd.read_pickle('actor_df.pkl')

# %%
#clean mojo df
mojog_df.opening = mojog_df.opening.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojog_df.opening = pd.to_numeric(mojog_df.opening)
mojog_df.tot_gross = mojog_df.tot_gross.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojog_df.tot_gross = pd.to_numeric(mojog_df.tot_gross)
mojog_df.theaters = mojog_df.theaters.replace(",","", regex = True).str.strip()
mojog_df.theaters = pd.to_numeric(mojog_df.theaters)
mojog_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 9 columns):
# movie_name    500 non-null object
# movie         500 non-null object
# opening       500 non-null int64
# date_time     500 non-null datetime64[ns]
# theaters      500 non-null int64
# tot_gross     500 non-null int64
# actors        458 non-null object
# directors     460 non-null object
# gtrend        500 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 39.1+ KB

# %%
# Clean youtube df 
# select youtube df relevant data
youtube_df = youtube_df[["movie_name", "viewCount", "commentCount", "dislikeCount", "likeCount"]]

#replace nulls with 0
youtube_df = youtube_df.fillna(0)
# convert numeric str values to int
youtube_df.viewCount = pd.to_numeric(youtube_df.viewCount)
youtube_df.dislikeCount = pd.to_numeric(youtube_df.dislikeCount)
youtube_df.commentCount = pd.to_numeric(youtube_df.commentCount)
youtube_df.likeCount = pd.to_numeric(youtube_df.likeCount)
youtube_df = youtube_df.rename(columns ={"viewCount":"Yviews", "commentCount": "Ycomments", 
                                         "dislikeCount": "Ydislikes", "likeCount":"Ylikes"})
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# movie_name    500 non-null object
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 19.6+ KB

# %%
# Clean omdb data
omdb_df.imdb = pd.to_numeric(omdb_df.imdb.replace("/10","", regex = True).str.strip())
omdb_df.metacritic = pd.to_numeric(omdb_df.metacritic.replace("/100","", regex = True).str.strip())
omdb_df.rotten_tomatoes = pd.to_numeric(omdb_df.rotten_tomatoes.replace("%","", regex = True).str.strip())
omdb_df.runtime = pd.to_numeric(omdb_df.runtime.replace("min","", regex = True).str.strip())
omdb_df.year = pd.to_numeric(omdb_df.year)
# Remove 11 movies that have been wrongly identified on omdb (wrong year)
year = [2013,2014,2015,2016,2017]
omdb_df = omdb_df[omdb_df.year.isin(year)]
omdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 479
# Data columns (total 7 columns):
# imdb               469 non-null float64
# metacritic         469 non-null int64
# movie              469 non-null object
# rated              469 non-null object
# rotten_tomatoes    469 non-null int64
# runtime            469 non-null int64
# year               469 non-null int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 29.3+ KB

# %%
# Clean directors data
# Convert str to numeric
director_df.dir_agross = pd.to_numeric(director_df.dir_agross.replace("\$","", regex = True).str.strip())
director_df.dir_gross = pd.to_numeric(director_df.dir_gross.replace("\$","", regex = True)
                                      .replace(",","", regex = True).str.strip())
director_df.dir_nmovies = pd.to_numeric(director_df.dir_nmovies)
director_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# dir_agross     500 non-null float64
# dir_gross      500 non-null float64
# dir_nmovies    500 non-null int64
# director       500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
# Clean directors data
# Convert str to numeric
actor_df.act_agross = pd.to_numeric(actor_df.act_agross.replace("\$", "", regex = True)
                                    .replace(",", "", regex = True).str.strip())
actor_df.act_gross = pd.to_numeric(actor_df.act_gross.replace("\$", "", regex = True)
                                      .replace(",", "", regex = True).str.strip())
actor_df.act_nmovies = pd.to_numeric(actor_df.act_nmovies)
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# act_agross     500 non-null float64
# act_gross      500 non-null float64
# act_nmovies    500 non-null int64
# actor          500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
actor_df.head()
# Out:
#    act_agross  act_gross  act_nmovies              actor
# 0        70.5     5149.1           73  Samuel L. Jackson
# 1       118.2     4963.8           42      Harrison Ford
# 2        96.0     4605.6           48          Tom Hanks
# 3        71.8     4522.2           63     Morgan Freeman
# 4       166.7     4333.5           26        Andy Serkis

# %%
# # Split actor & director strings into lists
# # for index in range(len(omdb_df)):
# #     omdb_df.actors[index] = [x.strip() for x in omdb_df.actors[index].split(',')]
# omdb_df.actors = omdb_df.actors.apply(lambda x :[x.strip() for x in x.split(',')])    
# omdb_df.director = omdb_df.director.apply(lambda x :[x.strip() for x in x.split(',')])
# omdb_df.head()

# %%
mojog_df
# Out:
#                               movie_name                                movie  \
# 0        The Hunger Games: Catching Fire      The Hunger Games: Catching Fire
# 1                             Iron Man 3                           Iron Man 3
# 2                                 Frozen                               Frozen
# 3                        Despicable Me 2                      Despicable Me 2
# 4                           Man of Steel                         Man of Steel
# 5                                Gravity                              Gravity
# 6                    Monsters University                  Monsters University
# 7    The Hobbit: The Desolation of Smaug  The Hobbit: The Desolation of Smaug
# 8                       Fast & Furious 6                     Fast & Furious 6
# 9              Oz The Great and Powerful            Oz The Great and Powerful
# 10               Star Trek Into Darkness              Star Trek Into Darkness
# 11                  Thor: The Dark World                 Thor: The Dark World
# 12                           World War Z                          World War Z
# 13                            The Croods                           The Croods
# 14                              The Heat                             The Heat
# 15                     We're the Millers                    We're the Millers
# 16                       American Hustle                      American Hustle
# 17               The Great Gatsby (2013)                     The Great Gatsby
# 18                         The Conjuring                        The Conjuring
# 19                        Identity Thief                       Identity Thief
# 20                           Grown Ups 2                          Grown Ups 2
# 21                         The Wolverine                        The Wolverine
# 22     Anchorman 2: The Legend Continues    Anchorman 2: The Legend Continues
# 23                         Lone Survivor                        Lone Survivor
# 24                 G.I. Joe: Retaliation                G.I. Joe: Retaliation
# 25   Cloudy with a Chance of Meatballs 2  Cloudy with a Chance of Meatballs 2
# 26                        Now You See Me                       Now You See Me
# 27               The Wolf of Wall Street              The Wolf of Wall Street
# 28               Lee Daniels' The Butler              Lee Daniels' The Butler
# 29                 The Hangover Part III                The Hangover Part III
# 477  [Eugenio Derbez, Salma Hayek, Rob Lowe, Kriste...
# 478                                                NaN
# 479                      [Kate Beckinsale, Theo James]
# 480                         [Idris Elba, Kate Winslet]
# 481  [Rebecca Ferguson, Jake Gyllenhaal, Ryan Reyno...
# 482    [Margot Robbie, Allison Janney, Sebastian Stan]
# 483        [Christian Bale, Rosamund Pike, Ben Foster]
# 484  [Jessica Chastain, Idris Elba, Kevin Costner, ...
# 485                     [Katherine Heigl, Jackie Chan]
# 486                                                NaN
# 487  [Daniel Craig, Channing Tatum, Katherine Water...
# 488      [Reese Witherspoon, Michael Sheen, Lake Bell]
# 489                                                NaN
# 490                                     [Will Ferrell]
# 491  [Michelle Williams, Christopher Plummer, Mark ...
# 492                     [Chris Evans, Octavia Spencer]
# 493  [Matt Damon, Kristen Wiig, Neil Patrick Harris...
# 494                 [Carrie-Anne Moss, Leigh Whannell]
# 495                                       [Judi Dench]
# 496                               [Scarlett Johansson]
# 497                                      [Emily Blunt]
# 498                                     [Elle Fanning]
# 499  [James Franco, Seth Rogen, Dave Franco, Josh H...
#
#                           directors  gtrend
# 0                [Francis Lawrence]   0.456
# 1                     [Shane Black]   0.792
# 2        [Chris Buck, Jennifer Lee]   0.124
# 3     [Pierre Coffin, Chris Renaud]   0.706
# 4                     [Zack Snyder]   0.713
# 5                  [Alfonso Cuaron]   0.221
# 6                     [Dan Scanlon]   0.559
# 7                   [Peter Jackson]   0.500
# 8                      [Justin Lin]   0.665
# 9                       [Sam Raimi]   0.628
# 10                    [J.J. Abrams]   0.736
# 11                    [Alan Taylor]   0.474
# 12                   [Marc Forster]   0.552
# 13   [Kirk De Micco, Chris Sanders]   0.330
# 14                      [Paul Feig]   0.246
# 15        [Rawson Marshall Thurber]   0.447
# 16               [David O. Russell]   0.152
# 17                   [Baz Luhrmann]   0.549
# 18                      [James Wan]   0.249
# 19                    [Seth Gordon]   0.255
# 20                   [Dennis Dugan]   0.583
# 21                  [James Mangold]   0.518
# 22                     [Adam McKay]   0.234
# 23                     [Peter Berg]   0.191
# 24                        [Jon Chu]   0.444
# 25                              NaN   0.331
# 26                [Louis Leterrier]   0.095
# 27                [Martin Scorsese]   0.212
# 28                    [Lee Daniels]   0.202
# 29                  [Todd Phillips]   0.605
# ..                              ...     ...
# 470                [Michael Cuesta]   0.311
# 471               [Martin Campbell]   0.343
# 472                             NaN   0.292
# 473                              []   0.075
# 474                   [Dean Devlin]   0.330
# 475                   [Chris Wedge]   0.351
# 476                              []   0.255
# 477                              []   0.234
# 478                             NaN   0.460
# 479                              []   0.606
# 480                             NaN   0.225
# 481               [Daniel Espinosa]   0.354
# 482               [Craig Gillespie]   0.189
# 483                  [Scott Cooper]   0.177
# 484                  [Aaron Sorkin]   0.274
# 485                   [Cal Brunker]   0.122
# 486                              []   0.366
# 487             [Steven Soderbergh]   0.238
# 488                             NaN   0.248
# 489            [Paul W.S. Anderson]   0.536
# 490               [Andrew J. Cohen]   0.356
# 491                  [Ridley Scott]   0.397
# 492                     [Marc Webb]   0.120
# 493               [Alexander Payne]   0.439
# 494                              []   0.271
# 495                [Stephen Frears]   0.362
# 496                             NaN   0.428
# 497                              []   0.580
# 498                             NaN   1.000
# 499                  [James Franco]   0.373
#
# [500 rows x 9 columns]

# %%
# Create a new column unemp_date, by dropping the datetime day to 1
# This is done in order to merge the unemployment monthly data to the movies release dates
#datetime.date(2008,1,1).replace(day=5)
mojog_df["unemp_date"] = mojog_df.date_time.apply(lambda x: x.replace(day=1))
mojog_df = pd.merge(mojog_df,unemp_df,on="unemp_date",how="inner")
mojog_df = mojog_df.drop(["unemp_date"],1)
mojog_df.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                           Frozen                           Frozen
# 2             Thor: The Dark World             Thor: The Dark World
# 3             The Best Man Holiday             The Best Man Holiday
# 4                       Last Vegas                       Last Vegas
#
#      opening  date_time  theaters  tot_gross  \
# 0  158074286 2013-11-22      4163  424668047
# 1     243390 2013-11-22         1  400738009
# 2   85737841 2013-11-08      3841  206362140
# 3   30107555 2013-11-15      2024   70525195
# 4   16334566 2013-11-01      3065   63914167
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1               [Kristen Bell, Josh Gad, Alan Tudyk]
# 2  [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# 3  [Morris Chestnut, Regina Hall, Terrence Howard...
# 4  [Michael Douglas, Robert DeNiro, Morgan Freema...
#
#                     directors  gtrend  unemp_rate
# 0          [Francis Lawrence]   0.456         6.9
# 1  [Chris Buck, Jennifer Lee]   0.124         6.9
# 2               [Alan Taylor]   0.474         6.9
# 3            [Malcolm D. Lee]   0.220         6.9
# 4            [Jon Turteltaub]   0.187         6.9

# %% [markdown]
# # Merge the dataframes

# %%
# Merge mojo and youtube
merged = pd.DataFrame.merge(mojog_df, youtube_df,on='movie_name', how = 'inner')
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 14 columns):
# movie_name    500 non-null object
# movie         500 non-null object
# opening       500 non-null int64
# date_time     500 non-null datetime64[ns]
# theaters      500 non-null int64
# tot_gross     500 non-null int64
# actors        458 non-null object
# directors     460 non-null object
# gtrend        500 non-null float64
# unemp_rate    500 non-null float64
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(7), object(4)
# memory usage: 58.6+ KB

# %%
# Merge omdb
merged2 = pd.DataFrame.merge(merged,omdb_df,on="movie",how="inner")
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                           Frozen                           Frozen
# 2             Thor: The Dark World             Thor: The Dark World
# 3             The Best Man Holiday             The Best Man Holiday
# 4                       Last Vegas                       Last Vegas
#
#      opening  date_time  theaters  tot_gross  \
# 0  158074286 2013-11-22      4163  424668047
# 1     243390 2013-11-22         1  400738009
# 2   85737841 2013-11-08      3841  206362140
# 3   30107555 2013-11-15      2024   70525195
# 4   16334566 2013-11-01      3065   63914167
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1               [Kristen Bell, Josh Gad, Alan Tudyk]
# 2  [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# 3  [Morris Chestnut, Regina Hall, Terrence Howard...
# 4  [Michael Douglas, Robert DeNiro, Morgan Freema...
#
#                     directors  gtrend  unemp_rate    Yviews  Ycomments  \
# 0          [Francis Lawrence]   0.456         6.9  12389287       9493
# 1  [Chris Buck, Jennifer Lee]   0.124         6.9  34267342       7458
# 2               [Alan Taylor]   0.474         6.9  17863773      11763
# 3            [Malcolm D. Lee]   0.220         6.9   2064143        781
# 4            [Jon Turteltaub]   0.187         6.9   2046856        252
#
#    Ydislikes  Ylikes  imdb  metacritic  rated  rotten_tomatoes  runtime  year
# 0       1385   52030   7.5          76  PG-13               89      146  2013
# 1       8664   54157   7.5          74     PG               90      102  2013
# 2       2486   65159   7.0          54  PG-13               66      112  2013
# 3        326    5425   6.7          59      R               70      123  2013
# 4        234    2747   6.6          48  PG-13               45      105  2013

# %%
# Adjust the youtube views based on google trends data
merged2["Yviews_adj"] = round(merged2.Yviews * merged2.gtrend)
merged2["Ylikes_adj"] = round(merged2.Ylikes * merged2.gtrend)
merged2["Ydis_adj"] = round(merged2.Ydislikes * merged2.gtrend)
merged2["Ycom_adj"] = round(merged2.Ycomments * merged2.gtrend)
#merged2["Yviews_adj2"] = round(merged2.Yviews * merged2.gtrend)
merged2 = merged2.drop(["gtrend","Yviews","Ycomments","Ylikes","Ydislikes"],1)
#merged2 = merged2.drop(["gtrend","gtrend2"],1)
merged2
# Out:
#                            movie_name                             movie  \
# 0     The Hunger Games: Catching Fire   The Hunger Games: Catching Fire
# 1                              Frozen                            Frozen
# 2                Thor: The Dark World              Thor: The Dark World
# 3                The Best Man Holiday              The Best Man Holiday
# 4                          Last Vegas                        Last Vegas
# 5                        Ender's Game                      Ender's Game
# 6                          Free Birds                        Free Birds
# 7                           Philomena                         Philomena
# 8                        Delivery Man                      Delivery Man
# 9                  Dallas Buyers Club                Dallas Buyers Club
# 10                         Iron Man 3                        Iron Man 3
# 11                   Fast & Furious 6                  Fast & Furious 6
# 12            Star Trek Into Darkness           Star Trek Into Darkness
# 13            The Great Gatsby (2013)                  The Great Gatsby
# 14                     Now You See Me                    Now You See Me
# 15              The Hangover Part III             The Hangover Part III
# 16                               Epic                              Epic
# 17                        After Earth                       After Earth
# 18                    Despicable Me 2                   Despicable Me 2
# 19                      The Conjuring                     The Conjuring
# 20                        Grown Ups 2                       Grown Ups 2
# 21                      The Wolverine                     The Wolverine
# 22                        Pacific Rim                       Pacific Rim
# 23                    The Lone Ranger                   The Lone Ranger
# 24                              Turbo                             Turbo
# 25                       The Smurfs 2                      The Smurfs 2
# 26                              Red 2                             Red 2
# 27                           R.I.P.D.                          R.I.P.D.
# 28                       Blue Jasmine                      Blue Jasmine
# 29         Kevin Hart: Let Me Explain        Kevin Hart: Let Me Explain
# ..                                ...                               ...
# 439             Going in Style (2017)                    Going in Style
# 440           How to be a Latin Lover           How to be a Latin Lover
# 441                            Gifted                            Gifted
# 442                           Get Out                           Get Out
# 443             The LEGO Batman Movie             The LEGO Batman Movie
# 444               Fifty Shades Darker               Fifty Shades Darker
# 445                    The Great Wall                    The Great Wall
# 446                        Fist Fight                        Fist Fight
# 447                             Rings                             Rings
# 448                             Split                             Split
# 449                   A Dog's Purpose                   A Dog's Purpose
# 457                   [Jeremy Renner, Elizabeth Olsen]
# 458                                                NaN
# 459                     [Katherine Heigl, Jackie Chan]
# 460  [Daniel Craig, Channing Tatum, Katherine Water...
# 461                                     [Elle Fanning]
# 462  [Ryan Gosling, Harrison Ford, Robin Wright, Ja...
# 463                                                NaN
# 464                                                NaN
# 465                      [Jackie Chan, Pierce Brosnan]
# 466                                                NaN
# 467                         [Idris Elba, Kate Winslet]
# 468                                      [Emily Blunt]
#
#                          directors  unemp_rate  imdb  metacritic  rated  \
# 0               [Francis Lawrence]         6.9   7.5          76  PG-13
# 1       [Chris Buck, Jennifer Lee]         6.9   7.5          74     PG
# 2                    [Alan Taylor]         6.9   7.0          54  PG-13
# 3                 [Malcolm D. Lee]         6.9   6.7          59      R
# 4                 [Jon Turteltaub]         6.9   6.6          48  PG-13
# 5                               []         6.9   6.7          51  PG-13
# 6                  [Jimmy Hayward]         6.9   5.9          38     PG
# 7                 [Stephen Frears]         6.9   7.6          77  PG-13
# 8                      [Ken Scott]         6.9   6.4          44  PG-13
# 9               [Jean-Marc Vallee]         6.9   8.0          84      R
# 10                   [Shane Black]         7.5   7.2          62  PG-13
# 11                    [Justin Lin]         7.5   7.1          61  PG-13
# 12                   [J.J. Abrams]         7.5   7.8          72  PG-13
# 13                  [Baz Luhrmann]         7.5   7.3          55  PG-13
# 14               [Louis Leterrier]         7.5   7.3          50  PG-13
# 15                 [Todd Phillips]         7.5   5.9          30      R
# 16                   [Chris Wedge]         7.5   6.7          52     PG
# 17            [M. Night Shyamalan]         7.5   4.9          33  PG-13
# 18   [Pierre Coffin, Chris Renaud]         7.3   7.4          62     PG
# 19                     [James Wan]         7.3   7.5          68      R
# 20                  [Dennis Dugan]         7.3   5.4          19  PG-13
# 21                 [James Mangold]         7.3   6.7          60  PG-13
# 22            [Guillermo del Toro]         7.3   6.9          64  PG-13
# 23                [Gore Verbinski]         7.3   6.5          37  PG-13
# 24                   [David Soren]         7.3   6.5          58     PG
# 25                  [Raja Gosnell]         7.3   5.4          34     PG
# 26                  [Dean Parisot]         7.3   6.7          47  PG-13
# 27              [Robert Schwentke]         7.3   5.6          25  PG-13
# 28                   [Woody Allen]         7.3   7.3          78  PG-13
# 29                             NaN         7.3   6.8          53      R
# ..                             ...         ...   ...         ...    ...
# 439                   [Zach Braff]         4.4   6.6          50  PG-13
# 440                             []         4.4   5.9          54  PG-13
# 441                    [Marc Webb]         4.4   7.6          60  PG-13
# 442                 [Jordan Peele]         4.7   7.7          84      R
# 443                            NaN         4.7   7.3          75     PG
# 444                  [James Foley]         4.7   4.6          33      R
# 445                  [Zhang Yimou]         4.7   6.0          42  PG-13
# 446                             []         4.7   5.6          37      R
# 447                             []         4.7   4.5          25  PG-13
# 448           [M. Night Shyamalan]         4.8   7.3          62  PG-13
# 449              [Lasse Hallstrom]         4.8   6.9          43     PG
# 450                  [Chris Wedge]         4.8   5.7          41     PG
# 451                             []         4.8   5.8          23      R
# 452           [Paul W.S. Anderson]         4.8   5.6          49      R
# 453                             []         4.8   4.3          37  PG-13
# 454            [David F. Sandberg]         4.4   6.6          62      R
# 454               70      109  2017   4929588.0     18629.0    1227.0
# 455               40      118  2017   2512450.0     18417.0     403.0
# 456               16       95  2017  12446314.0     59930.0    7849.0
# 457               87      107  2017    233817.0       428.0      31.0
# 458               37       95  2017   3480955.0     11187.0     624.0
# 459               13       91  2017    363031.0      1512.0     121.0
# 460               93      118  2017   2424323.0      6347.0     859.0
# 461               37       89  2016   1562299.0      7963.0     530.0
# 462               87      164  2017  11060894.0     63399.0    3861.0
# 463               71       96  2017   3483434.0     27664.0    1008.0
# 464               34       92  2017   7478913.0     34961.0    2384.0
# 465               62      113  2017   3203373.0     26755.0     490.0
# 466               13      109  2017   4152258.0     11681.0    1786.0
# 467               40      112  2017   2434995.0      2914.0     211.0
# 468               47       99  2017   2634835.0     19789.0    1739.0
#
#      Ycom_adj
# 0      4329.0
# 1       925.0
# 2      5576.0
# 3       172.0
# 4        47.0
# 5      1414.0
# 6       130.0
# 7        10.0
# 8       215.0
# 9        40.0
# 10     1301.0
# 11    11332.0
# 12     4074.0
# 13      626.0
# 14      133.0
# 15     4138.0
# 16      166.0
# 17     4812.0
# 18     1515.0
# 19      903.0
# 20     1276.0
# 21      360.0
# 22    10755.0
# 23     2830.0
# 24      164.0
# 25      176.0
# 26      188.0
# 27     2890.0
# 28       13.0
# 29      485.0
# ..        ...
# 439      69.0
# 440      70.0
# 441     562.0
# 442    2021.0
# 443     374.0
# 444    3662.0
# 445    3116.0
# 446     191.0
# 447     201.0
# 448    5326.0
# 449       0.0
# 450    1012.0
# 451     904.0
# 452    2175.0
# 453     775.0
# 454    2347.0
# 455    1028.0
# 456    9641.0
# 457      67.0
# 458    1855.0
# 459     129.0
# 460     536.0
# 461    1054.0
# 462    7911.0
# 463    3586.0
# 464    5238.0
# 465    2927.0
# 466    1804.0
# 467     316.0
# 468    4688.0
#
# [469 rows x 19 columns]

# %%
# First create a dataframe for year and corresponding movie ticket
year = [2013,2014,2015,2016,2017]
tick = [8.13,8.17,8.43,8.65,8.97]
adjuster = pd.DataFrame({"year":year,"tick":tick})
# Assign ticket price adjuster column to omdb through merge
merged2 = pd.merge(merged2,adjuster,on="year",how="inner")

# Create new column for merged
est_tick = (merged2.opening // merged2.tick).astype("int64")
merged2.insert(loc=3, column='est_tick', value=est_tick)
merged2 = merged2.rename(columns={"opening":"op_gross"})

# %%
merged2 = merged2.fillna(0)

# %%
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                           Frozen                           Frozen
# 2             Thor: The Dark World             Thor: The Dark World
# 3             The Best Man Holiday             The Best Man Holiday
# 4                       Last Vegas                       Last Vegas
#
#     op_gross  est_tick  date_time  theaters  tot_gross  \
# 0  158074286  19443331 2013-11-22      4163  424668047
# 1     243390     29937 2013-11-22         1  400738009
# 2   85737841  10545859 2013-11-08      3841  206362140
# 3   30107555   3703266 2013-11-15      2024   70525195
# 4   16334566   2009171 2013-11-01      3065   63914167
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1               [Kristen Bell, Josh Gad, Alan Tudyk]
# 2  [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# 3  [Morris Chestnut, Regina Hall, Terrence Howard...
# 4  [Michael Douglas, Robert DeNiro, Morgan Freema...
#
#                     directors  unemp_rate  ...   metacritic  rated  \
# 0          [Francis Lawrence]         6.9  ...           76  PG-13
# 1  [Chris Buck, Jennifer Lee]         6.9  ...           74     PG
# 2               [Alan Taylor]         6.9  ...           54  PG-13
# 3            [Malcolm D. Lee]         6.9  ...           59      R
# 4            [Jon Turteltaub]         6.9  ...           48  PG-13
#
#   rotten_tomatoes  runtime  year  Yviews_adj  Ylikes_adj  Ydis_adj  Ycom_adj  \
# 0              89      146  2013   5649515.0     23726.0     632.0    4329.0
# 1              90      102  2013   4249150.0      6715.0    1074.0     925.0
# 2              66      112  2013   8467428.0     30885.0    1178.0    5576.0
# 3              70      123  2013    454111.0      1194.0      72.0     172.0
# 4              45      105  2013    382762.0       514.0      44.0      47.0
#
#    tick
# 0  8.13
# 1  8.13
# 2  8.13
# 3  8.13
# 4  8.13
#
# [5 rows x 21 columns]

# %% [markdown]
# # Generate a metric for actor and directors

# %%
# import numpy as np

# # Calculate the average # movies the actors featured in, as well as their average total gross

# act_list = []
# for i in range(len(merged2)):
#     #for each of the actors in a given movie, sum up their total gross & movies
#     act_gross = 0
#     act_nmovies = 0
#     if (merged2.actors[i] == 0) or (merged2.actors[i] == []):
#         pass
#     else:
#         actor_count = len(merged2.actors[i])
#         for actoriter in merged2.actors[i]:
#             if actor_df[actor_df.actor == actoriter].empty:
#                 actor_count -= 1
#             #Subtract the movie total gross (movie i want to predict) from actor total gross
#             else:
#                 act_gross += actor_df[actor_df.actor == actoriter].act_gross.iloc[0] - \
#                 merged2.tot_gross[i]/(1e6)
#                 act_nmovies += actor_df[actor_df.actor == actoriter].act_nmovies.iloc[0]
#     #take the sum and average over number of actors featured
#     if actor_count <= 0:
#         act_gross, act_nmovies = 0, 0
#     else:
#         act_gross = round((act_gross/actor_count),1)
#         act_nmovies = round((act_nmovies/actor_count),1)
#     act_dict = {'movie': merged2.movie[i], 'act_gross':act_gross, 
#                 'act_nmovies': act_nmovies}
#     act_list.append(act_dict)
# actor_metric = pd.DataFrame(act_list)

# %% [markdown]
# #### actors

# %%
import numpy as np

# Calculate the average # movies the actors featured in, as well as their average total gross

act_list = []
for i in range(len(merged2)):
    #for each of the actors in a given movie, sum up their total gross & movies
    gross_list = []
    nmovies_list = []
    if (merged2.actors[i] == 0) or (merged2.actors[i] == []):
        act_gross, act_nmovies = 0, 0
    else:
        actor_count = len(merged2.actors[i])
        for actoriter in merged2.actors[i]:
            if actor_df[actor_df.actor == actoriter].empty:
                actor_count -= 1
            #Subtract the movie total gross (movie i want to predict) from actor total gross
            else:
                gross_list.append(actor_df[actor_df.actor == actoriter].act_gross.iloc[0] - \
                merged2.tot_gross[i]/(1e6))
                nmovies_list.append(actor_df[actor_df.actor == actoriter].act_nmovies.iloc[0])
    #take the sum and average over number of actors featured
    if (actor_count <= 0) or (merged2.actors[i] == []) or (merged2.actors[i] == 0):
        act_gross, act_nmovies = 0, 0
    else:
        act_gross = round(max(gross_list),1)
        act_nmovies = round(max(nmovies_list),1)
    act_dict = {'movie': merged2.movie[i], 'act_gross':act_gross, 
                'act_nmovies': act_nmovies}
    act_list.append(act_dict)
actor_metric = pd.DataFrame(act_list)

# %%
#merged2.actors[0]

# %% [markdown]
# #### directors

# %%
import numpy as np

# Calculate the average # movies the actors featured in, as well as their average total gross

dir_list = []
for i in range(len(merged2)):
    #for each of the actors in a given movie, sum up their total gross & movies
    gross_list = []
    nmovies_list = []
    if (merged2.directors[i] == 0) or (merged2.directors[i] == []):
        dir_gross, dir_nmovies = 0, 0
    else:
        director_count = len(merged2.directors[i])
        for directoriter in merged2.directors[i]:
            if director_df[director_df.director == directoriter].empty:
                director_count -= 1
            #Subtract the movie total gross (movie i want to predict) from actor total gross
            else:
                gross_list.append(director_df[director_df.director == directoriter].
                                  dir_gross.iloc[0] - \
                merged2.tot_gross[i]/(1e6))
                nmovies_list.append(director_df[director_df.director == directoriter]
                                    .dir_nmovies.iloc[0])
    #take the sum and average over number of actors featured
    if (director_count <= 0) or (merged2.directors[i] == []) or (merged2.directors[i] == 0):
        dir_gross, dir_nmovies = 0, 0
    else:
        dir_gross = round(max(gross_list),1)
        dir_nmovies = round(max(nmovies_list),1)
    dir_dict = {'movie': merged2.movie[i], 'dir_gross':dir_gross, 
                'dir_nmovies': dir_nmovies}
    dir_list.append(dir_dict)
director_metric = pd.DataFrame(dir_list)

# %% [markdown]
# # Merge the director & actor metrics to df

# %%
merged2 = pd.merge(merged2, actor_metric, on="movie", how="inner")
merged2 = pd.merge(merged2, director_metric, on="movie", how="inner")
merged2 = merged2.drop(["actors","directors"],1)
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                           Frozen                           Frozen
# 2             Thor: The Dark World             Thor: The Dark World
# 3             The Best Man Holiday             The Best Man Holiday
# 4                       Last Vegas                       Last Vegas
#
#     op_gross  est_tick  date_time  theaters  tot_gross  unemp_rate  imdb  \
# 0  158074286  19443331 2013-11-22      4163  424668047         6.9   7.5
# 1     243390     29937 2013-11-22         1  400738009         6.9   7.5
# 2   85737841  10545859 2013-11-08      3841  206362140         6.9   7.0
# 3   30107555   3703266 2013-11-15      2024   70525195         6.9   6.7
# 4   16334566   2009171 2013-11-01      3065   63914167         6.9   6.6
#
#    metacritic     ...       year  Yviews_adj  Ylikes_adj  Ydis_adj  Ycom_adj  \
# 0          76     ...       2013   5649515.0     23726.0     632.0    4329.0
# 1          74     ...       2013   4249150.0      6715.0    1074.0     925.0
# 2          54     ...       2013   8467428.0     30885.0    1178.0    5576.0
# 3          59     ...       2013    454111.0      1194.0      72.0     172.0
# 4          48     ...       2013    382762.0       514.0      44.0      47.0
#
#    tick  act_gross  act_nmovies  dir_gross  dir_nmovies
# 0  8.13     3333.4           56     1056.5            7
# 1  8.13     1774.2           19      230.0            3
# 2  8.13     2968.6           57       89.7            2
# 3  8.13     1328.5           34      346.3            9
# 4  8.13     4458.3           81      843.5           10
#
# [5 rows x 23 columns]

# %%
merged2.to_pickle("merged2.pkl")

# %%
len(merged2[(merged2.dir_nmovies == 0)])# | (merged2.act_gross == 0)])
# Out:
# 118
