# %%
import pickle
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import seaborn as sns

# %%
# Import all the dataframes
mojog_df = pd.read_pickle('mojog_df.pkl')
#mojog_df1 = pd.read_pickle('mojog_df1.pkl')
youtube_df = pd.read_pickle('youtube_df.pkl')
omdb_df = pd.read_pickle('omdb_df.pkl')
director_df = pd.read_pickle('director_df.pkl')
actor_df = pd.read_pickle('actor_df.pkl')

# %%
#clean mojo df
mojog_df.opening = mojog_df.opening.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojog_df.opening = pd.to_numeric(mojog_df.opening)
mojog_df.tot_gross = mojog_df.tot_gross.replace("\$","", regex = True).replace(",","", regex = True).str.strip()
mojog_df.tot_gross = pd.to_numeric(mojog_df.tot_gross)
mojog_df.theaters = mojog_df.theaters.replace(",","", regex = True).str.strip()
mojog_df.theaters = pd.to_numeric(mojog_df.theaters)
mojog_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 9 columns):
# movie_name    500 non-null object
# movie         500 non-null object
# opening       500 non-null int64
# date_time     500 non-null datetime64[ns]
# theaters      500 non-null int64
# tot_gross     500 non-null int64
# actors        458 non-null object
# directors     460 non-null object
# gtrend        500 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 39.1+ KB

# %%
# Clean youtube df 
# select youtube df relevant data
youtube_df = youtube_df[["movie_name", "viewCount", "commentCount", "dislikeCount", "likeCount"]]

#replace nulls with 0
youtube_df = youtube_df.fillna(0)
# convert numeric str values to int
youtube_df.viewCount = pd.to_numeric(youtube_df.viewCount)
youtube_df.dislikeCount = pd.to_numeric(youtube_df.dislikeCount)
youtube_df.commentCount = pd.to_numeric(youtube_df.commentCount)
youtube_df.likeCount = pd.to_numeric(youtube_df.likeCount)
youtube_df = youtube_df.rename(columns ={"viewCount":"Yviews", "commentCount": "Ycomments", 
                                         "dislikeCount": "Ydislikes", "likeCount":"Ylikes"})
youtube_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# movie_name    500 non-null object
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 19.6+ KB

# %%
# Clean omdb data
omdb_df.imdb = pd.to_numeric(omdb_df.imdb.replace("/10","", regex = True).str.strip())
omdb_df.metacritic = pd.to_numeric(omdb_df.metacritic.replace("/100","", regex = True).str.strip())
omdb_df.rotten_tomatoes = pd.to_numeric(omdb_df.rotten_tomatoes.replace("%","", regex = True).str.strip())
omdb_df.runtime = pd.to_numeric(omdb_df.runtime.replace("min","", regex = True).str.strip())
omdb_df.year = pd.to_numeric(omdb_df.year)
# Remove 11 movies that have been wrongly identified on omdb (wrong year)
year = [2013,2014,2015,2016,2017]
omdb_df = omdb_df[omdb_df.year.isin(year)]
omdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 0 to 479
# Data columns (total 7 columns):
# imdb               469 non-null float64
# metacritic         469 non-null int64
# movie              469 non-null object
# rated              469 non-null object
# rotten_tomatoes    469 non-null int64
# runtime            469 non-null int64
# year               469 non-null int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 29.3+ KB

# %%
# Clean directors data
# Convert str to numeric
director_df.dir_agross = pd.to_numeric(director_df.dir_agross.replace("\$","", regex = True).str.strip())
director_df.dir_gross = pd.to_numeric(director_df.dir_gross.replace("\$","", regex = True)
                                      .replace(",","", regex = True).str.strip())
director_df.dir_nmovies = pd.to_numeric(director_df.dir_nmovies)
director_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# dir_agross     500 non-null float64
# dir_gross      500 non-null float64
# dir_nmovies    500 non-null int64
# director       500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
# Clean directors data
# Convert str to numeric
actor_df.act_agross = pd.to_numeric(actor_df.act_agross.replace("\$", "", regex = True)
                                    .replace(",", "", regex = True).str.strip())
actor_df.act_gross = pd.to_numeric(actor_df.act_gross.replace("\$", "", regex = True)
                                      .replace(",", "", regex = True).str.strip())
actor_df.act_nmovies = pd.to_numeric(actor_df.act_nmovies)
actor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# act_agross     500 non-null float64
# act_gross      500 non-null float64
# act_nmovies    500 non-null int64
# actor          500 non-null object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.7+ KB

# %%
actor_df.head()
# Out:
#    act_agross  act_gross  act_nmovies              actor
# 0        70.5     5149.1           73  Samuel L. Jackson
# 1       118.2     4963.8           42      Harrison Ford
# 2        96.0     4605.6           48          Tom Hanks
# 3        71.8     4522.2           63     Morgan Freeman
# 4       166.7     4333.5           26        Andy Serkis

# %%
# # Split actor & director strings into lists
# # for index in range(len(omdb_df)):
# #     omdb_df.actors[index] = [x.strip() for x in omdb_df.actors[index].split(',')]
# omdb_df.actors = omdb_df.actors.apply(lambda x :[x.strip() for x in x.split(',')])    
# omdb_df.director = omdb_df.director.apply(lambda x :[x.strip() for x in x.split(',')])
# omdb_df.head()

# %%
act_list
# Out:
# [{'act_gross': 56   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 56   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Hunger Games: Catching Fire'},
#  {'act_gross': 5   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 5   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Iron Man 3'},
#  {'act_gross': 339   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 339   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Frozen'},
#  {'act_gross': 29   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 29   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Despicable Me 2'},
#  {'act_gross': 316   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 316   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Man of Steel'},
#  {'act_gross': 64   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 64   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Gravity'},
#  {'act_gross': 245   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 245   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Monsters University'},
#  {'act_gross': 12   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 12   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Hobbit: The Desolation of Smaug'},
#  {'act_gross': 39   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 39   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Fast & Furious 6'},
#  {'act_gross': 79   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 79   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Oz The Great and Powerful'},
#  {'act_gross': 135   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 135   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Star Trek Into Darkness'},
#  {'act_gross': 74   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 74   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Thor: The Dark World'},
#  {'act_gross': 45    181.406667
#   Name: act_gross, dtype: float64, 'act_nmovies': 45    2.8
#   Name: act_nmovies, dtype: float64, 'movie': 'World War Z'},
#  {'act_gross': 69   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 69   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Croods'},
#  {'act_gross': 64   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 64   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Heat'},
#  {'act_gross': 179   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 179   NaN
#   Name: act_nmovies, dtype: float64, 'movie': "We're the Millers"},
#  {'act_gross': 83   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 83   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'American Hustle'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'The Great Gatsby'},
#  {'act_gross': 409   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 409   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Conjuring'},
#  {'act_gross': 120   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 120   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Identity Thief'},
#  {'act_gross': 48   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 48   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Grown Ups 2'},
#  {'act_gross': 47    192.057143
#   Name: act_gross, dtype: float64, 'act_nmovies': 47    1.928571
#   Name: act_nmovies, dtype: float64, 'movie': 'The Wolverine'},
#  {'act_gross': 78   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 78   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Anchorman 2: The Legend Continues'},
#  {'act_gross': 34   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 34   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Lone Survivor'},
#  {'act_gross': 16   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 16   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'G.I. Joe: Retaliation'},
#  {'act_gross': 213    168.5
#   Name: act_gross, dtype: float64, 'act_nmovies': 213    2.444444
#   Name: act_nmovies, dtype: float64, 'movie': 'Cloudy with a Chance of Meatballs 2'},
#  {'act_gross': 271   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 271   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Now You See Me'},
#  {'act_gross': 58   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 58   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Wolf of Wall Street'},
#  {'act_gross': 42    214.523077
#   Name: act_gross, dtype: float64, 'act_nmovies': 42    4.307692
#   Name: act_nmovies, dtype: float64, 'movie': "Lee Daniels' The Butler"},
#  {'act_gross': 30   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 30   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Hangover Part III'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'Epic'},
#  {'act_gross': 2    270.917647
#   Name: act_gross, dtype: float64, 'act_nmovies': 2    2.823529
#   Name: act_nmovies, dtype: float64, 'movie': 'Captain Phillips'},
#  {'act_gross': 26    250.791667
#   Name: act_gross, dtype: float64, 'act_nmovies': 26    2.583333
#   Name: act_nmovies, dtype: float64, 'movie': 'Pacific Rim'},
#  {'act_gross': 79   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 79   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'This is the End'},
#  {'act_gross': 227   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 227   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Olympus Has Fallen'},
#  {'act_gross': 261   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 261   NaN
#   Name: act_nmovies, dtype: float64, 'movie': '42'},
#  {'act_gross': 21   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 21   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Elysium'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'Planes'},
#  {'act_gross': 11   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 11   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Lone Ranger'},
#  {'act_gross': 8   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 8   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Oblivion'},
#  {'act_gross': 422   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 422   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Insidious Chapter 2'},
#  {'act_gross': 196   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 196   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Saving Mr. Banks'},
#  {'act_gross': 157   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 157   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Turbo'},
#  {'act_gross': 70   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 70   NaN
#   Name: act_nmovies, dtype: float64, 'movie': '2 Guns'},
#  {'act_gross': 108   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 108   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'White House Down'},
#  {'act_gross': 281    79.333333
#   Name: act_gross, dtype: float64, 'act_nmovies': 281    1.333333
#   Name: act_nmovies, dtype: float64, 'movie': 'Mama'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'Safe Haven'},
#  {'act_gross': 403   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 403   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Smurfs 2'},
#  {'act_gross': 481    72.044444
#   Name: act_gross, dtype: float64, 'act_nmovies': 481    1.666667
#   Name: act_nmovies, dtype: float64, 'movie': 'The Best Man Holiday'},
#  {'act_gross': 0.0,
#   'act_nmovies': 0.0,
#   'movie': 'Percy Jackson: Sea of Monsters'},
#  {'act_gross': 18   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 18   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'A Good Day to Die Hard'},
#  {'act_gross': 389    88.76
#   Name: act_gross, dtype: float64, 'act_nmovies': 389    1.4
#   Name: act_nmovies, dtype: float64, 'movie': 'Warm Bodies'},
#  {'act_gross': 389   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 389   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Jack the Giant Slayer'},
#  {'act_gross': 404    69.233333
#   Name: act_gross, dtype: float64, 'act_nmovies': 404    3.916667
#   Name: act_nmovies, dtype: float64, 'movie': 'The Purge'},
#  {'act_gross': 152   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 152   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Last Vegas'},
#  {'act_gross': 1   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 1   NaN
#   Name: act_nmovies, dtype: float64, 'movie': "Ender's Game"},
#  {'act_gross': 47   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 47   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Prisoners'},
#  {'act_gross': 20    320.5
#   Name: act_gross, dtype: float64, 'act_nmovies': 20    2.5
#   Name: act_nmovies, dtype: float64, 'movie': 'After Earth'},
#  {'act_gross': 37   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 37   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Secret Life of Walter Mitty'},
#  {'act_gross': 313   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 313   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Escape From Planet Earth'},
#  {'act_gross': 292    129.488889
#   Name: act_gross, dtype: float64, 'act_nmovies': 292    2.222222
#   Name: act_nmovies, dtype: float64, 'movie': '12 Years a Slave'},
#  {'act_gross': 31   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 31   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Free Birds'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'Evil Dead'},
#  {'act_gross': 18   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 18   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Red 2'},
#  {'act_gross': 117   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 117   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Call'},
#  {'act_gross': 396    48.2
#   Name: act_gross, dtype: float64, 'act_nmovies': 396    2.166667
#   Name: act_nmovies, dtype: float64, 'movie': 'Gangster Squad'},
#  {'act_gross': 149   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 149   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'The Internship'},
#  {'act_gross': 0.0, 'act_nmovies': 0.0, 'movie': 'Instructions Not Included'},
#  {'act_gross': 16   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 16   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Snitch'},
#  {'act_gross': 39    216.461538
#   Name: act_gross, dtype: float64, 'act_nmovies': 39    1.692308
#   Name: act_nmovies, dtype: float64, 'movie': 'Riddick'},
#  {'act_gross': 430    58.892308
#   Name: act_gross, dtype: float64, 'act_nmovies': 430    1.307692
#   Name: act_nmovies, dtype: float64, 'movie': 'A Haunted House'},
#  {'act_gross': 121    150.723077
#   Name: act_gross, dtype: float64, 'act_nmovies': 121    3.538462
#   Name: act_nmovies, dtype: float64, 'movie': '47 Ronin'},
#  {'act_gross': 97   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 97   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'August: Osage County'},
#  {'act_gross': 122   NaN
#   Name: act_gross, dtype: float64, 'act_nmovies': 122   NaN
#   Name: act_nmovies, dtype: float64, 'movie': 'Philomena'},
#  {'act_gross': 199    172.422222
#   Name: act_gross, dtype: float64, 'act_nmovies': 199    4.333333
#   Name: act_nmovies, dtype: float64, 'movie': 'The Family'}]

# %%
actor_df.sort_values(by="act_gross",ascending=False).head(5)
#actor_df[actor_df.actor == 'Samuel L. Jackson'].empty
# Out:
#    act_agross  act_gross  act_nmovies              actor
# 0        70.5     5149.1           73  Samuel L. Jackson
# 1       118.2     4963.8           42      Harrison Ford
# 2        96.0     4605.6           48          Tom Hanks
# 3        71.8     4522.2           63     Morgan Freeman
# 4       166.7     4333.5           26        Andy Serkis

# %% [markdown]
# # Merge the dataframes

# %%
# Merge mojo and youtube
merged = pd.DataFrame.merge(mojog_df, youtube_df,on='movie_name', how = 'inner')
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 13 columns):
# movie_name    500 non-null object
# movie         500 non-null object
# opening       500 non-null int64
# date_time     500 non-null datetime64[ns]
# theaters      500 non-null int64
# tot_gross     500 non-null int64
# actors        458 non-null object
# directors     460 non-null object
# gtrend        500 non-null float64
# Yviews        500 non-null int64
# Ycomments     500 non-null int64
# Ydislikes     500 non-null int64
# Ylikes        500 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(7), object(4)
# memory usage: 54.7+ KB

# %%
# Merge omdb
merged2 = pd.DataFrame.merge(merged,omdb_df,on="movie",how="inner")
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                       Iron Man 3                       Iron Man 3
# 2                           Frozen                           Frozen
# 3                  Despicable Me 2                  Despicable Me 2
# 4                     Man of Steel                     Man of Steel
#
#      opening  date_time  theaters  tot_gross  \
# 0  158074286 2013-11-22      4163  424668047
# 1  174144585 2013-05-03      4253  409013994
# 2     243390 2013-11-22         1  400738009
# 3   83517315 2013-07-03      3997  368061265
# 4  116619362 2013-06-14      4207  291045518
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1  [Robert Downey, Jr., Gwyneth Paltrow, Don Chea...
# 2               [Kristen Bell, Josh Gad, Alan Tudyk]
# 3  [Steve Carell, Kristen Wiig, Benjamin Bratt, R...
# 4  [Henry Cavill, Amy Adams, Michael Shannon, Kev...
#
#                        directors  gtrend    Yviews  Ycomments  Ydislikes  \
# 0             [Francis Lawrence]   0.479  12389287       9493       1385
# 1                  [Shane Black]   0.831   1274074       1643        259
# 2     [Chris Buck, Jennifer Lee]   0.122  34267342       7458       8664
# 3  [Pierre Coffin, Chris Renaud]   0.771   7725854       2146       1733
# 4                  [Zack Snyder]   0.755  42683390      66568       6511
#
#    Ylikes  imdb  metacritic  rated  rotten_tomatoes  runtime  year
# 0   52030   7.5          76  PG-13               89      146  2013
# 1    7201   7.2          62  PG-13               80      130  2013
# 2   54157   7.5          74     PG               90      102  2013
# 3   17764   7.4          62     PG               74       98  2013
# 4  155344   7.1          55  PG-13               55      143  2013

# %%
# Adjust the youtube views based on google trends data
merged2["Yviews_adj"] = round(merged2.Yviews * merged2.gtrend)
merged2["Ylikes_adj"] = round(merged2.Ylikes * merged2.gtrend)
merged2["Ydis_adj"] = round(merged2.Ydislikes * merged2.gtrend)
merged2["Ycom_adj"] = round(merged2.Ycomments * merged2.gtrend)
#merged2["Yviews_adj2"] = round(merged2.Yviews * merged2.gtrend)
merged2 = merged2.drop(["gtrend","Yviews","Ycomments","Ylikes","Ydislikes"],1)
#merged2 = merged2.drop(["gtrend","gtrend2"],1)
merged2
# Out:
#                               movie_name                                movie  \
# 0        The Hunger Games: Catching Fire      The Hunger Games: Catching Fire
# 1                             Iron Man 3                           Iron Man 3
# 2                                 Frozen                               Frozen
# 3                        Despicable Me 2                      Despicable Me 2
# 4                           Man of Steel                         Man of Steel
# 5                                Gravity                              Gravity
# 6                    Monsters University                  Monsters University
# 7    The Hobbit: The Desolation of Smaug  The Hobbit: The Desolation of Smaug
# 8                      [Justin Lin]   7.1          61  PG-13               69
# 9                       [Sam Raimi]   6.3          44     PG               59
# 10                    [J.J. Abrams]   7.8          72  PG-13               86
# 11                    [Alan Taylor]   7.0          54  PG-13               66
# 12                   [Marc Forster]   7.0          63  PG-13               66
# 13   [Kirk De Micco, Chris Sanders]   7.2          55     PG               72
# 14                      [Paul Feig]   6.6          60      R               65
# 15        [Rawson Marshall Thurber]   7.0          44      R               47
# 16               [David O. Russell]   7.3          90      R               93
# 17                   [Baz Luhrmann]   7.3          55  PG-13               49
# 18                      [James Wan]   7.5          68      R               86
# 19                    [Seth Gordon]   5.7          35      R               19
# 20                   [Dennis Dugan]   5.4          19  PG-13                7
# 21                  [James Mangold]   6.7          60  PG-13               69
# 22                     [Adam McKay]   6.3          61  PG-13               75
# 23                     [Peter Berg]   7.5          60      R               76
# 24                        [Jon Chu]   5.8          41  PG-13               28
# 25                              NaN   6.4          59     PG               71
# 26                [Louis Leterrier]   7.3          50  PG-13               50
# 27                [Martin Scorsese]   8.2          75      R               78
# 28                    [Lee Daniels]   7.2          66  PG-13               72
# 29                  [Todd Phillips]   5.9          30      R               21
# ..                              ...   ...         ...    ...              ...
# 439                              []   5.8          39      R               34
# 440                [Michael Cuesta]   6.2          45      R               34
# 441               [Martin Campbell]   7.0          55      R               62
# 442                             NaN   6.4          52  PG-13               46
# 443                              []   7.8          73      R               87
# 444                   [Dean Devlin]   5.4          21  PG-13               13
# 445                   [Chris Wedge]   5.7          41     PG               30
# 446                              []   5.6          37      R               26
# 447                              []   5.9          54  PG-13               38
# 448                             NaN   5.9          44      R               37
# 449                              []   5.8          23      R               20
# 450                             NaN   6.4          48  PG-13               40
# 451               [Daniel Espinosa]   6.6          54      R               67
# 452               [Craig Gillespie]   7.6          77      R               90
# 453                  [Scott Cooper]   7.3          65      R               73
# 454                  [Aaron Sorkin]   7.5          71      R               82
# 455                   [Cal Brunker]   5.3          36     PG               13
# 456                              []   4.5          25  PG-13                7
# 457             [Steven Soderbergh]   7.1          78  PG-13               93
# 458                             NaN   5.7          41  PG-13               32
# 459            [Paul W.S. Anderson]   5.6          49      R               36
# 460               [Andrew J. Cohen]   5.6          30      R               18
# 461                  [Ridley Scott]   7.0          72      R               78
# 462                     [Marc Webb]   7.6          60  PG-13               73
# 463               [Alexander Payne]   5.7          63      R               51
# 464                              []   4.3          37  PG-13               23
# 465                             NaN   5.2          51      R               45
# 466                              []   6.2          39     PG               47
# 467                             NaN   6.8          48     PG               37
# 468                  [James Franco]   7.6          76      R               91
#
#      runtime  year  Yviews_adj  Ylikes_adj  Ydis_adj  Ycom_adj
# 0        146  2013   5934468.0     24922.0     663.0    4547.0
# 1        130  2013   1058755.0      5984.0     215.0    1365.0
# 2        102  2013   4180616.0      6607.0    1057.0     910.0
# 3         98  2013   5956633.0     13696.0    1336.0    1655.0
# 4        143  2013  32225959.0    117285.0    4916.0   50259.0
# 467       89  2016   1562299.0      7963.0     530.0    1054.0
# 468      104  2017   2802592.0     25362.0     601.0    1922.0
#
# [469 rows x 18 columns]

# %%
# First create a dataframe for year and corresponding movie ticket
year = [2013,2014,2015,2016,2017]
tick = [8.13,8.17,8.43,8.65,8.97]
adjuster = pd.DataFrame({"year":year,"tick":tick})
# Assign ticket price adjuster column to omdb through merge
merged2 = pd.merge(merged2,adjuster,on="year",how="inner")

# Create new column for merged
est_tick = (merged2.opening // merged2.tick).astype("int64")
merged2.insert(loc=3, column='est_tick', value=est_tick)
merged2 = merged2.rename(columns={"opening":"op_gross"})

# %%
merged2 = merged2.fillna(0)

# %%
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                       Iron Man 3                       Iron Man 3
# 2                           Frozen                           Frozen
# 3                  Despicable Me 2                  Despicable Me 2
# 4                     Man of Steel                     Man of Steel
#
#     op_gross  est_tick  date_time  theaters  tot_gross  \
# 0  158074286  19443331 2013-11-22      4163  424668047
# 1  174144585  21419998 2013-05-03      4253  409013994
# 2     243390     29937 2013-11-22         1  400738009
# 3   83517315  10272732 2013-07-03      3997  368061265
# 4  116619362  14344324 2013-06-14      4207  291045518
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1  [Robert Downey, Jr., Gwyneth Paltrow, Don Chea...
# 2               [Kristen Bell, Josh Gad, Alan Tudyk]
# 3  [Steve Carell, Kristen Wiig, Benjamin Bratt, R...
# 4  [Henry Cavill, Amy Adams, Michael Shannon, Kev...
#
#                        directors  imdb  metacritic  rated  rotten_tomatoes  \
# 0             [Francis Lawrence]   7.5          76  PG-13               89
# 1                  [Shane Black]   7.2          62  PG-13               80
# 2     [Chris Buck, Jennifer Lee]   7.5          74     PG               90
# 3  [Pierre Coffin, Chris Renaud]   7.4          62     PG               74
# 4                  [Zack Snyder]   7.1          55  PG-13               55
#
#    runtime  year  Yviews_adj  Ylikes_adj  Ydis_adj  Ycom_adj  tick
# 0      146  2013   5934468.0     24922.0     663.0    4547.0  8.13
# 1      130  2013   1058755.0      5984.0     215.0    1365.0  8.13
# 2      102  2013   4180616.0      6607.0    1057.0     910.0  8.13
# 3       98  2013   5956633.0     13696.0    1336.0    1655.0  8.13
# 4      143  2013  32225959.0    117285.0    4916.0   50259.0  8.13

# %% [markdown]
# # Generate a metric for actor and directors

# %%
# import numpy as np

# # Calculate the average # movies the actors featured in, as well as their average total gross

# act_list = []
# for i in range(len(merged2)):
#     #for each of the actors in a given movie, sum up their total gross & movies
#     act_gross = 0
#     act_nmovies = 0
#     if (merged2.actors[i] == 0) or (merged2.actors[i] == []):
#         pass
#     else:
#         actor_count = len(merged2.actors[i])
#         for actoriter in merged2.actors[i]:
#             if actor_df[actor_df.actor == actoriter].empty:
#                 actor_count -= 1
#             #Subtract the movie total gross (movie i want to predict) from actor total gross
#             else:
#                 act_gross += actor_df[actor_df.actor == actoriter].act_gross.iloc[0] - \
#                 merged2.tot_gross[i]/(1e6)
#                 act_nmovies += actor_df[actor_df.actor == actoriter].act_nmovies.iloc[0]
#     #take the sum and average over number of actors featured
#     if actor_count <= 0:
#         act_gross, act_nmovies = 0, 0
#     else:
#         act_gross = round((act_gross/actor_count),1)
#         act_nmovies = round((act_nmovies/actor_count),1)
#     act_dict = {'movie': merged2.movie[i], 'act_gross':act_gross, 
#                 'act_nmovies': act_nmovies}
#     act_list.append(act_dict)
# actor_metric = pd.DataFrame(act_list)

# %%
import numpy as np

# Calculate the average # movies the actors featured in, as well as their average total gross

act_list = []
for i in range(len(merged2)):
    #for each of the actors in a given movie, sum up their total gross & movies
    gross_list = []
    nmovies_list = []
    if (merged2.actors[i] == 0) or (merged2.actors[i] == []):
        act_gross, act_nmovies = 0, 0
    else:
        actor_count = len(merged2.actors[i])
        for actoriter in merged2.actors[i]:
            if actor_df[actor_df.actor == actoriter].empty:
                actor_count -= 1
            #Subtract the movie total gross (movie i want to predict) from actor total gross
            else:
                gross_list.append(actor_df[actor_df.actor == actoriter].act_gross.iloc[0] - \
                merged2.tot_gross[i]/(1e6))
                nmovies_list.append(actor_df[actor_df.actor == actoriter].act_nmovies.iloc[0])
    #take the sum and average over number of actors featured
    if (actor_count <= 0) or (merged2.actors[i] == []) or (merged2.actors[i] == 0):
        act_gross, act_nmovies = 0, 0
    else:
        act_gross = round(max(gross_list),1)
        act_nmovies = round(max(nmovies_list),1)
    act_dict = {'movie': merged2.movie[i], 'act_gross':act_gross, 
                'act_nmovies': act_nmovies}
    act_list.append(act_dict)
actor_metric = pd.DataFrame(act_list)

# %%
actor_metric.head()
# Out:
#    act_gross  act_nmovies                            movie
# 0     3333.4           56  The Hunger Games: Catching Fire
# 1     2476.5           52                       Iron Man 3
# 2     1774.2           19                           Frozen
# 3     2619.7           32                  Despicable Me 2
# 4     2120.6           42                     Man of Steel

# %%
import numpy as np

# Calculate the average # movies the actors featured in, as well as their average total gross

dir_list = []
for i in range(len(merged2)):
    #for each of the actors in a given movie, sum up their total gross & movies
    gross_list = []
    nmovies_list = []
    if (merged2.directors[i] == 0) or (merged2.directors[i] == []):
        dir_gross, dir_nmovies = 0, 0
    else:
        director_count = len(merged2.directors[i])
        for directoriter in merged2.directors[i]:
            if director_df[director_df.director == directoriter].empty:
                director_count -= 1
            #Subtract the movie total gross (movie i want to predict) from actor total gross
            else:
                gross_list.append(director_df[director_df.director == directoriter].
                                  dir_gross.iloc[0] - \
                merged2.tot_gross[i]/(1e6))
                nmovies_list.append(director_df[director_df.director == directoriter]
                                    .dir_nmovies.iloc[0])
    #take the sum and average over number of actors featured
    if (director_count <= 0) or (merged2.directors[i] == []) or (merged2.directors[i] == 0):
        dir_gross, dir_nmovies = 0, 0
    else:
        dir_gross = round(max(gross_list),1)
        dir_nmovies = round(max(nmovies_list),1)
    dir_dict = {'movie': merged2.movie[i], 'dir_gross':dir_gross, 
                'dir_nmovies': dir_nmovies}
    dir_list.append(dir_dict)
director_metric = pd.DataFrame(dir_list)

# %%
#merged2[merged2.movie == "Gravity"]
#director_df[director_df.director == "Alfonso Cuaron"]
len(merged2[merged2.directors == 0])
len(merged2[merged2.actors == 0])

#There are 38 ~ 39 movies with no directors/actors
# Out:
# 38

# %% [markdown]
# # Merge the director & actor metrics to df

# %%
merged2 = pd.merge(merged2, actor_metric, on="movie", how="inner")
merged2 = pd.merge(merged2, director_metric, on="movie", how="inner")
merged2.drop(["actors","directors"],1)
merged2.head()
# Out:
#                         movie_name                            movie  \
# 0  The Hunger Games: Catching Fire  The Hunger Games: Catching Fire
# 1                       Iron Man 3                       Iron Man 3
# 2                           Frozen                           Frozen
# 3                  Despicable Me 2                  Despicable Me 2
# 4                     Man of Steel                     Man of Steel
#
#     op_gross  est_tick  date_time  theaters  tot_gross  \
# 0  158074286  19443331 2013-11-22      4163  424668047
# 1  174144585  21419998 2013-05-03      4253  409013994
# 2     243390     29937 2013-11-22         1  400738009
# 3   83517315  10272732 2013-07-03      3997  368061265
# 4  116619362  14344324 2013-06-14      4207  291045518
#
#                                               actors  \
# 0  [Jennifer Lawrence, Josh Hutcherson, Liam Hems...
# 1  [Robert Downey, Jr., Gwyneth Paltrow, Don Chea...
# 2               [Kristen Bell, Josh Gad, Alan Tudyk]
# 3  [Steve Carell, Kristen Wiig, Benjamin Bratt, R...
# 4  [Henry Cavill, Amy Adams, Michael Shannon, Kev...
#
#                        directors  imdb     ...       year  Yviews_adj  \
# 0             [Francis Lawrence]   7.5     ...       2013   5934468.0
# 1                  [Shane Black]   7.2     ...       2013   1058755.0
# 2     [Chris Buck, Jennifer Lee]   7.5     ...       2013   4180616.0
# 3  [Pierre Coffin, Chris Renaud]   7.4     ...       2013   5956633.0
# 4                  [Zack Snyder]   7.1     ...       2013  32225959.0
#
#    Ylikes_adj  Ydis_adj  Ycom_adj  tick  act_gross  act_nmovies  dir_gross  \
# 0     24922.0     663.0    4547.0  8.13     3333.4           56     1056.5
# 1      5984.0     215.0    1365.0  8.13     2476.5           52       40.5
# 2      6607.0    1057.0     910.0  8.13     1774.2           19      230.0
# 3     13696.0    1336.0    1655.0  8.13     2619.7           32      852.1
# 4    117285.0    4916.0   50259.0  8.13     2120.6           42     1028.6
#
#    dir_nmovies
# 0            7
# 1            3
# 2            3
# 3            4
# 4            8
#
# [5 rows x 24 columns]

# %%
merged2.to_pickle("merged2.pkl")

# %%
merged2 = merged2.drop(["actors","directors"],1)
merged2.columns
# Out:
# Index(['movie_name', 'movie', 'op_gross', 'est_tick', 'date_time', 'theaters',
#        'tot_gross', 'imdb', 'metacritic', 'rated', 'rotten_tomatoes',
#        'runtime', 'year', 'Yviews_adj', 'Ylikes_adj', 'Ydis_adj', 'Ycom_adj',
#        'tick', 'act_gross', 'act_nmovies', 'dir_gross', 'dir_nmovies'],
#       dtype='object')
