# %% [markdown]
# # Google trends plots

# %%
import pandas as pd
import seaborn as sns
% matplotlib inline
# %config InlineBackend.figure_format = 'png'
import matplotlib as mpl
import datetime as dt
import numpy as np
import time
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
mpl.rcParams['figure.dpi']= 300

# %%
WNVSearch = pd.read_csv("WNVSearch.csv")
WNVSearch.head()
# Out:
#      Month  WestNileVirus
# 0  2004-01             10
# 1  2004-02             11
# 2  2004-03             13
# 3  2004-04             17
# 4  2004-05             25

# %%
WNVSearch.Month = pd.to_datetime(WNVSearch.Month)

# %%
WNVSearch["Year"] = WNVSearch.Month.apply(lambda x: x.year)

# %%
WNVSearch
# Out:
#          Month  WestNileVirus  Year
# 0   2004-01-01             10  2004
# 1   2004-02-01             11  2004
# 2   2004-03-01             13  2004
# 3   2004-04-01             17  2004
# 4   2004-05-01             25  2004
# 5   2004-06-01             51  2004
# 6   2004-07-01             83  2004
# 7   2004-08-01             90  2004
# 8   2004-09-01             51  2004
# 9   2004-10-01             21  2004
# 10  2004-11-01             10  2004
# 11  2004-12-01              7  2004
# 12  2005-01-01              7  2005
# 13  2005-02-01              9  2005
# 14  2005-03-01              9  2005
# 15  2005-04-01             11  2005
# 16  2005-05-01             16  2005
# 17  2005-06-01             23  2005
# 18  2005-07-01             37  2005
# 19  2005-08-01             50  2005
# 20  2005-09-01             33  2005
# 21  2005-10-01             15  2005
# 22  2005-11-01              9  2005
# 23  2005-12-01              5  2005
# 24  2006-01-01              4  2006
# ...

# %%
dt.timedelta(5)
# Out:
# datetime.timedelta(5)

# %%
sns.barplot(data=WNVSearch, x='Month', y='WestNileVirus', ci=None)

plt.xticks(np.arange(min(WNVSearch.Month), max(WNVSearch.Month)+1, 5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-c2e7b39ba9ac> in <module>()
#       1 sns.barplot(data=WNVSearch, x='Month', y='WestNileVirus', ci=None)
#       2
# ----> 3 plt.xticks(np.arange(min(WNVSearch.Month), max(WNVSearch.Month)+1, 5))
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib._Timestamp.__add__()
#
# ValueError: Cannot add integral value to Timestamp without freq.

# %%
sns.barplot(data=conjuring2, x='Month', y='conjuring',
                hue='Youtube Searches', ci=None)

# %%
sns.barplot(data=conjuring3, x='Week', y='conjuring',
                hue='Youtube Searches', ci=None)

# %%
releasedate - relativedelta(months=6)
# Out:
# datetime.date(2013, 1, 19)

# %%
releasedate + relativedelta(months=12)
# Out:
# datetime.date(2014, 7, 19)

# %%
dunkirk = datetime.date(2017,7,21)

# %%
dunkirk - relativedelta(months=6)
# Out:
# datetime.date(2017, 1, 21)

# %%
sns.barplot(data=dunkirk, x='Week', y='dunkirk',
                hue='Youtube Searches', ci=None)
plt.title("dunkirk")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-dafbf1e9e8c8> in <module>()
#       1 sns.barplot(data=dunkirk, x='Week', y='dunkirk',
#       2                 hue='Youtube Searches', ci=None)
# ----> 3 plt.title("dunkirk")
#
# NameError: name 'plt' is not defined
